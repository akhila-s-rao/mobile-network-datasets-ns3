# %%
# reload

# %load_ext autoreload
# %autoreload 2

# %%
# import  
#%matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import time
import numpy as np
import sys
import math
#import wandb
from tqdm import tqdm
from functions_dicts_to_parse_data import *
# Increase plot font size from default for all plots instead of setting it in each plot 
plt.rcParams.update({'font.size': 22})

# %%
# redirect all print statements to file instead of console

#file_path = 'logs_from_notebook.txt'
#sys.stdout = open(file_path, "w")

# %%
#=========================================
# What info / plots do you want displayed
#=========================================
print_logfile_info = True
print_byte_matrix = True
histogram_plots = True
distance_plots = True
timeseries_plots = True; 
# timeseries plots: Which run should I select for timeseries plots 
# (Since it would be too much to plot every UE in every run) 
ts_plot_run_nums = 'run3'; 
# Which UEs (or IMSIs) should we make time series plots for from the ts_plot_run_nums runs 
ts_plot_IMSIs = [1,2,3]
# When using time aggregation to smooth out plots and make 
# them more visually interpretable what window size to use 
time_wind_str = '500ms'
time_wind_val = 500
#===================================
# Data source
#=================================== 
# give the location of the right data source that you want to visualize

# srsPeriodicity40_1msUlSinr is now standard so not adding it in the name 
#data_dir = '../../data_volume/lte_3macro_30Ue_delay_rtt_UMi_ISD200m_noShadowing/' 
#data_dir = '../../data_volume/lte_3macro_30Ue_delay_rtt_UMaPropagationModel_ISD200m_noShadowing/'
#data_dir = '../../data_volume/lte_3macro_30Ue_delay_rtt_RangePropagationLossModel300m_ISD200m_noShadowing/'
#data_dir = '../../data_volume/lte_3macro_30Ue_delay_rtt_RangePropagationLossModel300m_ISD200m_noShadowing_ueTxPower30/' 

# Notes: Even when I say that it is RMa or RangePropagationLossModel it is going through the UMi if conditions so as to use UMi distances etc. 
# so that we only change the propagation model. 
# The steps here are all best case with one thing added on top. It is not incremental addition 
# - shadowing with versus without
# - easy peasy prop model versus UMi 
# - 23 dB versus 30 dB Tx power of UE (23 is the max allowed by standard for UE and 30 is the Tx power od BS,
# so i am trying to see I set UE tx power to same as BS will UL become as good as the downllink )    
        
# These should be the best case scenario where we have a low loss propagation model with no shadowing and the max BS to UE distance is low 
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_RangePropagationLossModel300m_ISD200m_noShadowing_ueTxPower30/'
# To check how much worse it gets when we reduce the Tx power of UE to max allowed level of 23dB
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_RangePropagationLossModel300m_ISD200m_noShadowing_ueTxPower23/'
# To check what happens when we switch up the model to UMi which has more path loss
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_noShadowing_ueTxPower23/'
# To check what happens when we introduce shadowing
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_ueTxPower23/'
# Made the A3 handover more conservative to see of the large number of handovers in the fast UEs wil reduce 
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_ueTxPower23_conservativeA3HO/'
#Made the A2A4 handover more conservative to see of the large number of handovers in the fast UEs wil reduce 
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_ueTxPower23_conservativeA2A4HO/'
# made it extremely conservative becaude the other one has no effect 
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_ueTxPower23_extremelyConservativeA2A4HO/'
# to see if 130 to 120 degree beamwifth reduces intereference 
#data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_ueTxPower23_120Beam/'

data_dir = '../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/'


# To check what happens when we increase inter site distance to what it was in the script - 500 m 
#data_dir = '../../data_volume/lte_3macro_30Ue_delay_rtt_RangePropagationLossModel300m_noShadowing_ueTxPower30/'

print('Raw data folder: \n'+data_dir+'\n')


plot_dir = './plots/'+data_dir.split('/')[-2]+'/'
print('Plots saved in folder: \n'+plot_dir+'\n')

if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)

info_file = open(data_dir+'run1/simulation_info.txt')
for i in range(95):
    print(info_file.readline())
    
# This is a subset of log files that we would like to parse and plot at the moment depending on what is in the data 
#files = ['delay_trace.txt', 'mobility_trace.txt']
files = ran_files+[
    #'dlThroughput_trace.txt',
                   'rtt_trace.txt', 'delay_trace.txt', 
                   'handover_trace.txt', 'mobility_trace.txt']         
         #'vrBurst_trace.txt', 'vrFragment_trace.txt',
         #'dashClient_trace.txt', 'mpegPlayer_trace.txt', # video streaming
         #'httpServerDelay_trace.txt', 'httpClientDelay_trace.txt', 'httpClientRtt_trace.txt']

# Specify here topology details from the dataset we are using 
# This can be infered from the files, but this is easier 
total_num_cells=3
total_num_ues=3
num_runs = 10
sim_time = 200 # seconds
sim_start_time = pd.to_datetime(0, unit='s', origin='unix')
sim_end_time = pd.to_datetime(sim_time, unit='s', origin='unix')

dict_gnb_pos = pd.read_csv(data_dir+'run1/gnb_locations.txt', sep=',').set_index('cellId').to_dict('index')
dict_gnb_pos[0] = {'gnbpos_x': np.nan, 'gnbpos_y': np.nan, 'gnbpos_z': np.nan}
# Out:
# Raw data folder:
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/
#
# Plots saved in folder:
# ./plots/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/
#
# Waf: Entering directory `/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build'
#
#
#
# Scenario Topology Parameters:
#
#
#
# Macro layer BS positions:               Regular hexaonal lay down
#
# Macro layer num of rings:               0
#
# Macro layer num of BSs:                 0
#
# Micro layer BS antenna pattern:         Cosine 120 degrees
#
# Micro layer of BSs:                     Disabled
#
# Num of UEs:                             0
#
# Number of UEs per BS (per sector):      1
#
# Antenna down tilt angle:                0 deg
#
# 3GPP Scenario:                          UMi
#
#   (ISD: 0.5 km, BS height: 10 m, UE height: 1.5 m, UE-BS min dist: 10 m)
#
#
#
# Radio Parameters:
#
#
#
# Radio Access Technology:                LTE
#
# UL/DL Duplexing mode:                   FDD
#
# Uplink Power Control mode:              Enabled
#
# Macro layer Channel bandwidth:          10 MHz
#
# Spectrum configuration:                 overlapping
#
# Scheduler:                              PF
#
# RLC buffer size:                        102400 Bytes
#
# Handover Algorithm:                     A2A4Rsrq
#
#
#
# TCP Send/REcv Buffer Size:              1024000 Bytes
#
#
#
# Mobility Parameters:
#
#
#
# Mobility Model:                         Random Way point
#
# Fraction of fast moving UEs:            0.2
#
#
#
# Traffic App Parameters:
#
#
#
# Apps included:                          Delay probes  RTT probes
#
#
#
# Delay/RTT Pkt size:                     1400
#
# Delay/RTT Probe interval:               +0.1s
#
# Video streaming Client Buffer:          10000000 Bytes
#
#
#
# Simulations Parameters:
#
# Simulations Duration:                   +200s
#
# Trace file generation:                  ON
#
# Rand Seed:                              0
#
# Start wall clock: Mon Jan  9 20:31:14 2023
#
#
#
# Macro topology Configuration: 1 sites, 3 sectors/site, 3 macro cells, 3 UEs
#
# Topology Bounding box (x,y): (-67.6667, -67.5327)  (-67.6667, 67.5327)  (67.1667, -67.5327)  (67.1667, 67.5327)
#
# Area X width: 134.833 meters  Area Y width: 135.065 meters
#
#
#
#
#
# ------------------------------------------------------
#
# Start Simulation ! Runtime: 201.05 seconds
#
#
#
# ================ BS Info =================
#
# All basestation locations:
#
# gnbNodes Index:0 CellId: 1 pos: (0.5, 0.866025, 10)
#
# gnbNodes Index:1 CellId: 2 pos: (-1, 1.22465e-16, 10)
#
# gnbNodes Index:2 CellId: 3 pos: (0.5, -0.866025, 10)
#
#
#
#
#
# ================ UE Info =================
#
# NodeId 3   UeIndex(ueId) 0   IMSI 1   cellId 0   UeIpAddr 7.0.0.2   UePos 7.27976:32.4545:1.5
#
# NodeId 4   UeIndex(ueId) 1   IMSI 2   cellId 0   UeIpAddr 7.0.0.3   UePos 11.4608:-61.4181:1.5
#
# NodeId 5   UeIndex(ueId) 2   IMSI 3   cellId 0   UeIpAddr 7.0.0.4   UePos 15.8265:26.1693:1.5
#
#
#
# Fast moving UeIds
#
#
#
# ConnectionEstablished at  gNB CellId 1 with UE IMSI 3 RNTI 1
#
# ConnectionEstablished at  gNB CellId 2 with UE IMSI 1 RNTI 1
#
# ConnectionEstablished at  gNB CellId 3 with UE IMSI 2 RNTI 1
#
# +4.294967295s (2.440   x real time) 203094 events processed
#
# +9.663676415s (2.777   x real time) 258378 events processed
#
# +16.935836950s (2.719   x real time) 347301 events processed
#
# +20.189600053s (4.397   x real time) 157201 events processed
#
# +23.443363156s (4.067   x real time) 158322 events processed
#
# +30.716480680s (2.577   x real time) 348392 events processed
#
# +37.805540915s (2.650   x real time) 339105 events processed
#
# +44.895534043s (2.612   x real time) 341400 events processed
#
# +51.868712640s (2.477   x real time) 333076 events processed
#
# +58.566451673s (2.410   x real time) 320382 events processed
#
# +65.251635027s (2.565   x real time) 319044 events processed
#
# +72.043599666s (2.397   x real time) 325299 events processed
#
# +78.638012144s (2.482   x real time) 314221 events processed
#
# +85.292397460s (2.461   x real time) 317674 events processed
#
# +91.960315302s (2.476   x real time) 317689 events processed
#
# +98.668644768s (2.475   x real time) 319980 events processed
#
# +105.357074662s (2.458   x real time) 318601 events processed
#
# +112.032404994s (2.479   x real time) 317968 events processed
#
# +118.714555758s (2.472   x real time) 318255 events processed
#
# +125.376759802s (2.464   x real time) 319033 events processed
#
# +132.019076669s (2.457   x real time) 317279 events processed
#
# +138.641565724s (2.450   x real time) 315969 events processed
#
# +145.244286155s (2.442   x real time) 315246 events processed

# %%
# initilize wandb for experiment tracking
config_dict = {'dataset': data_dir.split('/')[-2], 'window size': time_wind_str, 'log files processed': files,
              'simulation time': sim_time, 'num of cells': total_num_cells, 'num of UEs':total_num_ues,
              'num of runs':num_runs, 'run used for timeseriess plots': ts_plot_run_nums, 
               'IMSIs used for timeseries plots':ts_plot_IMSIs}
#wandb.init(project="mobile-radio-dataset", entity="network-intelligence", config=config_dict)
print(config_dict)
# Out:
# {'dataset': 'lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12', 'window size': '500ms', 'log files processed': ['DlTxPhyStats.txt', 'UlRxPhyStats.txt', 'UlSinrStats.txt', 'UlPdcpStats.txt', 'DlRsrpSinrStats.txt', 'UlRlcStats.txt', 'UlMacStats.txt', 'UlTxPhyStats.txt', 'DlPdcpStats.txt', 'DlRlcStats.txt', 'DlRxPhyStats.txt', 'DlMacStats.txt', 'rtt_trace.txt', 'delay_trace.txt', 'handover_trace.txt', 'mobility_trace.txt'], 'simulation time': 200, 'num of cells': 3, 'num of UEs': 3, 'num of runs': 10, 'run used for timeseriess plots': 'run3', 'IMSIs used for timeseries plots': [1, 2, 3]}

# %%
#=======================================
# Initilizing empty lists 
#=======================================

# To measure delay probe delivery rate 
# These are values aggregated over all UEs over the símulations time over all runs 
ul_delay_probe_delivery_rate = 0
dl_delay_probe_delivery_rate = 0
rtt_probe_delivery_rate = 0
ul_avg_thput = 0
dl_avg_thput = 0

# Baselines for empty networks
# Aggregate over UEs and runs for histogram plots
# These are arrays with samples aggregated over all UEs over the simulations time over all runs 
# These are not windowed 
ul_delays = np.empty(0)
dl_delays = np.empty(0)
rtt_delays = np.empty(0)
ul_thput = np.empty(0)
dl_thput = np.empty(0)
ul_mcs = np.empty(0)
dl_mcs = np.empty(0)
ul_sinr = np.empty(0)
dl_sinr = np.empty(0)

cell_ul_thput = np.empty(0)
cell_dl_thput = np.empty(0)



# Baselines for empty networks
# distance to BS versus metrics, aggregated over windows 
# These are arrays with samples aggregated over all UEs over the simulations time over all runs 
# These are windowed 
w_ul_delays = np.empty(0)
w_dl_delays = np.empty(0)
w_rtt_delays = np.empty(0)
w_ul_sinr = np.empty(0)
w_dl_sinr = np.empty(0)
w_rsrp = np.empty(0)
w_dist_to_cell = np.empty(0)
w_ul_mcs = np.empty(0)
w_dl_mcs = np.empty(0)

# mi here is multi-indexed, with time and IMSi as the 2 levels of indices 
mi_ul_delays = pd.DataFrame()
mi_dl_delays = np.empty(0)
mi_rtt_delays = np.empty(0)
mi_ul_sinr = np.empty(0)
mi_dl_sinr = np.empty(0)
mi_rsrp = np.empty(0)
mi_dist_to_cell = np.empty(0)



# app specific observations for plotting
# aggregated over all UEs running this app to plot histograms 
page_load_time = np.empty(0) # page load time over all webpages viewed 
webpage_size = np.empty(0) # size of the webpage 
segment_bitrate = np.empty(0) # bitrate of segment requested over all videos watched
vr_burst_time = np.empty(0) # time to receive a full burst in VR 

# handover related initializers
hos_per_cell_per_time = 0
time_bw_hos = np.empty(0) # seconds 

# constant multipliers
M = (10**6)
K = (10**3)

#=======================================
# Iterate over runs and files 
#=======================================


#=================================================================
#for run in os.listdir(data_dir):
#for run in tqdm(glob.glob(data_dir+'run3')):
for run in tqdm(glob.glob(data_dir+'run*')):
#=================================================================

    print('============================================================')
    print (run)
    print('============================================================')
    only_run = run.split('/')[-1]
    # check if run ran to completion
    with open(run+'/simulation_info.txt', "r") as sim_info_file:
        last_line = sim_info_file.readlines()[-1]
        if 'Elapsed wall clock' not in last_line:
            print('This run did not finish to completion, skipping it')
            continue
            
    # To store and compare the number of bytes sent and received in different RAN layers 
    bytes_matrix = np.zeros((4, 4), dtype=int)
    # time series plots for a chosen run 
    #if ts_plot_run_nums in run:
    if True:    
        # Aggregate plots from different files into one figure since we iterate over files
        # subplots for the chosen IMSI values for the one chosen run 
        # ul mcs, dl mcs figure
        if 'UlMacStats.txt'in files and 'DlMacStats.txt' in files:
            fig_mcs, axs_mcs = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
            fig_mcs.suptitle(only_run+':  MCS: UL/DL')
        if 'DlRsrpSinrStats.txt' in files and 'UlSinrStats.txt' in files: 
            # ul sinr and dl sinr
            fig_sinr, axs_sinr = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
            fig_sinr.suptitle(only_run+':  SINR: UL/DL')
        if 'delay_trace.txt' in files:
            # ul delay, dl delay, rtt figure 
            fig_delay, axs_delay = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
            fig_delay.suptitle(only_run+':  Delay: UL/DL')
        if 'httpClientRtt_trace.txt' in files:
            # http web page objects 
            fig_http, axs_http = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
            fig_http.suptitle(only_run+':  Time to fetch http web browser object (ms)')
        if 'dashClient_trace.txt' in files:
            # video segment bitrates 
            fig_bitrate, axs_bitrate = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
            fig_bitrate.suptitle(only_run+':  Video segment bitrate')
        
        
    
#=================================================================
    for file in files:
#=================================================================
        print('--------------------------------------------')
        print(file)
        start_time = time.time()
        
        #=======================================
        # Preprocess logs 
        #=======================================
        
        ## Read file while fixing the tab issue
        if file in files_with_trailing_tab:
            #df = pd.read_csv(data_dir+run+'/'+file, sep='\t', usecols=range(0,18))
            df = pd.read_csv(run+'/'+file, sep='\t', usecols=range(0,18))
            print(run+'/'+file)
        else:
            #df = pd.read_csv(data_dir+run+'/'+file, sep='\t')
            df = pd.read_csv(run+'/'+file, sep='\t')
            print(run+'/'+file)
        
        print('time to read file: ', (time.time() - start_time))
        
        
        ## Do some file specific preprocessing
        ## Make uniform the timestamp units convert them all to micro seconds 
        if '% time' in df.columns:
            df.rename(columns = {'% time':'tstamp_us'}, inplace = True)
            if file_name_to_tstamp_unit[file] == 'ms':
                df['tstamp_us'] = df['tstamp_us']*K
            elif file_name_to_tstamp_unit[file] == 's':
                df['tstamp_us'] = df['tstamp_us']*M
        ## Make uniform the timestamp units        
        if '% start' in df.columns:
            ## TO DO: check if this is actually micro seconds. I think it is seconds   
            df.rename(columns = {'% start':'tstamp_us'}, inplace = True)
            df.rename(columns = {'end':'end_timeslot_us'}, inplace = True)
            df['tstamp_us'] = df['tstamp_us']*M
            df['end_timeslot_us'] = df['end_timeslot_us']*M
        ## Some internally generated logs use the naming 'CellId' replace that with 'cellId'
        if ('CellId' in df.columns):
            df.rename(columns = {'CellId':'cellId'}, inplace = True)
        if ('currentCellId' in df.columns):
            df.rename(columns = {'currentCellId':'cellId'}, inplace = True)    
        
        # Warning: cellId and IMSI here are IP addresses, but it should not matter since 
        # there will only be 1 UE doing these ul and dl throughput scans   
        if file == 'dlThroughput_trace.txt':
            df.rename(columns = {'toAddr':'IMSI', 'fromAddr': 'cellId'}, inplace = True)
            assert (df['IMSI'].nunique() == 1), "More than one throughput measurement UE is in the logs" 
        if file == 'ulThroughput_trace.txt':
            df.rename(columns = {'toAddr':'cellId', 'fromAddr': 'IMSI'}, inplace = True)
            assert (df['IMSI'].nunique() == 1), "More than one throughput measurement UE is in the logs" 
            
        ## Just for plotting change the timestamp_us to seconds and delay values to milli seconds 
        ## since I am mostly plotting directly from pandas and don't know how to add a multiplicative factor to a column    
        if 'tstamp_us' in df.columns:
            df['tstamp_us'] = df['tstamp_us']/M
            # Set datetime index for all files so that we can do series operations 
            datatime_timestamps = pd.to_datetime(df['tstamp_us'], unit='s', origin='unix')
            df = df.set_index(datatime_timestamps, inplace=False)
            
            # add a sample at the beginning and ending of every timeseries at sim_start_time and sim_end_time. 
            # This way the timeseries after resampling are all of the same length 
            alignment_sample = np.empty(df.shape[1])
            alignment_sample[:] = np.nan
            start_sample = pd.DataFrame([alignment_sample], columns=df.columns, index=[sim_start_time])
            end_sample = pd.DataFrame([alignment_sample], columns=df.columns, index=[sim_end_time])
            if 'dir' in df.columns:
                for imsi in range(1,total_num_ues+1):
                    for di in ['UL', 'DL']:
                        start_sample['IMSI'] = imsi
                        start_sample['dir'] = di
                        end_sample['IMSI'] = imsi
                        end_sample['dir'] = di
                        df = pd.concat([start_sample, df, end_sample])
            elif 'cellId' in df.columns:
                for imsi in range(1,total_num_ues+1):
                    start_sample['IMSI'] = imsi
                    start_sample['cellId'] = 0
                    end_sample['IMSI'] = imsi
                    end_sample['cellId'] = 0
                    df = pd.concat([start_sample, df, end_sample])
            else:
                for imsi in range(1,total_num_ues+1):
                    start_sample['IMSI'] = imsi
                    end_sample['IMSI'] = imsi
                    df = pd.concat([start_sample, df, end_sample])
        
        if file == 'dlThroughput_trace.txt' or file == 'ulThroughput_trace.txt':
            df['IMSI'] = 1
            thput_meas_imsi = 1
        
        # converting all delay values to ms instead of us
        if 'delay' in df.columns:
            df['delay'] = df['delay']/K
        
        #=======================================
        # Print log file info  
        #=======================================
        if print_logfile_info:
            ## Display info about the UEs who have made entries in this file to make sure that all the UEs who should be here are here. 
            print('ueIds: min:', min(df['IMSI'].value_counts().index), 'max:', max(df['IMSI'].value_counts().index),
                 'count:', len(df['IMSI'].value_counts().index))
            if len(df['IMSI'].value_counts().index) < total_num_ues:
                print('WARNING: Fewer UEs in this file than the total number in the simulation')
                print(df['IMSI'].value_counts())

            ## Display info about the Cells who have made entries in this file
            #print('cellIds: min:', min(df['cellId'].value_counts().index), 'max:', max(df['cellId'].value_counts().index),
            #     'count:', len(df['cellId'].value_counts().index))

            ## Total runtime of log
            print('log time (start, end): (', np.nanmin(df['tstamp_us']), ', ' ,np.nanmax(df['tstamp_us']), ')')
            print('log runtime:', (np.nanmax(df['tstamp_us']) - np.nanmin(df['tstamp_us'])), ' seconds')
        
        
        #=======================================
        # Byte matrix: Aggregate bytes over runs  
        #=======================================
        
        ## Gather the number of bytes sent from/to all UEs in each layer and direction to compare
        if file == 'DlTxPhyStats.txt':
            bytes_matrix[0,0] = df['size'].sum()/M
        elif file == 'DlRxPhyStats.txt':
            bytes_matrix[2,0] = df['size'].sum()/M
        elif file == 'UlTxPhyStats.txt':
            bytes_matrix[1,0] = df['size'].sum()/M
        elif file == 'UlRxPhyStats.txt':
            bytes_matrix[3,0] = df['size'].sum()/M
        elif file == 'DlMacStats.txt':
            bytes_matrix[0,1] = (df['sizeTb1'].sum() + df['sizeTb2'].sum())/M
        elif file == 'UlMacStats.txt':
            bytes_matrix[1,1] = df['size'].sum()/M
        elif file == 'DlRlcStats.txt':
            bytes_matrix[0,2] = df['TxBytes'].sum()/M
            bytes_matrix[2,2] = df['RxBytes'].sum()/M
        elif file == 'UlRlcStats.txt':
            bytes_matrix[1,2] = df['TxBytes'].sum()/M
            bytes_matrix[3,2] = df['RxBytes'].sum()/M
        elif file == 'DlPdcpStats.txt':
            bytes_matrix[0,3] = df['TxBytes'].sum()/M
            bytes_matrix[2,3] = df['RxBytes'].sum()/M
        elif file == 'UlPdcpStats.txt':
            bytes_matrix[1,3] = df['TxBytes'].sum()/M
            bytes_matrix[3,3] = df['RxBytes'].sum()/M

        
        #======================================================
        # File specific extraction and aggregation of metrics  
        #======================================================
        
        if file == 'UlMacStats.txt':
            cell_ul_thput = np.append(cell_ul_thput, df.groupby(by=['cellId'])['size'].resample(time_wind_str).sum()/M) # MB in each time window 
            ul_mcs = np.append(ul_mcs, df['mcs'])
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            w_ul_mcs = np.append(w_ul_mcs, df_parsed['mcs'])
        
        if file == 'DlMacStats.txt':
            cell_dl_thput = np.append(cell_dl_thput, df.groupby(by=['cellId'])['sizeTb1'].resample(time_wind_str).sum()/M) # MB
            dl_mcs = np.append(dl_mcs, df['mcsTb1'])
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            w_dl_mcs = np.append(w_dl_mcs, df_parsed['mcsTb1'])
        
        if file == 'DlRsrpSinrStats.txt':
            #grouping results in a mutli-indexed dataframe 
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            dl_sinr = np.append(dl_sinr, df['sinr'])
            w_rsrp = np.append(w_rsrp, df_parsed['rsrp'])
            w_dl_sinr = np.append(w_dl_sinr, df_parsed['sinr'])
          
        if file == 'UlSinrStats.txt':
            # note that the UL sinr is linear while the dl sinr is in dB (I think ... )
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            w_ul_sinr = np.append(w_ul_sinr, df_parsed['sinrLinear'])
            ul_sinr = np.append(ul_sinr, df_parsed['sinrLinear'])
            
        if file == 'delay_trace.txt':
            # separate UL and DL 
            ul_probes = df.groupby(by=['dir']).get_group('UL').groupby(by=['IMSI']).size()
            dl_probes = df.groupby(by=['dir']).get_group('DL').groupby(by=['IMSI']).size()
            #if ts_plot_run_nums in run:
            if True:    
                # group by UE
                print('UL # delay probe delivery rate per UE: ', ul_probes/(sim_time*10))
                print('DL # delay probes delivery rate per UE: ', dl_probes/(sim_time*10))
            #print('Sum of Delay probes for all UEs: UL: ', ul_probes.sum(), ' DL: ', dl_probes.sum())
            ul_delay_probe_delivery_rate = ul_delay_probe_delivery_rate + ul_probes.sum()
            dl_delay_probe_delivery_rate = dl_delay_probe_delivery_rate + dl_probes.sum()
            # for histogram
            ul_delays = np.append(ul_delays, df.groupby(by=['dir']).get_group('UL')['delay'])
            dl_delays = np.append(dl_delays, df.groupby(by=['dir']).get_group('DL')['delay'])
            
            # need to organize by UE IMSI
            df_ul_parsed = df.groupby(by=['dir']).get_group('UL').sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')  
            df_dl_parsed = df.groupby(by=['dir']).get_group('DL').sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            w_ul_delays = np.append(w_ul_delays, df_ul_parsed['delay'])
            w_dl_delays = np.append(w_dl_delays, df_dl_parsed['delay'])
            #for name, group in df.groupby(by=['dir']).get_group('UL').sort_values(by=['IMSI']).groupby(by=['IMSI']):
            #    print(name, group.resample(time_wind_str).mean().shape[0])
            #    print(name, group.resample(time_wind_str).mean().index[0])
            #    print(name, group.resample(time_wind_str).mean().index[-1])
            
        if file == 'rtt_trace.txt':
            rtt_probes = df.groupby(by=['IMSI']).size()
            # group by UE
            #print('# RTT probes per UE: ', rtt_probes/(sim_time*10))
            #print('Sum of RTT probes for all UEs: ', rtt_probes.sum())
            rtt_probe_delivery_rate = rtt_probe_delivery_rate + rtt_probes.sum()
            # for histogram
            rtt_delays = np.append(rtt_delays, df['delay'])
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            w_rtt_delays = np.append(w_rtt_delays, df_parsed['delay'])
            
        if file == 'ulThroughput_trace.txt':
            ul_avg_thput = ul_avg_thput + (df['pktSize'].sum()/M) # MB
            # even the mobility log should only have one UE or we wont know which one to match with this log for distance versus metric graphs
            df_parsed = df.resample(time_wind_str).sum()*8/(time_wind_val*K)
            df_parsed = df_parsed[sim_start_time : sim_end_time]# Mbps
            ul_thput = np.append(ul_thput, df_parsed['pktSize'])# Mbps
            
        if file == 'dlThroughput_trace.txt':
            dl_avg_thput = dl_avg_thput + (df['pktSize'].sum()/M) # MB
            # even the mobility log should only have one UE or we wont know which one to match with this log for distance versus metric graphs
            df_parsed = df.resample(time_wind_str).sum()*8/(time_wind_val*K)
            df_parsed = df_parsed[sim_start_time : sim_end_time]# Mbps
            dl_thput = np.append(dl_thput, df_parsed['pktSize'])# Mbps   
        
        if file == 'handover_trace.txt':
            hos_per_cell_per_time = hos_per_cell_per_time + df.shape[0]
            time_bw_hos = np.append(time_bw_hos, df.groupby(by=['IMSI'])['tstamp_us'].diff().dropna())   
            #for name, group in df.groupby(by=['IMSI']):
            #    print('IMSI:', name, ' ')
        
        if file == 'mobility_trace.txt':
            # add a distance column which is the distance from the UE to the cell it is connected to
            gnb_pos = [dict_gnb_pos[cellId] for cellId in df['cellId'].to_numpy()]
            ue_pos = df[['pos_x', 'pos_y']].to_numpy()
            distance = [math.dist([gnb_loc['gnbpos_x'],gnb_loc['gnbpos_y']], ue_loc) for gnb_loc,ue_loc in zip(gnb_pos,ue_pos)]          
            # gnb_pos is a list of dictionaries as well with keys {'gnbpos_x': 1, 'gnbpos_y': 0.5, 'gnbpos_z' : 0.5}
            # so it is a list of dictionaries 
            # Does it have 0 IMSI values ? if so then I need to remove it  
            # add distance as a column 
            df['dist_to_cell'] = distance
            #if ('ulThroughput_trace.txt' in files) or ('dlThroughput_trace.txt' in files):
            #    df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).get_group(thput_meas_imsi).resample(time_wind_str).mean().loc[sim_start_time : sim_end_time]
            #else:
            df_parsed = df.sort_values(by=['IMSI']).groupby(by=['IMSI']).resample(time_wind_str).mean().loc[pd.IndexSlice[:, sim_start_time : sim_end_time], :].droplevel('IMSI')
            
            w_dist_to_cell = np.append(w_dist_to_cell, 
                                       df_parsed['dist_to_cell'])
            #for name, group in df.sort_values(by=['IMSI']).groupby(by=['IMSI']):
            #    print(name, group.resample(time_wind_str).mean().shape[0])
            #    print(name, group.resample(time_wind_str).mean().index[0])
            #    print(name, group.resample(time_wind_str).mean().index[-1])
            
        if file == 'httpClientRtt_trace.txt':
            # get page load time 
            # grouped by IMSI, by web page id 
            # doubt this will work but I need to see if there is a way to do this without a nested for loop
            #page_load_time = np.append( page_load_time, df.groupby(by=['IMSI']).groupby(by=['webpageId'])['delay'].sum() )
            #webpage_size = np.append( webpage_size, df.groupby(by=['IMSI']).groupby(by=['webpageId'])['objectSize'].sum() )
            for name1, group1 in df.groupby(by=['IMSI']):
                for name2, group2 in group1.groupby(by=['webpageId']):
                    page_load_time = np.append(page_load_time, group2['delay'].sum())
                    webpage_size = np.append(webpage_size, group2['objectSize'].sum())
                
        if file == 'vrFragment_trace.txt':
            # time to send a VR burst of pictures
            for name1, group1 in df.groupby(by=['IMSI']):
                for name2, group2 in group1.groupby(by=['burstSeqNum']):
                    this_run_vr_burst_time = group2['delay'].sum()
                    vr_idx = group2['delay'].index
                    vr_burst_time = np.append(vr_burst_time, this_run_vr_burst_time)
        
        if file == 'dashClient_trace.txt':
            segment_bitrate = np.append(segment_bitrate, df['newBitRate_bps'])
        
        #if file == 'flow_trace.txt':
        #    # separate UL and DL 
        #    ul_brate = df.groupby(by=['dir']).get_group('UL').groupby(by=['IMSI'])['pktSize'].sum()/(M) # MB
        #    ul_brate = ul_brate*8/(df['tstamp_us'].iloc[-1] - df['tstamp_us'].iloc[0]) 
        #    dl_brate = df.groupby(by=['dir']).get_group('DL').groupby(by=['IMSI'])['pktSize'].sum()/(M) # MB
        #    dl_brate = dl_brate*8/(df['tstamp_us'].iloc[-1] - df['tstamp_us'].iloc[0]) 
        #    # group by UE
        #    print('UL brate Mbps per UE: ', ul_brate)
        #    print('DL brate Mbps per UE: ', dl_brate)
        #    #print('UL Giga Bytes sent by each UE over the duration of the simulation: ', ul_bytes_sent)
        #    #print('DL Giga Bytes sent by each UE over the duration of the simulation: ', dl_bytes_sent)
        
        #=======================================
        # Plot timeseries   
        #=======================================
        
        #if (timeseries_plots and (ts_plot_run_nums in run) ):    
        if (timeseries_plots and (True) ):        
            # To see samples of various metrics in cmparison with each other as they change                
            ## RAN plots (UL mcs overlayed on DL mcs) for samples UEs in a sample run 
            if file == 'DlMacStats.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    #print('ix:', ix, 'ue', ue, 'ts_plot_IMSIs', ts_plot_IMSIs)
                    #print('imsis in df', df['IMSI'].unique())
                    val = df.groupby(by=['IMSI']).get_group(ue)['mcsTb1'].resample(time_wind_str).mean()
                    axs_mcs[ix].plot(val.index, val, color='b')
                    axs_mcs[ix].set_xlabel('Time stamp (seconds)')
                    axs_mcs[ix].set_ylabel('MCS')
                    axs_mcs[ix].set_title('IMSI: '+str(ue))
            elif file == 'UlMacStats.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    #print('ix:', ix, 'ue', ue, 'ts_plot_IMSIs', ts_plot_IMSIs)
                    #print('imsis in df', df['IMSI'].unique())
                    val = df.groupby(by=['IMSI']).get_group(ue)['mcs'].resample(time_wind_str).mean()
                    axs_mcs[ix].plot(val.index, val, color='r')
            elif file == 'DlRsrpSinrStats.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    #print('ix:', ix, 'ue', ue, 'ts_plot_IMSIs', ts_plot_IMSIs)
                    #print('imsis in df', df['IMSI'].unique())
                    val = df.groupby(by=['IMSI']).get_group(ue)['sinr'].resample(time_wind_str).mean()
                    axs_sinr[ix].plot(val.index, 10*np.log10(val), color='b')
                    axs_sinr[ix].set_xlabel('Time stamp (seconds)')
                    axs_sinr[ix].set_ylabel('SINR')
                    #axs_sinr[ix].set_ylim(-45,100) (-45,65)
                    axs_sinr[ix].set_title('IMSI: '+str(ue))
            elif file == 'UlSinrStats.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    #print('ix:', ix, 'ue', ue, 'ts_plot_IMSIs', ts_plot_IMSIs)
                    #print('imsis in df', df['IMSI'].unique())
                    val = df.groupby(by=['IMSI']).get_group(ue)['sinrLinear'].resample(time_wind_str).mean()
                    axs_sinr[ix].plot(val.index, 10*np.log10(val), color='r')
                    axs_sinr[ix].set_ylim(-45,150)
            ## Delay plots (UL delay, DL delay and RTT overlayed) 
            elif file == 'delay_trace.txt':
                df_ul = df.groupby(by=['dir']).get_group('UL').groupby(by=['IMSI'])
                df_dl = df.groupby(by=['dir']).get_group('DL').groupby(by=['IMSI'])
                for ix, ue in enumerate(ts_plot_IMSIs):
                    val = df_ul.get_group(ue)['delay'].resample(time_wind_str).mean()
                    axs_delay[ix].plot(val.index, val, color='r')
                    axs_delay[ix].set_xlabel('Time stamp (seconds)')
                    axs_delay[ix].set_ylabel('Delay (ms)')
                    axs_delay[ix].set_ylim(0,50)
                    axs_delay[ix].set_title('IMSI: '+str(ue))
                for ix, ue in enumerate(ts_plot_IMSIs):
                    val = df_dl.get_group(ue)['delay'].resample(time_wind_str).mean()
                    axs_delay[ix].plot(val.index, val, color='b')
                    axs_delay[ix].set_ylim(0,50)
            #elif file == 'rtt_trace.txt':
            #    print(df['IMSI'].value_counts())
            #    for ix, ue in enumerate(ts_plot_IMSIs):
            #        val = df.groupby(by=['IMSI']).get_group(ue)['delay']
            #        print(ix)
            #        axs_delay[ix].plot(val.index, val, color='magenta')
            #        axs_delay[ix].set_ylim(0,500)
            ## Browsing: Time between object request and object download (confirm this from the ns3 model)
            elif file == 'handover_trace.txt':      
                    #overlay handover shifts on delay timeseries
                for ix, ue in enumerate(ts_plot_IMSIs):
                    val = df.groupby(by=['IMSI']).get_group(ue)['cellId']
                    axs_delay[ix].stem(val.index, np.ones(val.shape[0])*1000, linefmt='k', basefmt=" ")
                    axs_mcs[ix].stem(val.index, np.ones(val.shape[0])*30, linefmt='k', basefmt=" ") 
                    axs_sinr[ix].stem(val.index, np.ones(val.shape[0])*150, linefmt='k', bottom=-45, basefmt=" ") 
            elif file == 'httpClientRtt_trace.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    val = df.groupby(by=['IMSI']).get_group(ue)['delay']
                    axs_http[ix].plot(val.index, val, color='r')
                    axs_http[ix].set_xlabel('Time stamp (seconds)')
                    axs_http[ix].set_ylabel('http object RTT (ms)')
                    axs_http[ix].set_title('IMSI: '+str(ue))
            elif file == 'dashClient_trace.txt':
                for ix, ue in enumerate(ts_plot_IMSIs):
                    val = df.groupby(by=['IMSI']).get_group(ue)['newBitRate_bps']
                    axs_bitrate[ix].plot(val.index, val, color='r')
                    axs_bitrate[ix].set_xlabel('Time stamp (seconds)')
                    axs_bitrate[ix].set_ylabel('Video segment bitrate')
                    axs_bitrate[ix].set_title('IMSI: '+str(ue))
            elif file == 'ulThroughput_trace.txt':
                val = df_parsed['pktSize'] # assuming it was parsed before 
                fig_ulThput = plt.figure(figsize=(20,3))
                fname=plot_dir+'ts_ul_throughput.png'
                plt.plot(val.index, val, color='r')
                plt.xlabel('Time stamp (seconds)')
                plt.ylabel('UL Throughput (Mbps)')
                plt.savefig(fname)
                fig_ulThput.show()
                #wandb.log({"UL Throughput (Mbps)": wandb.Image(fname)})
        
            elif file == 'dlThroughput_trace.txt':
                val = df_parsed['pktSize'] # assuming it was parsed before 
                fig_dlThput = plt.figure(figsize=(20,3))
                plt.plot(val.index, val, color='b')
                plt.xlabel('Time stamp (seconds)')
                plt.ylabel('DL Throughput (Mbps)')
                plt.savefig(plot_dir+'ts_dl_throughput.png')
                fig_dlThput.show()
                #wandb.log({"DL Throughput (Mbps)": plt})
            elif file == 'vrFragment_trace.txt': 
                fig_vr = plt.figure(figsize=(20,3))
                plt.plot(vr_idx, this_run_vr_burst_time, color='b')
                plt.xlabel('Time stamp (seconds)')
                plt.ylabel('VR time to send packet burst (ms)')
                plt.savefig(plot_dir+'ts_vr_time_to_send_packet_burst.png')
                fig_vr.show()
                #wandb.log({"VR time to send packet burst (ms)": plt})
        # end of timeseries_plots
    # end of for over files 
    #if ts_plot_run_nums in run:
    if True:    
        # save plots and send to wandb
        if 'DlRsrpSinrStats.txt' and 'UlSinrStats.txt': 
            fname=plot_dir+'timeseries_sinr.png'
            fig_sinr.savefig(fname)
            fig_sinr.show()
            print('===========================================================================================')
            #wandb.log({"timeseries of UL/DL SINR": wandb.Image(fname)})
            
        if 'UlMacStats.txt' and 'DlMacStats.txt':
            fname=plot_dir+'timeseries_mcs.png'
            fig_mcs.savefig(fname)
            fig_mcs.show()
            #wandb.log({"timeseries of UL/DL MCS": wandb.Image(fname)})
        if 'delay_trace.txt':
            fname=plot_dir+'timeseries_delay.png'
            fig_delay.savefig(fname)
            fig_delay.show()
            print('===========================================================================================')
            #wandb.log({"timeseries of UL/DL delay (ms)": wandb.Image(fname)})

        if 'httpClientRtt_trace.txt' in files:
            fname=plot_dir+'timeseries_http_delay.png'
            fig_http.savefig(fname)
            fig_http.show()
            print('===========================================================================================')
            #wandb.log({"timeseries of Time to receive http object (ms)": wandb.Image(fname)})
        if 'dashClient_trace.txt' in files:
            fname=plot_dir+'timeseries_dash_bitrate.png'
            fig_bitrate.savefig(fname)
            fig_bitrate.show()
            print('===========================================================================================')
            #wandb.log({"timeseries of Video segment bitrate": wandb.Image(fname)})     
        
    #=======================================
    # Print per run byte matrix in MB   
    #=======================================
    if print_byte_matrix:
        print ('Byte Matrix in MB')
        print('  X  phy mac rlc pdcp\n' + \
              'dlTx  x   x   x   x\n' + \
              'ulTx  x   x   x   x\n' + \
              'dlRx  x   x   x   x\n' + \
              'ulRx  x   x   x   x')
        print(bytes_matrix)

# end of for over runs

print('============================================================')
# some post processing 
if 'UlMacStats.txt' in files:
    cell_ul_thput = cell_ul_thput*8/(time_wind_val/K)#Mbps
if 'DlMacStats.txt' in files:
    cell_dl_thput = cell_dl_thput*8/(time_wind_val/K)#Mbps
# Out:
#   0%|                                                                                                                                                                                                                                                      | 0/10 [00:00<?, ?it/s]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlTxPhyStats.txt
# time to read file:  0.008282899856567383
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.523 ,  200.879 )
# log runtime: 200.356  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlRxPhyStats.txt
# time to read file:  0.0063707828521728516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.52 ,  200.818 )
# log runtime: 200.298  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlSinrStats.txt
# time to read file:  0.006203174591064453
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.043 )
# log runtime: 200.762  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlPdcpStats.txt
# time to read file:  0.00646519660949707
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlRsrpSinrStats.txt
# time to read file:  0.007456064224243164
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlRlcStats.txt
# time to read file:  0.00445246696472168
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlMacStats.txt
# time to read file:  0.005878448486328125
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.514 ,  200.812 )
# log runtime: 200.298  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/UlTxPhyStats.txt
# time to read file:  0.006911516189575195
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.52 ,  200.818 )
# log runtime: 200.298  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlPdcpStats.txt
# time to read file:  0.004902839660644531
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlRlcStats.txt
# time to read file:  0.004357099533081055
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlRxPhyStats.txt
# time to read file:  0.00655364990234375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.523 ,  200.879 )
# log runtime: 200.356  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/DlMacStats.txt
# time to read file:  0.006636619567871094
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.521 ,  200.877 )
# log runtime: 200.35600000000002  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/rtt_trace.txt
# time to read file:  0.004729032516479492
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.523999 ,  200.608999 )
# log runtime: 200.085  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/delay_trace.txt
# time to read file:  0.008367061614990234
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.645931 ,  200.879999 )
# log runtime: 200.234068  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    1.0010
# 2    0.8335
# 3    1.0010
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    0.9995
# 2    1.0010
# 3    1.0010
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/handover_trace.txt
# time to read file:  0.002106189727783203
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 6.320001 ,  163.680001 )
# log runtime: 157.36  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run3/mobility_trace.txt
# time to read file:  0.002255678176879883
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  10%|███████████████████████▊                                                                                                                                                                                                                      | 1/10 [00:01<00:17,  1.91s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[51 51 16 16]
#  [46 46 16 17]
#  [51  0 16 16]
#  [36  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlTxPhyStats.txt
# time to read file:  0.0055713653564453125
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.506 ,  200.697 )
# log runtime: 200.191  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlRxPhyStats.txt
# time to read file:  0.006032466888427734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.568 ,  200.811 )
# log runtime: 200.243  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlSinrStats.txt
# time to read file:  0.00480198860168457
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.044 )
# log runtime: 200.763  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlPdcpStats.txt
# time to read file:  0.00513148307800293
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlRsrpSinrStats.txt
# time to read file:  0.007190227508544922
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlRlcStats.txt
# time to read file:  0.0041124820709228516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlMacStats.txt
# time to read file:  0.006052255630493164
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.562 ,  200.805 )
# log runtime: 200.243  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/UlTxPhyStats.txt
# time to read file:  0.006456136703491211
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.568 ,  200.811 )
# log runtime: 200.243  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlPdcpStats.txt
# time to read file:  0.004498004913330078
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlRlcStats.txt
# time to read file:  0.003776073455810547
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlRxPhyStats.txt
# time to read file:  0.00525355339050293
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.506 ,  200.697 )
# log runtime: 200.191  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/DlMacStats.txt
# time to read file:  0.005803585052490234
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.504 ,  200.695 )
# log runtime: 200.191  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/rtt_trace.txt
# time to read file:  0.0041027069091796875
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.571999 ,  200.697999 )
# log runtime: 200.126  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/delay_trace.txt
# time to read file:  0.0074367523193359375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.506999 ,  200.811931 )
# log runtime: 200.30493199999998  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    1.0010
# 2    1.0010
# 3    0.9855
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/handover_trace.txt
# time to read file:  0.001672983169555664
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 3.760001 ,  187.160001 )
# log runtime: 183.4  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run6/mobility_trace.txt
# time to read file:  0.0023670196533203125
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  20%|███████████████████████████████████████████████▌                                                                                                                                                                                              | 2/10 [00:03<00:14,  1.76s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[52 52 17 17]
#  [51 51 17 17]
#  [52  0 17 17]
#  [43  0 17 17]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlTxPhyStats.txt
# time to read file:  0.006680488586425781
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.526 ,  200.824 )
# log runtime: 200.298  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlRxPhyStats.txt
# time to read file:  0.00711822509765625
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.572 ,  200.759 )
# log runtime: 200.18699999999998  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlSinrStats.txt
# time to read file:  0.004984378814697266
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.042 )
# log runtime: 200.761  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlPdcpStats.txt
# time to read file:  0.00461578369140625
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlRsrpSinrStats.txt
# time to read file:  0.0072214603424072266
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlRlcStats.txt
# time to read file:  0.004969596862792969
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlMacStats.txt
# time to read file:  0.0073544979095458984
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.566 ,  200.753 )
# log runtime: 200.18699999999998  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/UlTxPhyStats.txt
# time to read file:  0.006926298141479492
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.572 ,  200.759 )
# log runtime: 200.18699999999998  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlPdcpStats.txt
# time to read file:  0.004787445068359375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlRlcStats.txt
# time to read file:  0.0034127235412597656
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlRxPhyStats.txt
# time to read file:  0.005388498306274414
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.526 ,  200.824 )
# log runtime: 200.298  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/DlMacStats.txt
# time to read file:  0.0057027339935302734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.524 ,  200.822 )
# log runtime: 200.298  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/rtt_trace.txt
# time to read file:  0.004446268081665039
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.575999 ,  200.762999 )
# log runtime: 200.187  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/delay_trace.txt
# time to read file:  0.007279157638549805
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.526999 ,  200.824999 )
# log runtime: 200.298  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.9960
# 2    0.9670
# 3    0.9595
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/handover_trace.txt
# time to read file:  0.0013439655303955078
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 5.280001 ,  181.800001 )
# log runtime: 176.52  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run8/mobility_trace.txt
# time to read file:  0.0027399063110351562
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  30%|███████████████████████████████████████████████████████████████████████▍                                                                                                                                                                      | 3/10 [00:05<00:12,  1.77s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[52 52 17 17]
#  [46 46 17 17]
#  [52  0 17 17]
#  [40  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlTxPhyStats.txt
# time to read file:  0.005606174468994141
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.512 ,  200.883 )
# log runtime: 200.371  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlRxPhyStats.txt
# time to read file:  0.007357120513916016
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.513 ,  200.813 )
# log runtime: 200.29999999999998  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlSinrStats.txt
# time to read file:  0.011726617813110352
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.042 )
# log runtime: 200.761  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlPdcpStats.txt
# time to read file:  0.006025791168212891
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlRsrpSinrStats.txt
# time to read file:  0.009785652160644531
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlRlcStats.txt
# time to read file:  0.004221916198730469
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlMacStats.txt
# time to read file:  0.007869720458984375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.507 ,  200.807 )
# log runtime: 200.29999999999998  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/UlTxPhyStats.txt
# time to read file:  0.008749008178710938
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.513 ,  200.813 )
# log runtime: 200.29999999999998  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlPdcpStats.txt
# time to read file:  0.004656791687011719
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlRlcStats.txt
# time to read file:  0.0036797523498535156
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlRxPhyStats.txt
# time to read file:  0.006580352783203125
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.512 ,  200.883 )
# log runtime: 200.371  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/DlMacStats.txt
# time to read file:  0.005675077438354492
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.51 ,  200.881 )
# log runtime: 200.371  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/rtt_trace.txt
# time to read file:  0.004646778106689453
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.522999 ,  200.816999 )
# log runtime: 200.294  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/delay_trace.txt
# time to read file:  0.007817745208740234
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.512999 ,  200.883999 )
# log runtime: 200.37099999999998  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.9825
# 2    0.9980
# 3    0.9015
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.0010
# 2    1.0010
# 3    1.0005
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/handover_trace.txt
# time to read file:  0.0017838478088378906
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 11.560001 ,  190.200001 )
# log runtime: 178.64  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run5/mobility_trace.txt
# time to read file:  0.0023801326751708984
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  40%|███████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                              | 4/10 [00:07<00:10,  1.75s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[50 50 16 16]
#  [47 47 16 17]
#  [50  0 16 16]
#  [41  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlTxPhyStats.txt
# time to read file:  0.005712985992431641
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.598 ,  200.554 )
# log runtime: 199.956  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlRxPhyStats.txt
# time to read file:  0.007213115692138672
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.528 ,  200.84 )
# log runtime: 200.312  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlSinrStats.txt
# time to read file:  0.004919290542602539
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.043 )
# log runtime: 200.762  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlPdcpStats.txt
# time to read file:  0.004625797271728516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlRsrpSinrStats.txt
# time to read file:  0.007385969161987305
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlRlcStats.txt
# time to read file:  0.004502773284912109
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlMacStats.txt
# time to read file:  0.006545066833496094
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.522 ,  200.834 )
# log runtime: 200.312  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/UlTxPhyStats.txt
# time to read file:  0.007471323013305664
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.528 ,  200.84 )
# log runtime: 200.312  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlPdcpStats.txt
# time to read file:  0.0045545101165771484
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlRlcStats.txt
# time to read file:  0.0036802291870117188
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlRxPhyStats.txt
# time to read file:  0.005655050277709961
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.598 ,  200.554 )
# log runtime: 199.956  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/DlMacStats.txt
# time to read file:  0.005939006805419922
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.596 ,  200.552 )
# log runtime: 199.956  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/rtt_trace.txt
# time to read file:  0.0043487548828125
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.604999 ,  200.553999 )
# log runtime: 199.949  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/delay_trace.txt
# time to read file:  0.007319450378417969
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.528931 ,  200.840931 )
# log runtime: 200.312  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    1.0005
# 2    0.9965
# 3    0.9985
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/handover_trace.txt
# time to read file:  0.0016989707946777344
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 4.360001 ,  187.920001 )
# log runtime: 183.56  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run7/mobility_trace.txt
# time to read file:  0.0024259090423583984
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  50%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                       | 5/10 [00:08<00:08,  1.77s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[52 52 17 17]
#  [49 49 17 17]
#  [52  0 17 17]
#  [49  0 17 17]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlTxPhyStats.txt
# time to read file:  0.005871295928955078
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.579 ,  200.836 )
# log runtime: 200.257  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlRxPhyStats.txt
# time to read file:  0.009911060333251953
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.576 ,  200.899 )
# log runtime: 200.323  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlSinrStats.txt
# time to read file:  0.006014347076416016
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.042 )
# log runtime: 200.761  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlPdcpStats.txt
# time to read file:  0.0043697357177734375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlRsrpSinrStats.txt
# time to read file:  0.007243156433105469
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlRlcStats.txt
# time to read file:  0.004237651824951172
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlMacStats.txt
# time to read file:  0.009305238723754883
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.57 ,  200.893 )
# log runtime: 200.323  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/UlTxPhyStats.txt
# time to read file:  0.014424562454223633
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.576 ,  200.899 )
# log runtime: 200.323  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlPdcpStats.txt
# time to read file:  0.0060994625091552734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlRlcStats.txt
# time to read file:  0.005043745040893555
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlRxPhyStats.txt
# time to read file:  0.007125377655029297
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.579 ,  200.836 )
# log runtime: 200.257  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/DlMacStats.txt
# time to read file:  0.007065534591674805
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.577 ,  200.834 )
# log runtime: 200.257  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/rtt_trace.txt
# time to read file:  0.005499362945556641
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.579999 ,  200.836999 )
# log runtime: 200.257  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/delay_trace.txt
# time to read file:  0.007869720458984375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.693931 ,  200.899931 )
# log runtime: 200.20600000000002  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.967
# 2    0.984
# 3    0.874
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.000
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/handover_trace.txt
# time to read file:  0.0013892650604248047
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 10.960001 ,  182.280001 )
# log runtime: 171.32  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run10/mobility_trace.txt
# time to read file:  0.0031270980834960938
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  60%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                               | 6/10 [00:10<00:07,  1.79s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[51 51 16 16]
#  [34 34 16 17]
#  [51  0 16 16]
#  [33  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlTxPhyStats.txt
# time to read file:  0.006606578826904297
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.584 ,  200.828 )
# log runtime: 200.244  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlRxPhyStats.txt
# time to read file:  0.007935047149658203
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.645 ,  200.825 )
# log runtime: 200.17999999999998  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlSinrStats.txt
# time to read file:  0.005557537078857422
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.046 )
# log runtime: 200.765  seconds
# /tmp/ipykernel_181174/2047489452.py:111: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig_delay, axs_delay = plt.subplots(len(ts_plot_IMSIs),1,figsize=(20,(len(ts_plot_IMSIs)*3)), constrained_layout = True)
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlPdcpStats.txt
# time to read file:  0.004471540451049805
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlRsrpSinrStats.txt
# time to read file:  0.006852865219116211
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlRlcStats.txt
# time to read file:  0.004086732864379883
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlMacStats.txt
# time to read file:  0.006255149841308594
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.639 ,  200.819 )
# log runtime: 200.17999999999998  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/UlTxPhyStats.txt
# time to read file:  0.0075991153717041016
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.645 ,  200.825 )
# log runtime: 200.17999999999998  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlPdcpStats.txt
# time to read file:  0.0043294429779052734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlRlcStats.txt
# time to read file:  0.0043871402740478516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlRxPhyStats.txt
# time to read file:  0.0059511661529541016
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.584 ,  200.828 )
# log runtime: 200.244  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/DlMacStats.txt
# time to read file:  0.005574703216552734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.582 ,  200.826 )
# log runtime: 200.244  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/rtt_trace.txt
# time to read file:  0.004347562789916992
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.728999 ,  200.828999 )
# log runtime: 200.10000000000002  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/delay_trace.txt
# time to read file:  0.007346391677856445
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.584999 ,  200.740931 )
# log runtime: 200.15593199999998  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.8115
# 2    0.9950
# 3    1.0010
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/handover_trace.txt
# time to read file:  0.001811981201171875
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 16.440001 ,  148.400001 )
# log runtime: 131.96  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run9/mobility_trace.txt
# time to read file:  0.0024580955505371094
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  70%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                       | 7/10 [00:12<00:05,  1.78s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[50 50 16 16]
#  [41 41 16 17]
#  [50  0 16 16]
#  [41  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlTxPhyStats.txt
# time to read file:  0.006211042404174805
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.627 ,  200.785 )
# log runtime: 200.158  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlRxPhyStats.txt
# time to read file:  0.006766557693481445
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.665 ,  200.794 )
# log runtime: 200.12900000000002  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlSinrStats.txt
# time to read file:  0.0052721500396728516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.043 )
# log runtime: 200.762  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlPdcpStats.txt
# time to read file:  0.0044667720794677734
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlRsrpSinrStats.txt
# time to read file:  0.006999969482421875
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlRlcStats.txt
# time to read file:  0.004103183746337891
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlMacStats.txt
# time to read file:  0.0063860416412353516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.659 ,  200.788 )
# log runtime: 200.12900000000002  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/UlTxPhyStats.txt
# time to read file:  0.006999015808105469
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.665 ,  200.794 )
# log runtime: 200.12900000000002  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlPdcpStats.txt
# time to read file:  0.0046596527099609375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlRlcStats.txt
# time to read file:  0.003987312316894531
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlRxPhyStats.txt
# time to read file:  0.006068706512451172
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.627 ,  200.785 )
# log runtime: 200.158  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/DlMacStats.txt
# time to read file:  0.006204366683959961
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.625 ,  200.783 )
# log runtime: 200.158  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/rtt_trace.txt
# time to read file:  0.004244327545166016
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.757999 ,  200.667999 )
# log runtime: 199.91  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/delay_trace.txt
# time to read file:  0.008723735809326172
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.627999 ,  200.794931 )
# log runtime: 200.166932  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.9415
# 2    0.9980
# 3    0.9095
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.0000
# 2    1.0005
# 3    1.0010
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/handover_trace.txt
# time to read file:  0.0014269351959228516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 4.400001 ,  199.680001 )
# log runtime: 195.28  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run1/mobility_trace.txt
# time to read file:  0.0025131702423095703
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                               | 8/10 [00:14<00:03,  1.82s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[51 51 16 16]
#  [38 38 16 17]
#  [51  0 16 16]
#  [37  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlTxPhyStats.txt
# time to read file:  0.0057141780853271484
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.696 ,  200.724 )
# log runtime: 200.028  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlRxPhyStats.txt
# time to read file:  0.00914311408996582
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.606 ,  200.764 )
# log runtime: 200.15800000000002  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlSinrStats.txt
# time to read file:  0.006439208984375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.042 )
# log runtime: 200.761  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlPdcpStats.txt
# time to read file:  0.00490570068359375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlRsrpSinrStats.txt
# time to read file:  0.007614850997924805
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlRlcStats.txt
# time to read file:  0.0043087005615234375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlMacStats.txt
# time to read file:  0.010051250457763672
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.6 ,  200.758 )
# log runtime: 200.15800000000002  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/UlTxPhyStats.txt
# time to read file:  0.010445117950439453
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.606 ,  200.764 )
# log runtime: 200.15800000000002  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlPdcpStats.txt
# time to read file:  0.0057582855224609375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlRlcStats.txt
# time to read file:  0.004450798034667969
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlRxPhyStats.txt
# time to read file:  0.006836414337158203
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.696 ,  200.724 )
# log runtime: 200.028  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/DlMacStats.txt
# time to read file:  0.006530284881591797
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.694 ,  200.722 )
# log runtime: 200.02800000000002  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/rtt_trace.txt
# time to read file:  0.0044023990631103516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.696999 ,  200.645999 )
# log runtime: 199.94899999999998  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/delay_trace.txt
# time to read file:  0.008495330810546875
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.606931 ,  200.764931 )
# log runtime: 200.158  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    0.9980
# 2    0.9310
# 3    0.9815
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/handover_trace.txt
# time to read file:  0.001522064208984375
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 6.640001 ,  200.440001 )
# log runtime: 193.79999999999998  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run4/mobility_trace.txt
# time to read file:  0.0030655860900878906
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                       | 9/10 [00:16<00:01,  1.83s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[52 52 16 16]
#  [41 41 16 17]
#  [52  0 16 16]
#  [41  0 16 16]]
# ============================================================
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2
# ============================================================
# --------------------------------------------
# DlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlTxPhyStats.txt
# time to read file:  0.006018638610839844
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.513 ,  200.61 )
# log runtime: 200.097  seconds
# --------------------------------------------
# UlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlRxPhyStats.txt
# time to read file:  0.013032674789428711
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.633 ,  200.806 )
# log runtime: 200.173  seconds
# --------------------------------------------
# UlSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlSinrStats.txt
# time to read file:  0.006512641906738281
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.281 ,  201.045 )
# log runtime: 200.76399999999998  seconds
# --------------------------------------------
# UlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlPdcpStats.txt
# time to read file:  0.005956411361694336
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# DlRsrpSinrStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlRsrpSinrStats.txt
# time to read file:  0.009379148483276367
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.239214 ,  201.04 )
# log runtime: 200.800786  seconds
# --------------------------------------------
# UlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlRlcStats.txt
# time to read file:  0.004591464996337891
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.75 )
# log runtime: 200.25  seconds
# --------------------------------------------
# UlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlMacStats.txt
# time to read file:  0.006029605865478516
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.627 ,  200.8 )
# log runtime: 200.173  seconds
# --------------------------------------------
# UlTxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/UlTxPhyStats.txt
# time to read file:  0.006210803985595703
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.633 ,  200.806 )
# log runtime: 200.173  seconds
# --------------------------------------------
# DlPdcpStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlPdcpStats.txt
# time to read file:  0.004855632781982422
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRlcStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlRlcStats.txt
# time to read file:  0.00411534309387207
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  200.5 )
# log runtime: 200.0  seconds
# --------------------------------------------
# DlRxPhyStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlRxPhyStats.txt
# time to read file:  0.006428956985473633
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.513 ,  200.61 )
# log runtime: 200.097  seconds
# --------------------------------------------
# DlMacStats.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/DlMacStats.txt
# time to read file:  0.006575822830200195
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.511 ,  200.608 )
# log runtime: 200.097  seconds
# --------------------------------------------
# rtt_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/rtt_trace.txt
# time to read file:  0.004442930221557617
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.636999 ,  200.566999 )
# log runtime: 199.93  seconds
# --------------------------------------------
# delay_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/delay_trace.txt
# time to read file:  0.007239818572998047
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.513999 ,  200.806931 )
# log runtime: 200.29293199999998  seconds
# UL # delay probe delivery rate per UE:  IMSI
# 1    1.0010
# 2    0.9605
# 3    0.9970
# dtype: float64
# DL # delay probes delivery rate per UE:  IMSI
# 1    1.001
# 2    1.001
# 3    1.001
# dtype: float64
# --------------------------------------------
# handover_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/handover_trace.txt
# time to read file:  0.0017077922821044922
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 2.320001 ,  197.240001 )
# log runtime: 194.92000000000002  seconds
# --------------------------------------------
# mobility_trace.txt
# ../../data_volume/lte_3macro_3Ue_delay_rtt_UMi_ISD200m_BSgain12/run2/mobility_trace.txt
# time to read file:  0.002364635467529297
# ueIds: min: 1 max: 3 count: 3
# log time (start, end): ( 0.5 ,  201.0 )
# log runtime: 200.5  seconds
# ===========================================================================================
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:17<00:00,  1.79s/it]
# ===========================================================================================
# Byte Matrix in MB
#   X  phy mac rlc pdcp
# dlTx  x   x   x   x
# ulTx  x   x   x   x
# dlRx  x   x   x   x
# ulRx  x   x   x   x
# [[52 52 17 17]
#  [48 48 16 17]
#  [52  0 17 17]
#  [48  0 16 16]]
# ============================================================

# %%
#=======================================
# Print summary statistics   
#=======================================  
if 'delay_trace.txt' in files: 
    print('--------------------------------------------')
    print("UL delay probe delivery rate: ", ul_delay_probe_delivery_rate/(10*sim_time*total_num_ues*num_runs))
    print("DL delay probe delivery rate: ", dl_delay_probe_delivery_rate/(10*sim_time*total_num_ues*num_runs))
    print('--------------------------------------------')
    print("Summary stats: ul_delays")
    print(pd.Series(ul_delays).describe())
    print('0.95 quantile: ', np.nanquantile(ul_delays,0.95))
    print('0.97 quantile: ', np.nanquantile(ul_delays,0.97))
    print('0.99 quantile: ', np.nanquantile(ul_delays,0.99))
    print('--------------------------------------------')
    print("Summary stats: dl_delays")
    print(pd.Series(dl_delays).describe())
    print('0.95 quantile: ', np.nanquantile(dl_delays,0.95))
    print('0.97 quantile: ', np.nanquantile(dl_delays,0.97))
    print('0.99 quantile: ', np.nanquantile(dl_delays,0.99))
if 'rtt_trace.txt' in files:
    print('--------------------------------------------')
    print("RTT probe delivery rate: ", rtt_probe_delivery_rate/(10*sim_time*total_num_ues*num_runs))
    print('--------------------------------------------')
    print("Summary stats: rtt_delays")
    print(pd.Series(rtt_delays).describe())
    print('0.95 quantile: ', np.nanquantile(rtt_delays,0.95))
    print('0.97 quantile: ', np.nanquantile(rtt_delays,0.97))
    print('0.99 quantile: ', np.nanquantile(rtt_delays,0.99))
    
if 'ulThroughput_trace.txt' in files:
    print('--------------------------------------------')
    print("UL survey average thoughput (Mbps): ", ul_avg_thput*8/(sim_time*num_runs))
    print('--------------------------------------------')
    print("Summary stats: ul_thput (Mbps)")
    print(pd.Series(ul_thput).describe())
    print('0.95 quantile: ', np.nanquantile(ul_thput,0.95))
    print('0.97 quantile: ', np.nanquantile(ul_thput,0.97))
    print('0.99 quantile: ', np.nanquantile(ul_thput,0.99))
if 'dlThroughput_trace.txt' in files:
    print('--------------------------------------------')
    print("DL survey average thoughput (Mbps): ", dl_avg_thput*8/(sim_time*num_runs))
    print('--------------------------------------------')
    print("Summary stats: dl_thput (Mbps)")
    print(pd.Series(dl_thput).describe())
    print('0.95 quantile: ', np.nanquantile(dl_thput,0.95))
    print('0.97 quantile: ', np.nanquantile(dl_thput,0.97))
    print('0.99 quantile: ', np.nanquantile(dl_thput,0.99))
if 'handover_trace.txt' in files:
    print('--------------------------------------------')
    print('Number of handover per cell every 100 s: ', hos_per_cell_per_time*100/(total_num_cells*sim_time*num_runs))
    print('--------------------------------------------')
    print("Summary stats: time bw handovers (seconds)")
    print(pd.Series(time_bw_hos).describe())
    print('0.95 quantile: ', np.nanquantile(time_bw_hos,0.95))
# Out:
# --------------------------------------------
# UL delay probe delivery rate:  0.9657833333333333
# DL delay probe delivery rate:  1.00085
# --------------------------------------------
# Summary stats: ul_delays
# count    57887.000000
# mean       154.407686
# std       1303.824573
# min          4.932000
# 25%         11.931000
# 50%         11.931000
# 75%         11.931000
# max      33497.931000
# dtype: float64
# 0.95 quantile:  19.931
# 0.97 quantile:  372.03157999999127
# 0.99 quantile:  4084.052719999995
# --------------------------------------------
# Summary stats: dl_delays
# count    59991.000000
# mean         4.017253
# std          0.347232
# min          3.999000
# 25%          3.999000
# 50%          3.999000
# 75%          3.999000
# max         10.999000
# dtype: float64
# 0.95 quantile:  3.999
# 0.97 quantile:  3.999
# 0.99 quantile:  3.999
# --------------------------------------------
# RTT probe delivery rate:  0.9624333333333334
# --------------------------------------------
# Summary stats: rtt_delays
# count    57686.000000
# mean       159.970241
# std       1319.122636
# min          7.999000
# 25%         14.999000
# 50%         14.999000
# 75%         14.999000
# max      33526.999000
# dtype: float64
# 0.95 quantile:  22.999
# 0.97 quantile:  398.4489999999971
# 0.99 quantile:  4125.349000000013
# --------------------------------------------
# Number of handover per cell every 100 s:  7.166666666666667
# --------------------------------------------
# Summary stats: time bw handovers (seconds)
# count    340.000000
# mean       9.850588
# std       17.877149
# min        0.280000
# 25%        1.160000
# 50%        3.080000
# 75%        9.540000
# max      121.720000
# dtype: float64
# 0.95 quantile:  44.99200000000003

# %%
#=======================================
# Plot histograms   
#=======================================
# for metrics related to delay we are removing outliers using the 99th percentile value so that we can 
# get a better view of what is happenning in the data

if histogram_plots:
    if ('delay_trace.txt' in files):
        plot_histogram(ul_delays, 'red', 'UL delay (ms)', 'hist_ul_delays.png', plot_dir)
        plot_histogram(dl_delays, 'blue', 'DL delay (ms)', 'hist_dl_delays.png', plot_dir)
    if ('rtt_trace.txt' in files):
        plot_histogram(rtt_delays, 'violet', 'RTT delay (ms)', 'hist_rtt_delays.png', plot_dir)
    if ('ulThroughput_trace.txt' in files):
        plot_histogram(ul_thput, 'red', 'UL thput (Mbps)', 'hist_ul_thput.png', plot_dir)
    if ('dlThroughput_trace.txt' in files):
        plot_histogram(dl_thput, 'blue', 'DL thput (Mbps)', 'hist_dl_thput.png', plot_dir)
    if ('handover_trace.txt' in files):
        plot_histogram(time_bw_hos, 'green', 'Time b/w handovers (s)', 'hist_time_bw_hos.png', plot_dir)
    if ('httpClientRtt_trace.txt' in files):
        plot_histogram(page_load_time, 'green', 'Page load time for webpages (ms)', 'hist_page_load_time.png', plot_dir)
    if ('httpClientRtt_trace.txt' in files):
        plot_histogram(webpage_size, 'green', 'Webpage size (B)', 'hist_webpage_size.png', plot_dir)
    if ('dashClient_trace.txt' in files): 
        plot_histogram(segment_bitrate, 'green', 'Video segment bitrate', 'hist_segment_bitrate.png', plot_dir)
    if ('vrFragment_trace.txt' in files): 
        plot_histogram(vr_burst_time, 'green', 'VR time to send packet burst (ms)', 'hist_vr_burst_time.png', plot_dir)
    if ('UlMacStats.txt' in files):
        plot_histogram(cell_ul_thput, 'red', 'Cell UL throughput (Mbps)', 'hist_cell_ul_thput.png', plot_dir)
    if ('DlMacStats.txt' in files): 
        plot_histogram(cell_dl_thput, 'blue', 'Cell DL throughput (Mbps)', 'hist_cell_dl_thput.png', plot_dir)
    if ('DlRsrpSinrStats.txt' in files):
        plot_histogram(10*np.log10(dl_sinr), 'blue', 'DL SINR (dB)', 'hist_dl_sinr.png', plot_dir)
        #plot_histogram(10*np.log10(dl_rsrp), 'blue', 'DL RSRP (dB)', 'hist_dl_rsrp.png', plot_dir)
    if ('UlSinrStats.txt' in files):
        plot_histogram(10*np.log10(ul_sinr), 'red', 'UL SINR (dB)', 'hist_ul_sinr.png', plot_dir)
    if ('UlMacStats.txt' in files): 
        plot_histogram(ul_mcs, 'red', 'UL MCS', 'hist_ul_mcs.png', plot_dir)
    if ('DlMacStats.txt' in files): 
        plot_histogram(dl_mcs, 'blue', 'DL MCS', 'hist_dl_mcs.png', plot_dir)
        
        
#=======================================
# Plot metrics vs UE-BS distance   
#======================================= 
if distance_plots:
    #print('Each plot with sample size: ', w_dist_to_cell.size)
    if ('delay_trace.txt' in files):
        plot_metric_vs_distance_to_cell(w_dist_to_cell, w_ul_delays, 'red', 'UL delay (ms)', 'dist_vs_ul_delay.png', plot_dir)
        plot_metric_vs_distance_to_cell(w_dist_to_cell, w_dl_delays, 'blue', 'DL delay (ms)', 'dist_vs_dl_delay.png', plot_dir)
    #if ('rtt_trace.txt' in files):       
        #plot_metric_vs_distance_to_cell(w_dist_to_cell, w_rtt_delays, 'violet', 'RTT delay (ms)', 'dist_vs_rtt_delay.png', plot_dir)
    if ('ulThroughput_trace.txt' in files):
        #for a single user since only one user measures throughput
        imsi=1  
        imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        imsi_sliced_y = ul_thput[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'red', 'UL throughput (Mbps)', 'dist_vs_ul_thput.png', plot_dir)
        #plot_metric_vs_distance_to_cell(w_dist_to_cell, ul_thput, 'red', 'UL throughput (Mbps)', 'dist_vs_ul_thput.png', plot_dir)
    if ('dlThroughput_trace.txt' in files):
        #for a single user since only one user measures throughput
        imsi=1  
        imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        imsi_sliced_y = dl_thput[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'blue', 'DL throughput (Mbps)', 'dist_vs_dl_thput.png', plot_dir)
        #plot_metric_vs_distance_to_cell(w_dist_to_cell, dl_thput, 'blue', 'DL throughput (Mbps)', 'dist_vs_dl_thput.png', plot_dir)
    if ('UlSinrStats.txt' in files):       
        plot_metric_vs_distance_to_cell(w_dist_to_cell, 10*np.log10(w_ul_sinr), 'red', 'UL SINR (dB)', 'dist_vs_ul_sinr.png', plot_dir)
        # for a single user 
        #imsi=1  
        #imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #imsi_sliced_y = 10*np.log10(w_ul_sinr[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ])
        #plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'red', 'UL SINR (dB)', 'dist_vs_ul_sinr.png', plot_dir)
    if ('DlRsrpSinrStats.txt' in files):  
        plot_metric_vs_distance_to_cell(w_dist_to_cell, 10*np.log10(w_dl_sinr), 'blue', 'DL SINR (dB)', 'dist_vs_dl_sinr.png', plot_dir)
        #imsi=1  
        #imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #imsi_sliced_y = 10*np.log10(w_dl_sinr[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ])
        #plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'blue', 'DL SINR (dB)', 'dist_vs_dl_sinr.png', plot_dir)
    if ('UlMacStats.txt' in files):
        plot_metric_vs_distance_to_cell(w_dist_to_cell, w_ul_mcs, 'red', 'UL MCS', 'dist_vs_ul_mcs.png', plot_dir)
        #imsi=1  
        #imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #imsi_sliced_y = w_ul_mcs[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'red', 'UL MCS', 'dist_vs_ul_mcs.png', plot_dir)
    if ('DlMacStats.txt' in files):
        plot_metric_vs_distance_to_cell(w_dist_to_cell, w_dl_mcs, 'blue', 'DL MCS', 'dist_vs_dl_mcs.png', plot_dir)
        #imsi=1  
        #imsi_sliced_x = w_dist_to_cell[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #imsi_sliced_y = w_dl_mcs[int((imsi-1)*(sim_time*1000/time_wind_val)) : int(imsi*(sim_time*1000/time_wind_val)-1)  ]
        #plot_metric_vs_distance_to_cell(imsi_sliced_x, imsi_sliced_y, 'blue', 'DL MCS', 'dist_vs_dl_mcs.png', plot_dir)
        
            
print('DONE')
#wandb.finish
# Out:
# DONE

# %%
import os
os.system('cp parse_visualize_data.ipynb '+'./saved_notebooks/'+data_dir.split('/')[-2]+'.ipynb')
# Out:
# 0
