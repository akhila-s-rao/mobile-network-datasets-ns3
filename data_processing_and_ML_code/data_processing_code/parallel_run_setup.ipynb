# %%
from multiprocessing import Pool
import subprocess

# %%
# start one single run 
def setup_run(rand_index):
    data_dir="../../data_volume/logsT"
    
    cmd_args=("cellular-network-user "
    +"--scenario=UMi "
    +"--numRings=0 "
    +"--ueNumPerMacroGnb=5 "
    +"--useMicroLayer=true "
    +"--numMicroCells=3 "
    +"--ueNumPerMicroGnb=10 "
    +"--appGenerationTime=100 "
    +"--rat=LTE "
    +"--operationMode=FDD "
    +"--handoverAlgo=A2A4Rsrq "
    +"--enableUlPc=true "
    +"--appDlThput=false "
    +"--appUlThput=false "
    +"--appHttp=true "
    +"--appDash=true "
    +"--appVr=true "
    +"--numMacroVrUes=1 "
    +"--numMicroVrUes=3 "
    +"--freqScenario=1 "
    +"--randomSeed="+str(rand_index))
    
    run_dir="run"+str(rand_index+1)  
    result = subprocess.run(['mkdir', data_dir+'/'+run_dir], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print(result.stderr)
    print(result.stdout)
    #print('Starting run ', rand_index+1)
    result = subprocess.run(['cd ../ns-3-dev; ./waf --run-no-build '+'"'+cmd_args+'"'+ 
                             ' --cwd='+data_dir+'/'+run_dir+' > '+data_dir+'/'+run_dir+'/'+'simulation_info.txt'], 
                            stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, shell=True)
    print('Finished run ', rand_index+1)
    print(result.stderr)
    print(result.stdout)
    #sleep 2

# %%
runs=70
run_script_loc="../ns-3-dev/src/nr/examples/dataset_gen_scripts"
script_save_dir_name="scripts_used_to_gen_this_data"
data_dir="../../data_volume/logsT"
result = subprocess.run(['mkdir', data_dir], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print(result.stderr)
print(result.stdout)
result = subprocess.run(['echo', "Saving all scripts and code used for this set of simulation runs in", data_dir], 
                        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print(result.stderr)
print(result.stdout)
result = subprocess.run(['mkdir', data_dir+'/'+script_save_dir_name], 
                        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print(result.stderr)
print(result.stdout)
print(run_script_loc+'/*')
print(data_dir+'/'+script_save_dir_name+'/.')
result = subprocess.run(['cp -r '+run_script_loc+'/* '+data_dir+'/'+script_save_dir_name+'/.'], 
                        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, shell=True)
print(result.stderr)
print(result.stdout)

#setup_run(0)
pool = Pool(processes=20)
outputs = pool.map(setup_run, range(0,runs))
# Out:
# Saving all scripts and code used for this set of simulation runs in ../../data_volume/logsT
#
#
#
# ../ns-3-dev/src/nr/examples/dataset_gen_scripts/*
# ../../data_volume/logsT/scripts_used_to_gen_this_data/.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Finished run  13
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=12'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
#
#
#
#
# Finished run  5
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=4'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
#
#
#
#
# Finished run  8
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=7'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
#
#
#
#
# Finished run  6
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=5'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
#
#
#
#
# Finished run  19
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=18'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
#
#
#
#
# Finished run  24
# Command ['/home/ubuntu/mobile-network-datasets-ns3/ns-3-dev/build/src/nr/examples/ns3.35-cellular-network-user-optimized', '--scenario=UMi', '--numRings=0', '--ueNumPerMacroGnb=5', '--useMicroLayer=true', '--numMicroCells=3', '--ueNumPerMicroGnb=10', '--appGenerationTime=1000', '--rat=LTE', '--operationMode=FDD', '--handoverAlgo=A2A4Rsrq', '--enableUlPc=true', '--appDlThput=false', '--appUlThput=false', '--appHttp=true', '--appDash=true', '--appVr=true', '--numMacroVrUes=1', '--numMicroVrUes=3', '--freqScenario=1', '--randomSeed=23'] terminated with signal SIGSEGV. Run it under a debugger to get more information (./waf --run <program> --gdb").
