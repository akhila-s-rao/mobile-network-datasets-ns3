# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='vime', 
             pt_folder='FP3_only_traffic_rows')
# Out:
# Run with random seed:  420
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  3.1767117977142334
# Loaded run 1
# Time to read csv file for run:  3.1122801303863525
# Loaded run 2
# Time to read csv file for run:  3.1512675285339355
# Loaded run 3
# Time to read csv file for run:  3.082045555114746
# Loaded run 4
# Time to read csv file for run:  3.0678374767303467
# Loaded run 5
# Time to read csv file for run:  2.964858293533325
# Loaded run 6
# Time to read csv file for run:  2.9697444438934326
# Loaded run 7
# Time to read csv file for run:  3.1680908203125
# Loaded run 8
# Time to read csv file for run:  3.3719279766082764
# Loaded run 9
# Time to read csv file for run:  3.1789608001708984
# Loaded run 10
# Seed set to 42
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33012, 102)
# X_pretrain  (32691, 92)
# refresh rate:  10
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                        | Type    | Params | Mode
# ----------------------------------------------------------------
# 0 | task_loss_fn                | MSELoss | 0      | train
# 1 | mask_loss_fn                | BCELoss | 0      | train
# 2 | categorical_feature_loss_fn | BCELoss | 0      | train
# 3 | continuous_feature_loss_fn  | MSELoss | 0      | train
# 4 | consistency_loss_fn         | MSELoss | 0      | train
# 5 | model                       | VIME    | 278 K  | train
# ----------------------------------------------------------------
# 278 K     Trainable params
# 0         Non-trainable params
# 278 K     Total params
# 1.113     Total estimated model params size (MB)
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.12it/s, v_num=4]
# Epoch 1: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.00it/s, v_num=4, train_loss=3.880, val_loss=3.370]
# Epoch 2: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.21it/s, v_num=4, train_loss=3.340, val_loss=3.220]
# Epoch 3: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.32it/s, v_num=4, train_loss=3.290, val_loss=3.150]
# Epoch 4: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.00it/s, v_num=4, train_loss=3.180, val_loss=3.110]
# Epoch 5: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.82it/s, v_num=4, train_loss=3.160, val_loss=3.080]
# Epoch 6: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.53it/s, v_num=4, train_loss=3.120, val_loss=3.060]
# Epoch 7: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.44it/s, v_num=4, train_loss=3.100, val_loss=3.040]
# Epoch 8: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.72it/s, v_num=4, train_loss=3.080, val_loss=3.040]
# Epoch 9: 100%|█████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.31it/s, v_num=4, train_loss=3.070, val_loss=3.020]
# Epoch 10: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.27it/s, v_num=4, train_loss=3.060, val_loss=3.010]
# Epoch 11: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 73.83it/s, v_num=4, train_loss=3.050, val_loss=3.000]
# Epoch 12: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.84it/s, v_num=4, train_loss=3.040, val_loss=3.000]
# Epoch 13: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.49it/s, v_num=4, train_loss=3.050, val_loss=2.990]
# Epoch 14: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.23it/s, v_num=4, train_loss=3.030, val_loss=2.990]
# Epoch 15: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.97it/s, v_num=4, train_loss=3.030, val_loss=2.990]
# Epoch 16: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.69it/s, v_num=4, train_loss=3.040, val_loss=2.980]
# Epoch 17: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.96it/s, v_num=4, train_loss=3.020, val_loss=2.980]
# Epoch 18: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.00it/s, v_num=4, train_loss=3.020, val_loss=2.980]
# Epoch 19: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.14it/s, v_num=4, train_loss=3.020, val_loss=2.970]
# Epoch 20: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.48it/s, v_num=4, train_loss=3.010, val_loss=2.970]
# Epoch 21: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.97it/s, v_num=4, train_loss=3.020, val_loss=2.970]
# Epoch 22: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.89it/s, v_num=4, train_loss=3.000, val_loss=2.970]
# Epoch 23: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.76it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 24: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.06it/s, v_num=4, train_loss=3.000, val_loss=2.970]
# Epoch 25: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.84it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 26: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.56it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 27: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.67it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 28: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.31it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 29: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.64it/s, v_num=4, train_loss=3.000, val_loss=2.960]
# Epoch 30: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.86it/s, v_num=4, train_loss=2.990, val_loss=2.960]
# Epoch 31: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.70it/s, v_num=4, train_loss=2.990, val_loss=2.960]
# Epoch 32: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.36it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 33: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.95it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 34: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.93it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 35: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.76it/s, v_num=4, train_loss=2.990, val_loss=2.960]
# Epoch 36: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.21it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 37: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.14it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 38: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.19it/s, v_num=4, train_loss=2.990, val_loss=2.950]
# Epoch 39: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.58it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 40: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 65.96it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 41: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.64it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 42: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.15it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 43: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.90it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 44: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.35it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 45: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.17it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 46: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.45it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 47: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.33it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 48: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.83it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 49: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.53it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 50: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.16it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 51: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.40it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 52: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.67it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 53: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.65it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 54: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.13it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 55: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.36it/s, v_num=4, train_loss=2.980, val_loss=2.950]
# Epoch 56: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.82it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 57: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.32it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 58: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.00it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 59: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.50it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 60: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.85it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 61: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.22it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 62: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.14it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 63: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 65.64it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 64: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 73.70it/s, v_num=4, train_loss=2.980, val_loss=2.940]
# Epoch 65: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.71it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 66: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.71it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 67: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.32it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 68: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.60it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 69: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.61it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 70: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.98it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 71: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.70it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 72: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 73.38it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 73: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 66.84it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 74: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.01it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 75: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.28it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 76: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.68it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 77: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.84it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 78: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.53it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 79: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.38it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 80: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.38it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 81: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.11it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 82: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.30it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 83: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.21it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 84: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.14it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 85: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 69.26it/s, v_num=4, train_loss=2.970, val_loss=2.940]
# Epoch 86: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.67it/s, v_num=4, train_loss=2.980, val_loss=2.930]
# Epoch 87: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.74it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 88: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.17it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 89: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.54it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 90: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.68it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 91: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.17it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 92: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 72.49it/s, v_num=4, train_loss=2.960, val_loss=2.940]
# Epoch 93: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.79it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 94: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 71.16it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# Epoch 95: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 75.65it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 96: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 70.76it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 97: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 67.65it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 98: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 73.61it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 99: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 68.17it/s, v_num=4, train_loss=2.960, val_loss=2.930]
# Epoch 99: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 59.40it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|████████████████████████████████████████████████| 232/232 [00:03<00:00, 58.96it/s, v_num=4, train_loss=2.970, val_loss=2.930]
# DONE SAVING PRETRAINED MODEL
#    | Name                                         | Type                 | Params | Mode
# -----------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                 | MSELoss              | 0      | train
# 1  | mask_loss_fn                                 | BCELoss              | 0      | train
# 2  | categorical_feature_loss_fn                  | BCELoss              | 0      | train
# 3  | continuous_feature_loss_fn                   | MSELoss              | 0      | train
# 4  | consistency_loss_fn                          | MSELoss              | 0      | train
# 5  | model                                        | VIME                 | 278 K  | train
# 6  | model._VIME__encoder                         | VIMESelfSupervised   | 177 K  | train
# 7  | model._VIME__encoder.encoder                 | MLP                  | 140 K  | train
# 8  | model._VIME__encoder.encoder.linear_0        | Linear               | 18.6 K | train
# 9  | model._VIME__encoder.encoder.batchnorm_0     | BatchNorm1d          | 400    | train
# 10 | model._VIME__encoder.encoder.relu_0          | ReLU                 | 0      | train
# 11 | model._VIME__encoder.encoder.dropout_0       | Dropout              | 0      | train
# 12 | model._VIME__encoder.encoder.linear_1        | Linear               | 40.2 K | train
# 13 | model._VIME__encoder.encoder.batchnorm_1     | BatchNorm1d          | 400    | train
# 14 | model._VIME__encoder.encoder.relu_1          | ReLU                 | 0      | train
# 15 | model._VIME__encoder.encoder.dropout_1       | Dropout              | 0      | train
# 16 | model._VIME__encoder.encoder.linear_2        | Linear               | 40.2 K | train
# 17 | model._VIME__encoder.encoder.batchnorm_2     | BatchNorm1d          | 400    | train
# 18 | model._VIME__encoder.encoder.relu_2          | ReLU                 | 0      | train
# 19 | model._VIME__encoder.encoder.dropout_2       | Dropout              | 0      | train
# 20 | model._VIME__encoder.encoder.linear_n_layers | Linear               | 40.2 K | train
# 21 | model._VIME__encoder.mask_output             | Linear               | 18.5 K | train
# 22 | model._VIME__encoder.feature_output          | Linear               | 18.5 K | train
# 23 | model.one_layer_prediction_head              | VIMESemiSupervised_1 | 40.4 K | train
# 24 | model.one_layer_prediction_head.fc1          | Linear               | 40.2 K | train
# 25 | model.one_layer_prediction_head.fc3          | Linear               | 201    | train
# 26 | model.two_layer_prediction_head              | VIMESemiSupervised_2 | 60.4 K | train
# 27 | model.two_layer_prediction_head.fc1          | Linear               | 40.2 K | train
# 28 | model.two_layer_prediction_head.fc2          | Linear               | 20.1 K | train
# 29 | model.two_layer_prediction_head.fc3          | Linear               | 101    | train
# -----------------------------------------------------------------------------------------------
# 278 K     Trainable params
# 0         Non-trainable params
# 278 K     Total params
# 1.113     Total estimated model params size (MB)
# DONE PRETRAINING
