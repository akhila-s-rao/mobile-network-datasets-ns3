# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='dae', 
             pt_folder='FP3_only_traffic_rows')
# Out:
# Run with random seed:  420
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  2.855168342590332
# Loaded run 1
# Time to read csv file for run:  2.8800978660583496
# Loaded run 2
# Time to read csv file for run:  2.6751816272735596
# Loaded run 3
# Time to read csv file for run:  2.6569716930389404
# Loaded run 4
# Time to read csv file for run:  2.784564256668091
# Loaded run 5
# Time to read csv file for run:  2.678839683532715
# Loaded run 6
# Time to read csv file for run:  2.7517220973968506
# Loaded run 7
# Time to read csv file for run:  2.7282726764678955
# Loaded run 8
# Time to read csv file for run:  2.6843631267547607
# Loaded run 9
# Time to read csv file for run:  2.8343138694763184
# Loaded run 10
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 295 K  | train
# -------------------------------------------------------------
# 295 K     Trainable params
# 0         Non-trainable params
# 295 K     Total params
# 1.183     Total estimated model params size (MB)
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33012, 102)
# X_pretrain  (32691, 92)
# refresh rate:  10
# Epoch 0: 100%|██████████████████████████████████████████████████████████████████████████████████| 232/232 [00:02<00:00, 108.15it/s, v_num=1]
# Epoch 1: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 100.50it/s, v_num=1, train_loss=2.270, val_loss=1.590]
# Epoch 2: 100%|█████████████████████████████████████████████████| 232/232 [00:02<00:00, 94.38it/s, v_num=1, train_loss=1.490, val_loss=1.310]
# Epoch 3: 100%|█████████████████████████████████████████████████| 232/232 [00:02<00:00, 96.35it/s, v_num=1, train_loss=1.320, val_loss=1.200]
# Epoch 4: 100%|█████████████████████████████████████████████████| 232/232 [00:02<00:00, 92.68it/s, v_num=1, train_loss=1.240, val_loss=1.140]
# Epoch 5: 100%|█████████████████████████████████████████████████| 232/232 [00:02<00:00, 92.44it/s, v_num=1, train_loss=1.180, val_loss=1.080]
# Epoch 6: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 101.31it/s, v_num=1, train_loss=1.140, val_loss=1.050]
# Epoch 7: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 100.16it/s, v_num=1, train_loss=1.110, val_loss=1.020]
# Epoch 8: 100%|█████████████████████████████████████████████████| 232/232 [00:02<00:00, 95.96it/s, v_num=1, train_loss=1.080, val_loss=0.993]
# Epoch 9: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 101.05it/s, v_num=1, train_loss=1.060, val_loss=0.981]
# Epoch 10: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 96.20it/s, v_num=1, train_loss=1.050, val_loss=0.961]
# Epoch 11: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 95.69it/s, v_num=1, train_loss=1.030, val_loss=0.952]
# Epoch 12: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 97.87it/s, v_num=1, train_loss=1.020, val_loss=0.941]
# Epoch 13: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 92.37it/s, v_num=1, train_loss=1.010, val_loss=0.926]
# Epoch 14: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 92.37it/s, v_num=1, train_loss=0.999, val_loss=0.916]
# Epoch 15: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 90.25it/s, v_num=1, train_loss=0.992, val_loss=0.910]
# Epoch 16: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 97.98it/s, v_num=1, train_loss=0.983, val_loss=0.914]
# Epoch 17: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 91.73it/s, v_num=1, train_loss=0.977, val_loss=0.906]
# Epoch 18: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 98.52it/s, v_num=1, train_loss=0.970, val_loss=0.893]
# Epoch 19: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 98.77it/s, v_num=1, train_loss=0.965, val_loss=0.881]
# Epoch 20: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 98.77it/s, v_num=1, train_loss=0.954, val_loss=0.888]
# Epoch 21: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 99.44it/s, v_num=1, train_loss=0.947, val_loss=0.885]
# Epoch 22: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 97.91it/s, v_num=1, train_loss=0.946, val_loss=0.870]
# Epoch 23: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 99.65it/s, v_num=1, train_loss=0.943, val_loss=0.856]
# Epoch 24: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 99.04it/s, v_num=1, train_loss=0.942, val_loss=0.885]
# Epoch 25: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 97

# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|████████████████████████████████████████████████| 232/232 [00:02<00:00, 85.36it/s, v_num=1, train_loss=0.846, val_loss=0.811]
# DONE SAVING PRETRAINED MODEL
#    | Name                                             | Type        | Params | Mode
# ------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss     | 0      | train
# 1  | mask_loss_fn                                     | BCELoss     | 0      | train
# 2  | categorical_feature_loss                         | BCELoss     | 0      | train
# 3  | continuous_feature_loss                          | MSELoss     | 0      | train
# 4  | model                                            | DAE         | 295 K  | train
# 5  | model._DAE__encoder                              | MLP         | 140 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear      | 18.6 K | train
# 7  | model._DAE__encoder.batchnorm_0                  | BatchNorm1d | 400    | train
# 8  | model._DAE__encoder.relu_0                       | ReLU        | 0      | train
# 9  | model._DAE__encoder.dropout_0                    | Dropout     | 0      | train
# 10 | model._DAE__encoder.linear_1                     | Linear      | 40.2 K | train
# 11 | model._DAE__encoder.batchnorm_1                  | BatchNorm1d | 400    | train
# 12 | model._DAE__encoder.relu_1                       | ReLU        | 0      | train
# 13 | model._DAE__encoder.dropout_1                    | Dropout     | 0      | train
# 14 | model._DAE__encoder.linear_2                     | Linear      | 40.2 K | train
# 15 | model._DAE__encoder.batchnorm_2                  | BatchNorm1d | 400    | train
# 16 | model._DAE__encoder.relu_2                       | ReLU        | 0      | train
# 17 | model._DAE__encoder.dropout_2                    | Dropout     | 0      | train
# 18 | model._DAE__encoder.linear_n_layers              | Linear      | 40.2 K | train
# 19 | model.mask_predictor_head                        | MLP         | 27.2 K | train
# 20 | model.mask_predictor_head.linear_0               | Linear      | 18.5 K | train
# 21 | model.mask_predictor_head.batchnorm_0            | BatchNorm1d | 184    | train
# 22 | model.mask_predictor_head.relu_0                 | ReLU        | 0      | train
# 23 | model.mask_predictor_head.dropout_0              | Dropout     | 0      | train
# 24 | model.mask_predictor_head.linear_n_layers        | Linear      | 8.6 K  | train
# 25 | model.reconstruction_head                        | MLP         | 27.2 K | train
# 26 | model.reconstruction_head.linear_0               | Linear      | 18.5 K | train
# 27 | model.reconstruction_head.batchnorm_0            | BatchNorm1d | 184    | train
# 28 | model.reconstruction_head.relu_0                 | ReLU        | 0      | train
# 29 | model.reconstruction_head.dropout_0              | Dropout     | 0      | train
# 30 | model.reconstruction_head.linear_n_layers        | Linear      | 8.6 K  | train
# 31 | model.one_layer_prediction_head                  | Sequential  | 40.4 K | train
# 32 | model.one_layer_prediction_head.head_linear_hid  | Linear      | 40.2 K | train
# 33 | model.one_layer_prediction_head.head_activation  | ReLU        | 0      | train
# 34 | model.one_layer_prediction_head.head_linear_out  | Linear      | 201    | train
# 35 | model.two_layer_prediction_head                  | Sequential  | 60.4 K | train
# 36 | model.two_layer_prediction_head.head_linear_hid1 | Linear      | 40.2 K | train
# 37 | model.two_layer_prediction_head.head_activation1 | ReLU        | 0      | train
# 38 | model.two_layer_prediction_head.head_linear_hid2 | Linear      | 20.1 K | train
# 39 | model.two_layer_prediction_head.head_activation2 | ReLU        | 0      | train
# 40 | model.two_layer_prediction_head.head_linear_out  | Linear      | 101    | train
# ------------------------------------------------------------------------------------------
# 295 K     Trainable params
# 0         Non-trainable params
# 295 K     Total params
# 1.183     Total estimated model params size (MB)
# DONE PRETRAINING
