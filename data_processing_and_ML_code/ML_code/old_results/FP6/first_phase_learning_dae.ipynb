# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='dae', 
             pt_folder='FP6')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  3.343733072280884
# Loaded run 1
# Time to read csv file for run:  3.2708985805511475
# Loaded run 2
# Time to read csv file for run:  3.1289937496185303
# Loaded run 3
# Time to read csv file for run:  3.0069386959075928
# Loaded run 4
# Time to read csv file for run:  3.245631694793701
# Loaded run 5
# Time to read csv file for run:  3.3982059955596924
# Loaded run 6
# Time to read csv file for run:  3.3685102462768555
# Loaded run 7
# Time to read csv file for run:  3.1349875926971436
# Loaded run 8
# Time to read csv file for run:  3.1985857486724854
# Loaded run 9
# Time to read csv file for run:  3.0918216705322266
# Loaded run 10
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (1799100, 102)
# X_pretrain  (1796746, 92)
# Seed set to 42
# HYPERPARAMETERS:  {'loss_fn': 'MSELoss', 'metric': 'r2_score', 'hidden_dim': 200, 'max_epochs': 100, 'batch_size': 128, 'optim_hparams': {'lr': 0.0001, 'weight_decay': 5e-05}, 'encoder_depth': 8, 'head_depth': 2, 'dropout_rate': 0.1, 'noise_type': 'Swap', 'noise_ratio': 0.3}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# refresh rate:  10
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 458 K  | train
# -------------------------------------------------------------
# 458 K     Trainable params
# 0         Non-trainable params
# 458 K     Total params
# 1.832     Total estimated model params size (MB)
# Epoch 0: 100%|████████████████████████████████████████████████████| 12704/12704 [03:38<00:00, 58.08it/s]
# Epoch 1: 100%|██████████████████| 12704/12704 [03:46<00:00, 56.09it/s, train_loss=1.100, val_loss=0.902]
# Epoch 2: 100%|██████████████████| 12704/12704 [03:29<00:00, 60.78it/s, train_loss=0.942, val_loss=0.866]
# Epoch 3: 100%|██████████████████| 12704/12704 [03:17<00:00, 64.44it/s, train_loss=0.914, val_loss=0.842]
# Epoch 4: 100%|██████████████████| 12704/12704 [03:40<00:00, 57.73it/s, train_loss=0.900, val_loss=0.844]
# Epoch 5: 100%|██████████████████| 12704/12704 [03:51<00:00, 54.85it/s, train_loss=0.888, val_loss=0.829]
# Epoch 6: 100%|██████████████████| 12704/12704 [03:37<00:00, 58.44it/s, train_loss=0.879, val_loss=0.864]
# Epoch 7: 100%|██████████████████| 12704/12704 [03:26<00:00, 61.46it/s, train_loss=0.872, val_loss=0.812]
# Epoch 8: 100%|██████████████████| 12704/12704 [03:35<00:00, 58.90it/s, train_loss=0.866, val_loss=0.804]
# Epoch 9: 100%|██████████████████| 12704/12704 [03:44<00:00, 56.49it/s, train_loss=0.860, val_loss=0.811]
# Epoch 10: 100%|█████████████████| 12704/12704 [03:42<00:00, 57.11it/s, train_loss=0.855, val_loss=0.798]
# Epoch 11: 100%|█████████████████| 12704/12704 [03:25<00:00, 61.75it/s, train_loss=0.853, val_loss=0.803]
# Epoch 12: 100%|█████████████████| 12704/12704 [03:37<00:00, 58.53it/s, train_loss=0.847, val_loss=0.786]
# Epoch 13: 100%|█████████████████| 12704/12704 [03:37<00:00, 58.28it/s, train_loss=0.844, val_loss=0.794]
# Epoch 14: 100%|█████████████████| 12704/12704 [03:40<00:00, 57.65it/s, train_loss=0.842, val_loss=0.785]
# Epoch 15: 100%|█████████████████| 12704/12704 [03:28<00:00, 60.82it/s, train_loss=0.838, val_loss=0.792]
# Epoch 16: 100%|█████████████████| 12704/12704 [03:30<00:00, 60.28it/s, train_loss=0.836, val_loss=0.797]
# Epoch 17: 100%|█████████████████| 12704/12704 [03:44<00:00, 56.50it/s, train_loss=0.832, val_loss=0.783]
# Epoch 18: 100%|█████████████████| 12704/12704 [03:39<00:00, 57.76it/s, train_loss=0.830, val_loss=0.782]
# Epoch 19: 100%|█████████████████| 12704/12704 [03:34<00:00, 59.11it/s, train_loss=0.827, val_loss=0.782]
# Epoch 20: 100%|█████████████████| 12704/12704 [03:30<00:00, 60.46it/s, train_loss=0.825, val_loss=0.777]
# Epoch 21: 100%|█████████████████| 12704/12704 [03:34<00:00, 59.15it/s, train_loss=0.823, val_loss=0.775]
# Epoch 22: 100%|█████████████████| 12704/12704 [03:48<00:00, 55.64it/s, train_loss=0.823, val_loss=0.775]
# Epoch 23: 100%|█████████████████| 12704/12704 [03:37<00:00, 58.29it/s, train_loss=0.820, val_loss=0.771]
# Epoch 24: 100%|█████████████████| 12704/12704 [03:25<00:00, 61.71it/s, train_loss=0.817, val_loss=0.769]
# Epoch 25: 100%|█████████████████| 12704/12704 [03:28<00:00, 61.01it/s, train_loss=0.818, val_loss=0.761]
# Epoch 26: 100%|█████████████████| 12704/12704 [03:44<00:00, 56.52it/s, train_loss=0.814, val_loss=0.771]
# Epoch 27: 100%|█████████████████| 12704/12704 [03:46<00:00, 56.20it/s, train_loss=0.813, val_loss=0.768]
# Epoch 28: 100%|█████████████████| 12704/12704 [03:39<00:00, 57.91it/s, train_loss=0.811, val_loss=0.763]
# Epoch 29: 100%|█████████████████| 12704/12704 [03:23<00:00, 62.37it/s, train_loss=0.809, val_loss=0.762]
# Epoch 30: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.62it/s, train_loss=0.807, val_loss=0.764]
# Epoch 31: 100%|█████████████████| 12704/12704 [03:37<00:00, 58.36it/s, train_loss=0.806, val_loss=0.770]
# Epoch 32: 100%|█████████████████| 12704/12704 [03:43<00:00, 56.90it/s, train_loss=0.803, val_loss=0.768]
# Epoch 33: 100%|█████████████████| 12704/12704 [03:40<00:00, 57.62it/s, train_loss=0.804, val_loss=0.758]
# Epoch 34: 100%|█████████████████| 12704/12704 [03:25<00:00, 61.91it/s, train_loss=0.804, val_loss=0.768]
# Epoch 35: 100%|█████████████████| 12704/12704 [03:21<00:00, 62.99it/s, train_loss=0.801, val_loss=0.751]
# Epoch 36: 100%|█████████████████| 12704/12704 [03:40<00:00, 57.65it/s, train_loss=0.801, val_loss=0.753]
# Epoch 37: 100%|█████████████████| 12704/12704 [03:46<00:00, 56.21it/s, train_loss=0.800, val_loss=0.770]
# Epoch 38: 100%|█████████████████| 12704/12704 [03:40<00:00, 57.60it/s, train_loss=0.797, val_loss=0.760]
# Epoch 39: 100%|█████████████████| 12704/12704 [03:30<00:00, 60.46it/s, train_loss=0.796, val_loss=0.753]
# Epoch 40: 100%|█████████████████| 12704/12704 [03:23<00:00, 62.44it/s, train_loss=0.796, val_loss=0.754]
# Epoch 41: 100%|█████████████████| 12704/12704 [03:28<00:00, 60.92it/s, train_loss=0.796, val_loss=0.752]
# Epoch 42: 100%|█████████████████| 12704/12704 [03:45<00:00, 56.44it/s, train_loss=0.793, val_loss=0.758]
# Epoch 43: 100%|█████████████████| 12704/12704 [03:40<00:00, 57.53it/s, train_loss=0.795, val_loss=0.745]
# Epoch 44: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.26it/s, train_loss=0.796, val_loss=0.753]
# Epoch 45: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.59it/s, train_loss=0.791, val_loss=0.758]
# Epoch 46: 100%|█████████████████| 12704/12704 [03:22<00:00, 62.59it/s, train_loss=0.790, val_loss=0.757]
# Epoch 47: 100%|█████████████████| 12704/12704 [03:36<00:00, 58.75it/s, train_loss=0.790, val_loss=0.743]
# Epoch 48: 100%|█████████████████| 12704/12704 [03:41<00:00, 57.35it/s, train_loss=0.788, val_loss=0.746]
# Epoch 49: 100%|█████████████████| 12704/12704 [03:28<00:00, 60.80it/s, train_loss=0.786, val_loss=0.743]
# Epoch 50: 100%|█████████████████| 12704/12704 [03:35<00:00, 59.06it/s, train_loss=0.786, val_loss=0.745]
# Epoch 51: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.77it/s, train_loss=0.784, val_loss=0.739]
# Epoch 52: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.59it/s, train_loss=0.784, val_loss=0.733]
# Epoch 53: 100%|█████████████████| 12704/12704 [03:31<00:00, 60.16it/s, train_loss=0.783, val_loss=0.741]
# Epoch 54: 100%|█████████████████| 12704/12704 [03:38<00:00, 58.07it/s, train_loss=0.785, val_loss=0.738]
# Epoch 55: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.61it/s, train_loss=0.781, val_loss=0.734]
# Epoch 56: 100%|█████████████████| 12704/12704 [03:31<00:00, 59.99it/s, train_loss=0.781, val_loss=0.735]
# Epoch 57: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.67it/s, train_loss=0.780, val_loss=0.735]
# Epoch 58: 100%|█████████████████| 12704/12704 [03:33<00:00, 59.45it/s, train_loss=0.781, val_loss=0.767]
# Epoch 59: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.78it/s, train_loss=0.780, val_loss=0.738]
# Epoch 60: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.09it/s, train_loss=0.777, val_loss=0.738]
# Epoch 61: 100%|█████████████████| 12704/12704 [03:32<00:00, 59.85it/s, train_loss=0.778, val_loss=0.740]
# Epoch 62: 100%|█████████████████| 12704/12704 [03:35<00:00, 59.00it/s, train_loss=0.777, val_loss=0.729]
# Epoch 63: 100%|█████████████████| 12704/12704 [03:34<00:00, 59.24it/s, train_loss=0.779, val_loss=0.732]
# Epoch 64: 100%|█████████████████| 12704/12704 [03:37<00:00, 58.38it/s, train_loss=0.777, val_loss=0.760]
# Epoch 65: 100%|█████████████████| 12704/12704 [03:30<00:00, 60.40it/s, train_loss=0.778, val_loss=0.736]
# Epoch 66: 100%|█████████████████| 12704/12704 [03:26<00:00, 61.45it/s, train_loss=0.776, val_loss=0.733]
# Epoch 67: 100%|█████████████████| 12704/12704 [03:35<00:00, 58.84it/s, train_loss=0.776, val_loss=0.736]
# Epoch 68: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.29it/s, train_loss=0.774, val_loss=0.727]
# Epoch 69: 100%|█████████████████| 12704/12704 [03:36<00:00, 58.75it/s, train_loss=0.775, val_loss=0.730]
# Epoch 70: 100%|█████████████████| 12704/12704 [03:38<00:00, 58.02it/s, train_loss=0.774, val_loss=0.729]
# Epoch 71: 100%|█████████████████| 12704/12704 [03:30<00:00, 60.31it/s, train_loss=0.772, val_loss=0.729]
# Epoch 72: 100%|█████████████████| 12704/12704 [03:33<00:00, 59.53it/s, train_loss=0.772, val_loss=0.724]
# Epoch 73: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.35it/s, train_loss=0.772, val_loss=0.730]
# Epoch 74: 100%|█████████████████| 12704/12704 [03:31<00:00, 60.08it/s, train_loss=0.774, val_loss=0.719]
# Epoch 75: 100%|█████████████████| 12704/12704 [03:35<00:00, 58.90it/s, train_loss=0.771, val_loss=0.724]
# Epoch 76: 100%|█████████████████| 12704/12704 [03:32<00:00, 59.83it/s, train_loss=0.772, val_loss=0.736]
# Epoch 77: 100%|█████████████████| 12704/12704 [03:31<00:00, 60.08it/s, train_loss=0.770, val_loss=0.726]
# Epoch 78: 100%|█████████████████| 12704/12704 [03:28<00:00, 60.90it/s, train_loss=0.769, val_loss=0.728]
# Epoch 79: 100%|█████████████████| 12704/12704 [03:26<00:00, 61.52it/s, train_loss=0.770, val_loss=0.722]
# Epoch 80: 100%|█████████████████| 12704/12704 [03:28<00:00, 60.98it/s, train_loss=0.769, val_loss=0.732]
# Epoch 81: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.30it/s, train_loss=0.769, val_loss=0.799]
# Epoch 82: 100%|█████████████████| 12704/12704 [03:32<00:00, 59.68it/s, train_loss=0.769, val_loss=0.719]
# Epoch 83: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.62it/s, train_loss=0.769, val_loss=0.740]
# Epoch 84: 100%|█████████████████| 12704/12704 [03:42<00:00, 57.19it/s, train_loss=0.767, val_loss=0.720]
# Epoch 85: 100%|█████████████████| 12704/12704 [03:31<00:00, 60.11it/s, train_loss=0.768, val_loss=0.722]
# Epoch 86: 100%|█████████████████| 12704/12704 [03:25<00:00, 61.80it/s, train_loss=0.767, val_loss=0.716]
# Epoch 87: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.16it/s, train_loss=0.769, val_loss=0.722]
# Epoch 88: 100%|█████████████████| 12704/12704 [03:24<00:00, 62.01it/s, train_loss=0.766, val_loss=0.728]
# Epoch 89: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.60it/s, train_loss=0.767, val_loss=0.726]
# Epoch 90: 100%|█████████████████| 12704/12704 [03:33<00:00, 59.49it/s, train_loss=0.766, val_loss=0.714]
# Epoch 91: 100%|█████████████████| 12704/12704 [03:29<00:00, 60.57it/s, train_loss=0.767, val_loss=0.725]
# Epoch 92: 100%|█████████████████| 12704/12704 [03:27<00:00, 61.12it/s, train_loss=0.764, val_loss=0.721]
# Epoch 93: 100%|█████████████████| 12704/12704 [03:17<00:00, 64.27it/s, train_loss=0.766, val_loss=0.733]
# Epoch 94: 100%|█████████████████| 12704/12704 [03:14<00:00, 65.31it/s, train_loss=0.763, val_loss=0.718]
# Epoch 95: 100%|█████████████████| 12704/12704 [03:04<00:00, 68.72it/s, train_loss=0.765, val_loss=0.726]
# Epoch 96: 100%|█████████████████| 12704/12704 [03:01<00:00, 69.80it/s, train_loss=0.763, val_loss=0.728]
# Epoch 97: 100%|█████████████████| 12704/12704 [03:01<00:00, 69.94it/s, train_loss=0.764, val_loss=0.725]
# Epoch 98: 100%|█████████████████| 12704/12704 [03:00<00:00, 70.32it/s, train_loss=0.764, val_loss=0.718]
# Epoch 99: 100%|█████████████████| 12704/12704 [03:02<00:00, 69.74it/s, train_loss=0.763, val_loss=0.716]
# Epoch 99: 100%|█████████████████| 12704/12704 [03:12<00:00, 66.07it/s, train_loss=0.762, val_loss=0.739]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|█████████████████| 12704/12704 [03:12<00:00, 66.05it/s, train_loss=0.762, val_loss=0.739]
# DONE SAVING PRETRAINED MODEL
#    | Name                                             | Type        | Params | Mode
# ------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss     | 0      | train
# 1  | mask_loss_fn                                     | BCELoss     | 0      | train
# 2  | categorical_feature_loss                         | BCELoss     | 0      | train
# 3  | continuous_feature_loss                          | MSELoss     | 0      | train
# 4  | model                                            | DAE         | 458 K  | train
# 5  | model._DAE__encoder                              | MLP         | 302 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear      | 18.6 K | train
# 7  | model._DAE__encoder.batchnorm_0                  | BatchNorm1d | 400    | train
# 8  | model._DAE__encoder.relu_0                       | ReLU        | 0      | train
# 9  | model._DAE__encoder.dropout_0                    | Dropout     | 0      | train
# 10 | model._DAE__encoder.linear_1                     | Linear      | 40.2 K | train
# 11 | model._DAE__encoder.batchnorm_1                  | BatchNorm1d | 400    | train
# 12 | model._DAE__encoder.relu_1                       | ReLU        | 0      | train
# 13 | model._DAE__encoder.dropout_1                    | Dropout     | 0      | train
# 14 | model._DAE__encoder.linear_2                     | Linear      | 40.2 K | train
# 15 | model._DAE__encoder.batchnorm_2                  | BatchNorm1d | 400    | train
# 16 | model._DAE__encoder.relu_2                       | ReLU        | 0      | train
# 17 | model._DAE__encoder.dropout_2                    | Dropout     | 0      | train
# 18 | model._DAE__encoder.linear_3                     | Linear      | 40.2 K | train
# 19 | model._DAE__encoder.batchnorm_3                  | BatchNorm1d | 400    | train
# 20 | model._DAE__encoder.relu_3                       | ReLU        | 0      | train
# 21 | model._DAE__encoder.dropout_3                    | Dropout     | 0      | train
# 22 | model._DAE__encoder.linear_4                     | Linear      | 40.2 K | train
# 23 | model._DAE__encoder.batchnorm_4                  | BatchNorm1d | 400    | train
# 24 | model._DAE__encoder.relu_4                       | ReLU        | 0      | train
# 25 | model._DAE__encoder.dropout_4                    | Dropout     | 0      | train
# 26 | model._DAE__encoder.linear_5                     | Linear      | 40.2 K | train
# 27 | model._DAE__encoder.batchnorm_5                  | BatchNorm1d | 400    | train
# 28 | model._DAE__encoder.relu_5                       | ReLU        | 0      | train
# 29 | model._DAE__encoder.dropout_5                    | Dropout     | 0      | train
# 30 | model._DAE__encoder.linear_6                     | Linear      | 40.2 K | train
# 31 | model._DAE__encoder.batchnorm_6                  | BatchNorm1d | 400    | train
# 32 | model._DAE__encoder.relu_6                       | ReLU        | 0      | train
# 33 | model._DAE__encoder.dropout_6                    | Dropout     | 0      | train
# 34 | model._DAE__encoder.linear_n_layers              | Linear      | 40.2 K | train
# 35 | model.mask_predictor_head                        | MLP         | 27.2 K | train
# 36 | model.mask_predictor_head.linear_0               | Linear      | 18.5 K | train
# 37 | model.mask_predictor_head.batchnorm_0            | BatchNorm1d | 184    | train
# 38 | model.mask_predictor_head.relu_0                 | ReLU        | 0      | train
# 39 | model.mask_predictor_head.dropout_0              | Dropout     | 0      | train
# 40 | model.mask_predictor_head.linear_n_layers        | Linear      | 8.6 K  | train
# 41 | model.reconstruction_head                        | MLP         | 27.2 K | train
# 42 | model.reconstruction_head.linear_0               | Linear      | 18.5 K | train
# 43 | model.reconstruction_head.batchnorm_0            | BatchNorm1d | 184    | train
# 44 | model.reconstruction_head.relu_0                 | ReLU        | 0      | train
# 45 | model.reconstruction_head.dropout_0              | Dropout     | 0      | train
# 46 | model.reconstruction_head.linear_n_layers        | Linear      | 8.6 K  | train
# 47 | model.one_layer_prediction_head                  | Sequential  | 40.4 K | train
# 48 | model.one_layer_prediction_head.head_linear_hid  | Linear      | 40.2 K | train
# 49 | model.one_layer_prediction_head.head_activation  | ReLU        | 0      | train
# 50 | model.one_layer_prediction_head.head_linear_out  | Linear      | 201    | train
# 51 | model.two_layer_prediction_head                  | Sequential  | 60.4 K | train
# 52 | model.two_layer_prediction_head.head_linear_hid1 | Linear      | 40.2 K | train
# 53 | model.two_layer_prediction_head.head_activation1 | ReLU        | 0      | train
# 54 | model.two_layer_prediction_head.head_linear_hid2 | Linear      | 20.1 K | train
# 55 | model.two_layer_prediction_head.head_activation2 | ReLU        | 0      | train
# 56 | model.two_layer_prediction_head.head_linear_out  | Linear      | 101    | train
# ------------------------------------------------------------------------------------------
# 458 K     Trainable params
# 0         Non-trainable params
# 458 K     Total params
# 1.832     Total estimated model params size (MB)
# Time to pretrain model:  22394.893273353577
# DONE PRETRAINING
