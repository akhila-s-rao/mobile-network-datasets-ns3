# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='scarf', 
             pt_folder='FP3')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  3.199936866760254
# Loaded run 1
# Time to read csv file for run:  3.020139455795288
# Loaded run 2
# Time to read csv file for run:  3.0797629356384277
# Loaded run 3
# Time to read csv file for run:  3.0439136028289795
# Loaded run 4
# Time to read csv file for run:  3.0336201190948486
# Loaded run 5
# Time to read csv file for run:  2.966256618499756
# Loaded run 6
# Time to read csv file for run:  2.961700916290283
# Loaded run 7
# Time to read csv file for run:  3.240589141845703
# Loaded run 8
# Time to read csv file for run:  3.0765795707702637
# Loaded run 9
# Time to read csv file for run:  3.124497890472412
# Loaded run 10
# Seed set to 42
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33026, 102)
# X_pretrain  (32705, 92)
# HYPERPARAMETERS:  {'loss_fn': 'MSELoss', 'metric': 'r2_score', 'hidden_dim': 200, 'max_epochs': 100, 'batch_size': 128, 'optim_hparams': {'lr': 0.0001, 'weight_decay': 5e-05}, 'encoder_depth': 4, 'head_depth': 2, 'dropout_rate': 0.1, 'corruption_rate': 0.3}
# refresh rate:  10
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type       | Params | Mode
# --------------------------------------------------------
# 0 | task_loss_fn     | MSELoss    | 0      | train
# 1 | contrastive_loss | NTXentLoss | 0      | train
# 2 | model            | SCARF      | 322 K  | train
# --------------------------------------------------------
# 322 K     Trainable params
# 0         Non-trainable params
# 322 K     Total params
# 1.288     Total estimated model params size (MB)
# Epoch 0: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 59.06it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.23it/s, train_loss=2.470, val_loss=2.010]
# Epoch 2: 100%|██████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 58.71it/s, train_loss=1.600, val_loss=1.630]
# Epoch 3: 100%|██████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 60.87it/s, train_loss=1.290, val_loss=1.470]
# Epoch 4: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 56.02it/s, train_loss=1.120, val_loss=1.370]
# Epoch 5: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 55.02it/s, train_loss=1.010, val_loss=1.310]
# Epoch 6: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 55.50it/s, train_loss=0.929, val_loss=1.250]
# Epoch 7: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 54.85it/s, train_loss=0.869, val_loss=1.190]
# Epoch 8: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 55.54it/s, train_loss=0.823, val_loss=1.210]
# Epoch 9: 100%|██████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 56.67it/s, train_loss=0.779, val_loss=1.170]
# Epoch 10: 100%|█████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 61.46it/s, train_loss=0.747, val_loss=1.150]
# Epoch 11: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.51it/s, train_loss=0.732, val_loss=1.120]
# Epoch 12: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.10it/s, train_loss=0.708, val_loss=1.120]
# Epoch 13: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.21it/s, train_loss=0.696, val_loss=1.110]
# Epoch 14: 100%|█████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 61.19it/s, train_loss=0.669, val_loss=1.140]
# Epoch 15: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 56.77it/s, train_loss=0.654, val_loss=1.070]
# Epoch 16: 100%|█████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 58.57it/s, train_loss=0.647, val_loss=1.100]
# Epoch 17: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 55.47it/s, train_loss=0.646, val_loss=1.050]
# Epoch 18: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 56.68it/s, train_loss=0.620, val_loss=1.090]
# Epoch 19: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.47it/s, train_loss=0.614, val_loss=1.060]
# Epoch 20: 100%|█████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 56
 100%|█████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 58.93it/s, train_loss=0.434, val_loss=0.758]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|█████████████████████████████████████████████████████████| 232/232 [00:03<00:00, 58.62it/s, train_loss=0.434, val_loss=0.758]
# DONE SAVING PRETRAINED MODEL
#    | Name                                             | Type        | Params | Mode
# ------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss     | 0      | train
# 1  | contrastive_loss                                 | NTXentLoss  | 0      | train
# 2  | model                                            | SCARF       | 322 K  | train
# 3  | model._SCARF__encoder                            | MLP         | 140 K  | train
# 4  | model._SCARF__encoder.linear_0                   | Linear      | 18.6 K | train
# 5  | model._SCARF__encoder.batchnorm_0                | BatchNorm1d | 400    | train
# 6  | model._SCARF__encoder.relu_0                     | ReLU        | 0      | train
# 7  | model._SCARF__encoder.dropout_0                  | Dropout     | 0      | train
# 8  | model._SCARF__encoder.linear_1                   | Linear      | 40.2 K | train
# 9  | model._SCARF__encoder.batchnorm_1                | BatchNorm1d | 400    | train
# 10 | model._SCARF__encoder.relu_1                     | ReLU        | 0      | train
# 11 | model._SCARF__encoder.dropout_1                  | Dropout     | 0      | train
# 12 | model._SCARF__encoder.linear_2                   | Linear      | 40.2 K | train
# 13 | model._SCARF__encoder.batchnorm_2                | BatchNorm1d | 400    | train
# 14 | model._SCARF__encoder.relu_2                     | ReLU        | 0      | train
# 15 | model._SCARF__encoder.dropout_2                  | Dropout     | 0      | train
# 16 | model._SCARF__encoder.linear_n_layers            | Linear      | 40.2 K | train
# 17 | model.pretraining_head                           | MLP         | 80.8 K | train
# 18 | model.pretraining_head.linear_0                  | Linear      | 40.2 K | train
# 19 | model.pretraining_head.batchnorm_0               | BatchNorm1d | 400    | train
# 20 | model.pretraining_head.relu_0                    | ReLU        | 0      | train
# 21 | model.pretraining_head.dropout_0                 | Dropout     | 0      | train
# 22 | model.pretraining_head.linear_n_layers           | Linear      | 40.2 K | train
# 23 | model.one_layer_prediction_head                  | Sequential  | 40.4 K | train
# 24 | model.one_layer_prediction_head.head_linear_hid  | Linear      | 40.2 K | train
# 25 | model.one_layer_prediction_head.head_activation  | ReLU        | 0      | train
# 26 | model.one_layer_prediction_head.head_linear_out  | Linear      | 201    | train
# 27 | model.two_layer_prediction_head                  | Sequential  | 60.4 K | train
# 28 | model.two_layer_prediction_head.head_linear_hid1 | Linear      | 40.2 K | train
# 29 | model.two_layer_prediction_head.head_activation1 | ReLU        | 0      | train
# 30 | model.two_layer_prediction_head.head_linear_hid2 | Linear      | 20.1 K | train
# 31 | model.two_layer_prediction_head.head_activation2 | ReLU        | 0      | train
# 32 | model.two_layer_prediction_head.head_linear_out  | Linear      | 101    | train
# ------------------------------------------------------------------------------------------
# 322 K     Trainable params
# 0         Non-trainable params
# 322 K     Total params
# 1.288     Total estimated model params size (MB)
# Time to pretrain model:  430.33152198791504
# DONE PRETRAINING
