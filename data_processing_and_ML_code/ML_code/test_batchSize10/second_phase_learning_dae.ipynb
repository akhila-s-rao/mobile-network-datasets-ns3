# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(SP_results_folder='rando_test_batchSize10', # This folder will be created and the results csv files stored there 
             pred_head_type = 'ts3l',
             pt_type ='dae',
             pt_folder = 'FP2',
             pretrain=False, # if True First Phase training
             use_pretrained_model=True, 
             freeze_encoder=False,
             pred_head_size = 1, 
             shift_samp_for_predict = True)
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# rand_itr:  0  train_runs:  [11]  test_runs:  [12]
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  3.467087745666504
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  3.336289882659912
# Loaded run 12
# Time to read data:  17.41712522506714
# ==========================================================================
# NUM. LABELLED SAMPLES:  100
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# Train data shape (100, 92)
# Test data shape (3152, 92)
# Val data shape (100, 92)
# Time to process data for one learning task:  0.020778179168701172
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
#    | Name                                             | Type       | Params | Mode
# -----------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss    | 0      | train
# 1  | mask_loss_fn                                     | BCELoss    | 0      | train
# 2  | categorical_feature_loss                         | BCELoss    | 0      | train
# 3  | continuous_feature_loss                          | MSELoss    | 0      | train
# 4  | model                                            | DAE        | 357 K  | train
# 5  | model._DAE__encoder                              | MLP        | 139 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear     | 18.6 K | train
# 7  | model._DAE__encoder.relu_0                       | ReLU       | 0      | train
# 8  | model._DAE__encoder.dropout_0                    | Dropout    | 0      | train
# 9  | model._DAE__encoder.linear_1                     | Linear     | 40.2 K | train
# 10 | model._DAE__encoder.relu_1                       | ReLU       | 0      | train
# 11 | model._DAE__encoder.dropout_1                    | Dropout    | 0      | train
# 12 | model._DAE__encoder.linear_2                     | Linear     | 40.2 K | train
# 13 | model._DAE__encoder.relu_2                       | ReLU       | 0      | train
# 14 | model._DAE__encoder.dropout_2                    | Dropout    | 0      | train
# 15 | model._DAE__encoder.last_layer                   | Linear     | 40.2 K | train
# 16 | model.mask_predictor_head                        | MLP        | 58.7 K | train
# 17 | model.mask_predictor_head.linear_0               | Linear     | 40.2 K | train
# 18 | model.mask_predictor_head.relu_0                 | ReLU       | 0      | train
# 19 | model.mask_predictor_head.dropout_0              | Dropout    | 0      | train
# 20 | model.mask_predictor_head.last_layer             | Linear     | 18.5 K | train
# 21 | model.reconstruction_head                        | MLP        | 58.7 K | train
# 22 | model.reconstruction_head.linear_0               | Linear     | 40.2 K | train
# 23 | model.reconstruction_head.relu_0                 | ReLU       | 0      | train
# 24 | model.reconstruction_head.dropout_0              | Dropout    | 0      | train
# 25 | model.reconstruction_head.last_layer             | Linear     | 18.5 K | train
# 26 | model.one_layer_prediction_head                  | Sequential | 40.4 K | train
# 27 | model.one_layer_prediction_head.head_linear_hid  | Linear     | 40.2 K | train
# 28 | model.one_layer_prediction_head.head_activation  | ReLU       | 0      | train
# 29 | model.one_layer_prediction_head.head_linear_out  | Linear     | 201    | train
# 30 | model.two_layer_prediction_head                  | Sequential | 60.4 K | train
# 31 | model.two_layer_prediction_head.head_linear_hid1 | Linear     | 40.2 K | train
# 32 | model.two_layer_prediction_head.head_activation1 | ReLU       | 0      | train
# 33 | model.two_layer_prediction_head.head_linear_hid2 | Linear     | 20.1 K | train
# 34 | model.two_layer_prediction_head.head_activation2 | ReLU       | 0      | train
# 35 | model.two_layer_prediction_head.head_linear_out  | Linear     | 101    | train
# -----------------------------------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# HYPERPARAMETERS:  {'batch_size': 10, 'max_epochs': 30, 'patience': 5, 'loss': {'reg': 'MSELoss', 'clas': 'CrossEntropyLoss'}, 'metrics': {'reg': ['r2_score'], 'clas': ['Recall']}}
# refresh rate:  10
# Epoch 0: 100%|██████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 60.74it/s]
# Epoch 1: 100%|████████████████████| 10/10 [00:01<00:00,  8.19it/s, train_loss=3.610, val_r2_score=-16.7]
# Epoch 2: 100%|████████████████████| 10/10 [00:01<00:00,  7.28it/s, train_loss=2.280, val_r2_score=-4.57]
# Epoch 3: 100%|████████████████████| 10/10 [00:01<00:00,  8.05it/s, train_loss=1.150, val_r2_score=-3.57]
# Epoch 4: 100%|████████████████████| 10/10 [00:01<00:00,  7.25it/s, train_loss=0.757, val_r2_score=-3.97]
# Epoch 5: 100%|████████████████████| 10/10 [00:01<00:00,  7.94it/s, train_loss=0.762, val_r2_score=-2.38]
# Epoch 6: 100%|████████████████████| 10/10 [00:01<00:00,  7.44it/s, train_loss=0.760, val_r2_score=-2.96]
# Epoch 7: 100%|████████████████████| 10/10 [00:01<00:00,  8.07it/s, train_loss=0.862, val_r2_score=-2.30]
# Epoch 8: 100%|████████████████████| 10/10 [00:01<00:00,  7.42it/s, train_loss=0.647, val_r2_score=-1.58]
# Epoch 9: 100%|████████████████████| 10/10 [00:01<00:00,  7.99it/s, train_loss=0.609, val_r2_score=-2.24]
# Epoch 10: 100%|███████████████████| 10/10 [00:01<00:00,  7.47it/s, train_loss=0.502, val_r2_score=-1.91]
# Epoch 11: 100%|███████████████████| 10/10 [00:01<00:00,  8.01it/s, train_loss=0.469, val_r2_score=-1.85]
# Epoch 12: 100%|███████████████████| 10/10 [00:01<00:00,  7.66it/s, train_loss=0.451, val_r2_score=-1.69]
# Epoch 13: 100%|███████████████████| 10/10 [00:01<00:00,  8.13it/s, train_loss=0.491, val_r2_score=-1.73]
# Epoch 14: 100%|███████████████████| 10/10 [00:01<00:00,  7.10it/s, train_loss=0.442, val_r2_score=-1.60]
# Epoch 15: 100%|███████████████████| 10/10 [00:01<00:00,  8.32it/s, train_loss=0.407, val_r2_score=-1.60]
# Epoch 16: 100%|███████████████████| 10/10 [00:01<00:00,  7.60it/s, train_loss=0.312, val_r2_score=-1.20]
# Epoch 17: 100%|███████████████████| 10/10 [00:01<00:00,  8.05it/s, train_loss=0.304, val_r2_score=-1.30]
# Epoch 18: 100%|███████████████████| 10/10 [00:01<00:00,  7.51it/s, train_loss=0.459, val_r2_score=-1.16]
# Epoch 19: 100%|███████████████████| 10/10 [00:01<00:00,  7.82it/s, train_loss=0.414, val_r2_score=-1.05]
# Epoch 20: 100%|███████████████████| 10/10 [00:01<00:00,  7.94it/s, train_loss=0.400, val_r2_score=-1.32]
# Epoch 21: 100%|███████████████████| 10/10 [00:01<00:00,  7.99it/s, train_loss=0.259, val_r2_score=-1.04]
# Epoch 22: 100%|██████████████████| 10/10 [00:01<00:00,  8.14it/s, train_loss=0.361, val_r2_score=-0.869]
# Epoch 23: 100%|███████████████████| 10/10 [00:01<00:00,  7.68it/s, train_loss=0.254, val_r2_score=-1.06]
# Epoch 24: 100%|███████████████████| 10/10 [00:01<00:00,  8.11it/s, train_loss=0.301, val_r2_score=-0.73]
# Epoch 25: 100%|███████████████████| 10/10 [00:01<00:00,  8.21it/s, train_loss=0.485, val_r2_score=-0.78]
# Epoch 26: 100%|██████████████████| 10/10 [00:01<00:00,  7.59it/s, train_loss=0.354, val_r2_score=-0.765]
# Epoch 27: 100%|███████████████████| 10/10 [00:01<00:00,  8.03it/s, train_loss=0.224, val_r2_score=-1.16]
# Epoch 28: 100%|███████████████████| 10/10 [00:01<00:00,  7.93it/s, train_loss=0.240, val_r2_score=-0.80]
# Epoch 29: 100%|██████████████████| 10/10 [00:01<00:00,  8.28it/s, train_loss=0.306, val_r2_score=-0.815]
# Epoch 29: 100%|██████████████████| 10/10 [00:02<00:00,  3.96it/s, train_loss=0.268, val_r2_score=-0.828]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|██████████████████| 10/10 [00:02<00:00,  3.93it/s, train_loss=0.268, val_r2_score=-0.828]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.018465280532836914
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  100
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_thput_mbps  task type:  reg  task num:  1 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# Train data shape (100, 92)
# Test data shape (3148, 92)
# Val data shape (100, 92)
# Time to process data for one learning task:  0.025979995727539062
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 140.02it/s]
# Epoch 1: 100%|████████████████████| 10/10 [00:01<00:00,  7.97it/s, train_loss=503.0, val_r2_score=-0.57]
# Epoch 2: 100%|███████████████████| 10/10 [00:01<00:00,  8.14it/s, train_loss=401.0, val_r2_score=-0.257]
# Epoch 3: 100%|██████████████████| 10/10 [00:01<00:00,  7.72it/s, train_loss=332.0, val_r2_score=-0.0487]
# Epoch 4: 100%|████████████████████| 10/10 [00:01<00:00,  7.86it/s, train_loss=282.0, val_r2_score=0.075]
# Epoch 5: 100%|████████████████████| 10/10 [00:01<00:00,  7.71it/s, train_loss=250.0, val_r2_score=0.137]
# Epoch 6: 100%|████████████████████| 10/10 [00:01<00:00,  8.31it/s, train_loss=224.0, val_r2_score=0.160]
# Epoch 7: 100%|████████████████████| 10/10 [00:01<00:00,  7.92it/s, train_loss=209.0, val_r2_score=0.167]
# Epoch 8: 100%|████████████████████| 10/10 [00:01<00:00,  8.72it/s, train_loss=196.0, val_r2_score=0.174]
# Epoch 9: 100%|████████████████████| 10/10 [00:01<00:00,  8.33it/s, train_loss=179.0, val_r2_score=0.180]
# Epoch 10: 100%|███████████████████| 10/10 [00:01<00:00,  8.47it/s, train_loss=176.0, val_r2_score=0.192]
# Epoch 11: 100%|███████████████████| 10/10 [00:01<00:00,  8.51it/s, train_loss=156.0, val_r2_score=0.178]
# Epoch 12: 100%|███████████████████| 10/10 [00:01<00:00,  8.36it/s, train_loss=147.0, val_r2_score=0.150]
# Epoch 13: 100%|███████████████████| 10/10 [00:01<00:00,  8.71it/s, train_loss=137.0, val_r2_score=0.152]
# Epoch 14: 100%|███████████████████| 10/10 [00:01<00:00,  8.64it/s, train_loss=128.0, val_r2_score=0.173]
# Epoch 15: 100%|███████████████████| 10/10 [00:01<00:00,  8.45it/s, train_loss=117.0, val_r2_score=0.137]
# Epoch 16: 100%|██████████████████| 10/10 [00:01<00:00,  8.60it/s, train_loss=117.0, val_r2_score=0.0976]
# Epoch 17: 100%|███████████████████| 10/10 [00:01<00:00,  8.43it/s, train_loss=110.0, val_r2_score=0.128]
# Epoch 18: 100%|███████████████████| 10/10 [00:01<00:00,  8.64it/s, train_loss=100.0, val_r2_score=0.118]
# Epoch 19: 100%|███████████████████| 10/10 [00:01<00:00,  8.73it/s, train_loss=99.80, val_r2_score=0.102]
# Epoch 20: 100%|███████████████████| 10/10 [00:01<00:00,  8.45it/s, train_loss=89.10, val_r2_score=0.108]
# Epoch 21: 100%|███████████████████| 10/10 [00:01<00:00,  8.71it/s, train_loss=87.50, val_r2_score=0.117]
# Epoch 22: 100%|██████████████████| 10/10 [00:01<00:00,  8.56it/s, train_loss=83.50, val_r2_score=0.0574]
# Epoch 23: 100%|███████████████████| 10/10 [00:01<00:00,  8.47it/s, train_loss=87.40, val_r2_score=0.210]
# Epoch 24: 100%|███████████████████| 10/10 [00:01<00:00,  8.69it/s, train_loss=76.00, val_r2_score=0.115]
# Epoch 25: 100%|███████████████████| 10/10 [00:01<00:00,  8.60it/s, train_loss=70.60, val_r2_score=0.129]
# Epoch 26: 100%|███████████████████| 10/10 [00:01<00:00,  7.46it/s, train_loss=69.80, val_r2_score=0.194]
# Epoch 27: 100%|██████████████████| 10/10 [00:01<00:00,  8.65it/s, train_loss=59.40, val_r2_score=0.0642]
# Epoch 28: 100%|███████████████████| 10/10 [00:01<00:00,  7.67it/s, train_loss=59.80, val_r2_score=0.153]
# Epoch 29: 100%|███████████████████| 10/10 [00:01<00:00,  8.54it/s, train_loss=49.30, val_r2_score=0.170]
# Epoch 29: 100%|███████████████████| 10/10 [00:02<00:00,  4.36it/s, train_loss=61.80, val_r2_score=0.116]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████| 10/10 [00:02<00:00,  4.32it/s, train_loss=61.80, val_r2_score=0.116]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.01756865978240967
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  100
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_time  task type:  reg  task num:  2 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# Train data shape (100, 92)
# Test data shape (3110, 92)
# Val data shape (100, 92)
# Time to process data for one learning task:  0.02534031867980957
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 163.37it/s]
# Epoch 1: 100%|█████████████████| 10/10 [00:01<00:00,  9.08it/s, train_loss=2.79e+4, val_r2_score=-0.875]
# Epoch 2: 100%|█████████████████| 10/10 [00:01<00:00,  8.81it/s, train_loss=2.67e+4, val_r2_score=-0.772]
# Epoch 3: 100%|█████████████████| 10/10 [00:01<00:00,  8.67it/s, train_loss=2.55e+4, val_r2_score=-0.667]
# Epoch 4: 100%|██████████████████| 10/10 [00:01<00:00,  9.00it/s, train_loss=2.42e+4, val_r2_score=-0.55]
# Epoch 5: 100%|█████████████████| 10/10 [00:01<00:00,  8.76it/s, train_loss=2.27e+4, val_r2_score=-0.412]
# Epoch 6: 100%|█████████████████| 10/10 [00:01<00:00,  8.95it/s, train_loss=2.07e+4, val_r2_score=-0.259]
# Epoch 7: 100%|████████████████| 10/10 [00:01<00:00,  8.92it/s, train_loss=1.86e+4, val_r2_score=-0.0983]
# Epoch 8: 100%|█████████████████| 10/10 [00:01<00:00,  8.75it/s, train_loss=1.66e+4, val_r2_score=0.0283]
# Epoch 9: 100%|██████████████████| 10/10 [00:01<00:00,  8.48it/s, train_loss=1.47e+4, val_r2_score=0.141]
# Epoch 10: 100%|█████████████████| 10/10 [00:01<00:00,  8.75it/s, train_loss=1.26e+4, val_r2_score=0.233]
# Epoch 11: 100%|█████████████████| 10/10 [00:01<00:00,  8.68it/s, train_loss=1.07e+4, val_r2_score=0.309]
# Epoch 12: 100%|█████████████████| 10/10 [00:01<00:00,  8.97it/s, train_loss=9.99e+3, val_r2_score=0.371]
# Epoch 13: 100%|█████████████████| 10/10 [00:01<00:00,  8.46it/s, train_loss=8.78e+3, val_r2_score=0.425]
# Epoch 14: 100%|█████████████████| 10/10 [00:01<00:00,  8.63it/s, train_loss=8.03e+3, val_r2_score=0.467]
# Epoch 15: 100%|█████████████████| 10/10 [00:01<00:00,  8.72it/s, train_loss=7.72e+3, val_r2_score=0.503]
# Epoch 16: 100%|█████████████████| 10/10 [00:01<00:00,  8.64it/s, train_loss=7.36e+3, val_r2_score=0.541]
# Epoch 17: 100%|█████████████████| 10/10 [00:01<00:00,  8.64it/s, train_loss=6.25e+3, val_r2_score=0.567]
# Epoch 18: 100%|█████████████████| 10/10 [00:01<00:00,  7.75it/s, train_loss=6.23e+3, val_r2_score=0.592]
# Epoch 19: 100%|████████████████████| 10/10 [00:01<00:00,  8.80it/s, train_loss=6e+3, val_r2_score=0.618]
# Epoch 20: 100%|█████████████████| 10/10 [00:01<00:00,  8.77it/s, train_loss=5.57e+3, val_r2_score=0.639]
# Epoch 21: 100%|█████████████████| 10/10 [00:01<00:00,  8.89it/s, train_loss=5.44e+3, val_r2_score=0.655]
# Epoch 22: 100%|█████████████████| 10/10 [00:01<00:00,  8.79it/s, train_loss=5.19e+3, val_r2_score=0.669]
# Epoch 23: 100%|██████████████████| 10/10 [00:01<00:00,  8.84it/s, train_loss=4.5e+3, val_r2_score=0.680]
# Epoch 24: 100%|█████████████████| 10/10 [00:01<00:00,  9.01it/s, train_loss=4.42e+3, val_r2_score=0.690]
# Epoch 25: 100%|█████████████████| 10/10 [00:01<00:00,  8.84it/s, train_loss=4.31e+3, val_r2_score=0.694]
# Epoch 26: 100%|█████████████████| 10/10 [00:01<00:00,  8.61it/s, train_loss=4.02e+3, val_r2_score=0.702]
# Epoch 27: 100%|█████████████████| 10/10 [00:01<00:00,  8.85it/s, train_loss=3.86e+3, val_r2_score=0.706]
# Epoch 28: 100%|█████████████████| 10/10 [00:01<00:00,  6.95it/s, train_loss=3.34e+3, val_r2_score=0.707]
# Epoch 29: 100%|█████████████████| 10/10 [00:01<00:00,  8.95it/s, train_loss=3.77e+3, val_r2_score=0.708]
# Epoch 29: 100%|█████████████████| 10/10 [00:02<00:00,  4.50it/s, train_loss=3.04e+3, val_r2_score=0.713]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████| 10/10 [00:02<00:00,  4.45it/s, train_loss=3.04e+3, val_r2_score=0.713]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.017316818237304688
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  100
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_time  task type:  reg  task num:  3 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# Train data shape (100, 92)
# Test data shape (3105, 92)
# Val data shape (100, 92)
# Time to process data for one learning task:  0.02409529685974121
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 171.72it/s]
# Epoch 1: 100%|█████████████████| 10/10 [00:01<00:00,  9.03it/s, train_loss=2.83e+4, val_r2_score=-0.752]
# Epoch 2: 100%|█████████████████| 10/10 [00:01<00:00,  8.00it/s, train_loss=2.71e+4, val_r2_score=-0.674]
# Epoch 3: 100%|█████████████████| 10/10 [00:01<00:00,  8.90it/s, train_loss=2.58e+4, val_r2_score=-0.595]
# Epoch 4: 100%|█████████████████| 10/10 [00:01<00:00,  8.86it/s, train_loss=2.43e+4, val_r2_score=-0.509]
# Epoch 5: 100%|██████████████████| 10/10 [00:01<00:00,  7.69it/s, train_loss=2.26e+4, val_r2_score=-0.41]
# Epoch 6: 100%|█████████████████| 10/10 [00:01<00:00,  8.84it/s, train_loss=2.06e+4, val_r2_score=-0.298]
# Epoch 7: 100%|█████████████████| 10/10 [00:01<00:00,  8.97it/s, train_loss=1.88e+4, val_r2_score=-0.175]
# Epoch 8: 100%|████████████████| 10/10 [00:01<00:00,  8.96it/s, train_loss=1.57e+4, val_r2_score=-0.0667]
# Epoch 9: 100%|█████████████████| 10/10 [00:01<00:00,  8.83it/s, train_loss=1.38e+4, val_r2_score=0.0286]
# Epoch 10: 100%|█████████████████| 10/10 [00:01<00:00,  9.00it/s, train_loss=1.11e+4, val_r2_score=0.112]
# Epoch 11: 100%|█████████████████| 10/10 [00:01<00:00,  8.86it/s, train_loss=9.11e+3, val_r2_score=0.194]
# Epoch 12: 100%|█████████████████| 10/10 [00:01<00:00,  9.13it/s, train_loss=8.14e+3, val_r2_score=0.275]
# Epoch 13: 100%|████████████████████| 10/10 [00:01<00:00,  8.80it/s, train_loss=7e+3, val_r2_score=0.346]
# Epoch 14: 100%|█████████████████| 10/10 [00:01<00:00,  8.77it/s, train_loss=6.51e+3, val_r2_score=0.387]
# Epoch 15: 100%|█████████████████| 10/10 [00:01<00:00,  8.93it/s, train_loss=5.99e+3, val_r2_score=0.425]
# Epoch 16: 100%|██████████████████| 10/10 [00:01<00:00,  8.65it/s, train_loss=5.8e+3, val_r2_score=0.449]
# Epoch 17: 100%|█████████████████| 10/10 [00:01<00:00,  8.81it/s, train_loss=5.49e+3, val_r2_score=0.472]
# Epoch 18: 100%|█████████████████| 10/10 [00:01<00:00,  8.94it/s, train_loss=5354.75, val_r2_score=0.480]
# Epoch 19: 100%|█████████████████| 10/10 [00:01<00:00,  8.86it/s, train_loss=5.34e+3, val_r2_score=0.505]
# Epoch 20: 100%|█████████████████| 10/10 [00:01<00:00,  8.86it/s, train_loss=5.34e+3, val_r2_score=0.522]
# Epoch 21: 100%|█████████████████| 10/10 [00:01<00:00,  8.93it/s, train_loss=4.82e+3, val_r2_score=0.529]
# Epoch 22: 100%|██████████████████| 10/10 [00:01<00:00,  8.93it/s, train_loss=4.5e+3, val_r2_score=0.545]
# Epoch 23: 100%|█████████████████| 10/10 [00:01<00:00,  8.76it/s, train_loss=4.02e+3, val_r2_score=0.558]
# Epoch 24: 100%|█████████████████| 10/10 [00:01<00:00,  8.96it/s, train_loss=4.21e+3, val_r2_score=0.575]
# Epoch 25: 100%|█████████████████| 10/10 [00:01<00:00,  8.97it/s, train_loss=3.43e+3, val_r2_score=0.585]
# Epoch 26: 100%|█████████████████| 10/10 [00:01<00:00,  8.91it/s, train_loss=3.59e+3, val_r2_score=0.599]
# Epoch 27: 100%|█████████████████| 10/10 [00:01<00:00,  8.81it/s, train_loss=3.42e+3, val_r2_score=0.616]
# Epoch 28: 100%|█████████████████| 10/10 [00:01<00:00,  8.97it/s, train_loss=3.53e+3, val_r2_score=0.617]
# Epoch 29: 100%|█████████████████| 10/10 [00:01<00:00,  8.80it/s, train_loss=3.21e+3, val_r2_score=0.628]
# Epoch 29: 100%|█████████████████| 10/10 [00:02<00:00,  4.47it/s, train_loss=3.03e+3, val_r2_score=0.643]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████| 10/10 [00:02<00:00,  4.42it/s, train_loss=3.03e+3, val_r2_score=0.643]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.017940688133239745
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  100
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  delay_trace.txt_dl_delay  task type:  reg  task num:  4 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179730, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179703, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# Train data shape (100, 92)
# Test data shape (174864, 92)
# Val data shape (100, 92)
# Time to process data for one learning task:  0.909857988357544
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 130.72it/s]
# Epoch 1: 100%|█████████████████| 10/10 [00:01<00:00,  8.42it/s, train_loss=1.12e+3, val_r2_score=-0.154]
# Epoch 2: 100%|███████████████████| 10/10 [00:01<00:00,  8.62it/s, train_loss=1e+3, val_r2_score=-0.0907]
# Epoch 3: 100%|██████████████████| 10/10 [00:01<00:00,  8.40it/s, train_loss=947.0, val_r2_score=-0.0517]
# Epoch 4: 100%|██████████████████| 10/10 [00:01<00:00,  8.48it/s, train_loss=899.0, val_r2_score=-0.0276]
# Epoch 5: 100%|█████████████████| 10/10 [00:01<00:00,  8.24it/s, train_loss=865.0, val_r2_score=-0.00562]
# Epoch 6: 100%|███████████████████| 10/10 [00:01<00:00,  8.63it/s, train_loss=817.0, val_r2_score=0.0143]
# Epoch 7: 100%|███████████████████| 10/10 [00:01<00:00,  8.50it/s, train_loss=791.0, val_r2_score=0.0356]
# Epoch 8: 100%|███████████████████| 10/10 [00:01<00:00,  8.34it/s, train_loss=768.0, val_r2_score=0.0586]
# Epoch 9: 100%|███████████████████| 10/10 [00:01<00:00,  8.27it/s, train_loss=719.0, val_r2_score=0.0793]
# Epoch 10: 100%|██████████████████| 10/10 [00:01<00:00,  8.38it/s, train_loss=671.0, val_r2_score=0.0976]
# Epoch 11: 100%|███████████████████| 10/10 [00:01<00:00,  8.39it/s, train_loss=668.0, val_r2_score=0.118]
# Epoch 12: 100%|███████████████████| 10/10 [00:01<00:00,  8.18it/s, train_loss=625.0, val_r2_score=0.137]
# Epoch 13: 100%|███████████████████| 10/10 [00:01<00:00,  8.42it/s, train_loss=571.0, val_r2_score=0.154]
# Epoch 14: 100%|███████████████████| 10/10 [00:01<00:00,  8.36it/s, train_loss=567.0, val_r2_score=0.167]
# Epoch 15: 100%|███████████████████| 10/10 [00:01<00:00,  8.28it/s, train_loss=534.0, val_r2_score=0.176]
# Epoch 16: 100%|███████████████████| 10/10 [00:01<00:00,  8.18it/s, train_loss=533.0, val_r2_score=0.185]
# Epoch 17: 100%|███████████████████| 10/10 [00:01<00:00,  6.99it/s, train_loss=499.0, val_r2_score=0.195]
# Epoch 18: 100%|███████████████████| 10/10 [00:01<00:00,  8.58it/s, train_loss=454.0, val_r2_score=0.210]
# Epoch 19: 100%|███████████████████| 10/10 [00:01<00:00,  8.63it/s, train_loss=439.0, val_r2_score=0.223]
# Epoch 20: 100%|███████████████████| 10/10 [00:01<00:00,  8.46it/s, train_loss=410.0, val_r2_score=0.235]
# Epoch 21: 100%|███████████████████| 10/10 [00:01<00:00,  8.58it/s, train_loss=387.0, val_r2_score=0.247]
# Epoch 22: 100%|███████████████████| 10/10 [00:01<00:00,  8.50it/s, train_loss=366.0, val_r2_score=0.259]
# Epoch 23: 100%|███████████████████| 10/10 [00:01<00:00,  8.47it/s, train_loss=373.0, val_r2_score=0.271]
# Epoch 24: 100%|███████████████████| 10/10 [00:01<00:00,  8.39it/s, train_loss=323.0, val_r2_score=0.280]
# Epoch 25: 100%|███████████████████| 10/10 [00:01<00:00,  8.54it/s, train_loss=304.0, val_r2_score=0.292]
# Epoch 26: 100%|███████████████████| 10/10 [00:01<00:00,  8.38it/s, train_loss=304.0, val_r2_score=0.306]
# Epoch 27: 100%|███████████████████| 10/10 [00:01<00:00,  8.30it/s, train_loss=251.0, val_r2_score=0.320]
# Epoch 28: 100%|███████████████████| 10/10 [00:01<00:00,  8.52it/s, train_loss=219.0, val_r2_score=0.331]
# Epoch 29: 100%|███████████████████| 10/10 [00:01<00:00,  8.48it/s, train_loss=251.0, val_r2_score=0.343]
# Epoch 29: 100%|███████████████████| 10/10 [00:02<00:00,  4.31it/s, train_loss=222.0, val_r2_score=0.352]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████| 10/10 [00:02<00:00,  4.25it/s, train_loss=222.0, val_r2_score=0.352]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.019598174095153808
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# Time to run experiments for rand itr  0  for num labeled samples  100 :  424.3308906555176
#
# ===============================  DONE with this random iteration  ===================================================
# ============================= Train set mean over runs ===================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.145258  1.075354  0.788014
# vrFragment_trace.txt_vr_burst_thput_mbps   4.262357  0.548216  0.859230
# vrFragment_trace.txt_vr_frag_time         38.798840  0.935047  0.808049
# vrFragment_trace.txt_vr_burst_time        35.009204  0.770758  0.820986
# delay_trace.txt_dl_delay                   4.957637  0.475387  0.811748
# =============================== Test set results =========================================
#                                                MAE     MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    [0.424]  [3.799]  [-0.394]
# vrFragment_trace.txt_vr_burst_thput_mbps  [11.916]  [2.242]   [0.236]
# vrFragment_trace.txt_vr_frag_time         [36.420]  [0.938]   [0.676]
# vrFragment_trace.txt_vr_burst_time        [38.101]  [1.212]   [0.628]
# delay_trace.txt_dl_delay                  [11.102]  [1.118]   [0.240]
# ============================= Test set mean over runs ====================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.424300  3.799024 -0.394208
# vrFragment_trace.txt_vr_burst_thput_mbps  11.915616  2.242285  0.236415
# vrFragment_trace.txt_vr_frag_time         36.420488  0.937775  0.676386
# vrFragment_trace.txt_vr_burst_time        38.101253  1.212497  0.628271
# delay_trace.txt_dl_delay                  11.101659  1.118416  0.240089
# ==========================================================================================
# Time to run experiments for  100  labeled samples:  424.3517520427704
#
# ===============================  DONE with this num labeled samples size  ===================================================
# Time to run the whole script:  424.35178327560425
# ===============================  EVERYTHING DONE  ===========================================
