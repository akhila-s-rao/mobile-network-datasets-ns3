# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(SP_results_folder='rando_test_batchSize10_50', # This folder will be created and the results csv files stored there 
             pred_head_type = 'ts3l',
             pt_type ='dae',
             pt_folder = 'FP2',
             pretrain=False, # if True First Phase training
             use_pretrained_model=True, 
             freeze_encoder=False,
             pred_head_size = 1, 
             shift_samp_for_predict = True)
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# rand_itr:  0  train_runs:  [11]  test_runs:  [12]
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  3.016934871673584
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  2.9445419311523438
# Loaded run 12
# Time to read data:  15.181922674179077
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# Train data shape (1000, 92)
# Test data shape (2439, 92)
# Val data shape (813, 92)
# Time to process data for one learning task:  0.01993083953857422
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
#    | Name                                             | Type       | Params | Mode
# -----------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss    | 0      | train
# 1  | mask_loss_fn                                     | BCELoss    | 0      | train
# 2  | categorical_feature_loss                         | BCELoss    | 0      | train
# 3  | continuous_feature_loss                          | MSELoss    | 0      | train
# 4  | model                                            | DAE        | 357 K  | train
# 5  | model._DAE__encoder                              | MLP        | 139 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear     | 18.6 K | train
# 7  | model._DAE__encoder.relu_0                       | ReLU       | 0      | train
# 8  | model._DAE__encoder.dropout_0                    | Dropout    | 0      | train
# 9  | model._DAE__encoder.linear_1                     | Linear     | 40.2 K | train
# 10 | model._DAE__encoder.relu_1                       | ReLU       | 0      | train
# 11 | model._DAE__encoder.dropout_1                    | Dropout    | 0      | train
# 12 | model._DAE__encoder.linear_2                     | Linear     | 40.2 K | train
# 13 | model._DAE__encoder.relu_2                       | ReLU       | 0      | train
# 14 | model._DAE__encoder.dropout_2                    | Dropout    | 0      | train
# 15 | model._DAE__encoder.last_layer                   | Linear     | 40.2 K | train
# 16 | model.mask_predictor_head                        | MLP        | 58.7 K | train
# 17 | model.mask_predictor_head.linear_0               | Linear     | 40.2 K | train
# 18 | model.mask_predictor_head.relu_0                 | ReLU       | 0      | train
# 19 | model.mask_predictor_head.dropout_0              | Dropout    | 0      | train
# 20 | model.mask_predictor_head.last_layer             | Linear     | 18.5 K | train
# 21 | model.reconstruction_head                        | MLP        | 58.7 K | train
# 22 | model.reconstruction_head.linear_0               | Linear     | 40.2 K | train
# 23 | model.reconstruction_head.relu_0                 | ReLU       | 0      | train
# 24 | model.reconstruction_head.dropout_0              | Dropout    | 0      | train
# 25 | model.reconstruction_head.last_layer             | Linear     | 18.5 K | train
# 26 | model.one_layer_prediction_head                  | Sequential | 40.4 K | train
# 27 | model.one_layer_prediction_head.head_linear_hid  | Linear     | 40.2 K | train
# 28 | model.one_layer_prediction_head.head_activation  | ReLU       | 0      | train
# 29 | model.one_layer_prediction_head.head_linear_out  | Linear     | 201    | train
# 30 | model.two_layer_prediction_head                  | Sequential | 60.4 K | train
# 31 | model.two_layer_prediction_head.head_linear_hid1 | Linear     | 40.2 K | train
# 32 | model.two_layer_prediction_head.head_activation1 | ReLU       | 0      | train
# 33 | model.two_layer_prediction_head.head_linear_hid2 | Linear     | 20.1 K | train
# 34 | model.two_layer_prediction_head.head_activation2 | ReLU       | 0      | train
# 35 | model.two_layer_prediction_head.head_linear_out  | Linear     | 101    | train
# -----------------------------------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# HYPERPARAMETERS:  {'batch_size': 10, 'max_epochs': 30, 'patience': 5, 'loss': {'reg': 'MSELoss', 'clas': 'CrossEntropyLoss'}, 'metrics': {'reg': ['r2_score'], 'clas': ['Recall']}}
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 148.74it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.99it/s, train_loss=1.250, val_r2_score=-1.05]
# Epoch 2: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.10it/s, train_loss=0.444, val_r2_score=-0.60]
# Epoch 3: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.34it/s, train_loss=0.358, val_r2_score=-0.47]
# Epoch 4: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.71it/s, train_loss=0.268, val_r2_score=-0.681]
# Epoch 5: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.62it/s, train_loss=0.260, val_r2_score=-0.588]
# Epoch 6: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 52.66it/s, train_loss=0.201, val_r2_score=-0.367]
# Epoch 7: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 64.89it/s, train_loss=0.209, val_r2_score=-0.202]
# Epoch 8: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.58it/s, train_loss=0.181, val_r2_score=-0.353]
# Epoch 9: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.30it/s, train_loss=0.170, val_r2_score=-0.214]
# Epoch 10: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.04it/s, train_loss=0.151, val_r2_score=-0.224]
# Epoch 11: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.45it/s, train_loss=0.145, val_r2_score=-0.171]
# Epoch 12: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.88it/s, train_loss=0.205, val_r2_score=-0.398]
# Epoch 13: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.10it/s, train_loss=0.170, val_r2_score=0.140]
# Epoch 14: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.35it/s, train_loss=0.125, val_r2_score=-0.162]
# Epoch 15: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.56it/s, train_loss=0.116, val_r2_score=0.116]
# Epoch 16: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.31it/s, train_loss=0.122, val_r2_score=0.153]
# Epoch 17: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.65it/s, train_loss=0.108, val_r2_score=0.122]
# Epoch 18: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.51it/s, train_loss=0.109, val_r2_score=0.314]
# Epoch 19: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.93it/s, train_loss=0.101, val_r2_score=0.199]
# Epoch 20: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.52it/s, train_loss=0.0932, val_r2_score=0.266]
# Epoch 21: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.58it/s, train_loss=0.0967, val_r2_score=0.266]
# Epoch 22: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.23it/s, train_loss=0.094, val_r2_score=0.216]
# Epoch 23: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.90it/s, train_loss=0.123, val_r2_score=0.344]
# Epoch 24: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.29it/s, train_loss=0.100, val_r2_score=0.150]
# Epoch 25: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.25it/s, train_loss=0.0883, val_r2_score=0.349]
# Epoch 26: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.94it/s, train_loss=0.0883, val_r2_score=0.117]
# Epoch 27: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.63it/s, train_loss=0.0907, val_r2_score=0.381]
# Epoch 28: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.39it/s, train_loss=0.0947, val_r2_score=0.261]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.70it/s, train_loss=0.089, val_r2_score=0.324]
# Epoch 29: 100%|████████████████████████████████████████████████| 100/100 [00:02<00:00, 33.83it/s, train_loss=0.0786, val_r2_score=0.177]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|████████████████████████████████████████████████| 100/100 [00:02<00:00, 33.59it/s, train_loss=0.0786, val_r2_score=0.177]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.0033381342887878417
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_thput_mbps  task type:  reg  task num:  1 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# Train data shape (1000, 92)
# Test data shape (2436, 92)
# Val data shape (812, 92)
# Time to process data for one learning task:  0.029036998748779297
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 196.47it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.90it/s, train_loss=288.0, val_r2_score=0.258]
# Epoch 2: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.86it/s, train_loss=175.0, val_r2_score=0.354]
# Epoch 3: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.53it/s, train_loss=142.0, val_r2_score=0.466]
# Epoch 4: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.48it/s, train_loss=127.0, val_r2_score=0.501]
# Epoch 5: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.75it/s, train_loss=117.0, val_r2_score=0.521]
# Epoch 6: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.54it/s, train_loss=110.0, val_r2_score=0.550]
# Epoch 7: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.78it/s, train_loss=110.0, val_r2_score=0.546]
# Epoch 8: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.25it/s, train_loss=102.0, val_r2_score=0.577]
# Epoch 9: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.20it/s, train_loss=96.80, val_r2_score=0.539]
# Epoch 10: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.57it/s, train_loss=97.50, val_r2_score=0.588]
# Epoch 11: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.37it/s, train_loss=94.80, val_r2_score=0.599]
# Epoch 12: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.31it/s, train_loss=91.80, val_r2_score=0.578]
# Epoch 13: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.59it/s, train_loss=88.90, val_r2_score=0.570]
# Epoch 14: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.71it/s, train_loss=86.90, val_r2_score=0.613]
# Epoch 15: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.83it/s, train_loss=87.00, val_r2_score=0.578]
# Epoch 16: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.86it/s, train_loss=83.90, val_r2_score=0.599]
# Epoch 17: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.77it/s, train_loss=81.10, val_r2_score=0.613]
# Epoch 18: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.49it/s, train_loss=82.40, val_r2_score=0.576]
# Epoch 19: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.53it/s, train_loss=79.10, val_r2_score=0.619]
# Epoch 20: 100%|█████████████████████████████████████████████████| 100/100 [00:03<00:00, 32.81it/s, train_loss=76.50, val_r2_score=0.604]
# Epoch 21: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.68it/s, train_loss=76.50, val_r2_score=0.604]
# Epoch 22: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.85it/s, train_loss=76.80, val_r2_score=0.529]
# Epoch 23: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.96it/s, train_loss=76.00, val_r2_score=0.611]
# Epoch 24: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.75it/s, train_loss=72.90, val_r2_score=0.612]
# Epoch 25: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.15it/s, train_loss=67.00, val_r2_score=0.606]
# Epoch 26: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.68it/s, train_loss=68.80, val_r2_score=0.587]
# Epoch 27: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.49it/s, train_loss=69.20, val_r2_score=0.617]
# Epoch 28: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.95it/s, train_loss=70.00, val_r2_score=0.618]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.52it/s, train_loss=65.60, val_r2_score=0.591]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.24it/s, train_loss=65.60, val_r2_score=0.618]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:02<00:00, 33.94it/s, train_loss=65.60, val_r2_score=0.618]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.0031090497970581053
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_time  task type:  reg  task num:  2 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# Train data shape (1000, 92)
# Test data shape (2408, 92)
# Val data shape (802, 92)
# Time to process data for one learning task:  0.023693561553955078
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 175.98it/s]
# Epoch 1: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.02it/s, train_loss=2.24e+4, val_r2_score=0.131]
# Epoch 2: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.77it/s, train_loss=1.05e+4, val_r2_score=0.508]
# Epoch 3: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.07it/s, train_loss=6.21e+3, val_r2_score=0.681]
# Epoch 4: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.93it/s, train_loss=4.41e+3, val_r2_score=0.770]
# Epoch 5: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.02it/s, train_loss=3.75e+3, val_r2_score=0.780]
# Epoch 6: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.12it/s, train_loss=3.47e+3, val_r2_score=0.793]
# Epoch 7: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.44it/s, train_loss=3.37e+3, val_r2_score=0.799]
# Epoch 8: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.45it/s, train_loss=3.25e+3, val_r2_score=0.807]
# Epoch 9: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 64.60it/s, train_loss=3.17e+3, val_r2_score=0.792]
# Epoch 10: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 58.66it/s, train_loss=3.06e+3, val_r2_score=0.811]
# Epoch 11: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.53it/s, train_loss=3.01e+3, val_r2_score=0.811]
# Epoch 12: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 63.44it/s, train_loss=2.95e+3, val_r2_score=0.810]
# Epoch 13: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.73it/s, train_loss=2.88e+3, val_r2_score=0.815]
# Epoch 14: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.23it/s, train_loss=2.7e+3, val_r2_score=0.813]
# Epoch 15: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.42it/s, train_loss=2.77e+3, val_r2_score=0.807]
# Epoch 16: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.38it/s, train_loss=2.58e+3, val_r2_score=0.815]
# Epoch 17: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.87it/s, train_loss=2.53e+3, val_r2_score=0.813]
# Epoch 18: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 63.22it/s, train_loss=2.57e+3, val_r2_score=0.817]
# Epoch 19: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.67it/s, train_loss=2.68e+3, val_r2_score=0.807]
# Epoch 20: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.77it/s, train_loss=2.49e+3, val_r2_score=0.807]
# Epoch 21: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.48it/s, train_loss=2.41e+3, val_r2_score=0.807]
# Epoch 22: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.01it/s, train_loss=2.38e+3, val_r2_score=0.817]
# Epoch 23: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.30it/s, train_loss=2.21e+3, val_r2_score=0.812]
# Epoch 24: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.24it/s, train_loss=2.24e+3, val_r2_score=0.805]
# Epoch 25: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.56it/s, train_loss=2.23e+3, val_r2_score=0.805]
# Epoch 26: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.34it/s, train_loss=2.09e+3, val_r2_score=0.799]
# Epoch 27: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.32it/s, train_loss=2.21e+3, val_r2_score=0.810]
# Epoch 28: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 65.70it/s, train_loss=2.26e+3, val_r2_score=0.802]
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.42it/s, train_loss=2.08e+3, val_r2_score=0.813]
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:02<00:00, 34.63it/s, train_loss=1.95e+3, val_r2_score=0.786]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:02<00:00, 34.34it/s, train_loss=1.95e+3, val_r2_score=0.786]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.003187205791473389
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_time  task type:  reg  task num:  3 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# Train data shape (1000, 92)
# Test data shape (2404, 92)
# Val data shape (801, 92)
# Time to process data for one learning task:  0.027138471603393555
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 165.51it/s]
# Epoch 1: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.26it/s, train_loss=2.3e+4, val_r2_score=0.0935]
# Epoch 2: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.08it/s, train_loss=1.04e+4, val_r2_score=0.428]
# Epoch 3: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.20it/s, train_loss=6.46e+3, val_r2_score=0.675]
# Epoch 4: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.35it/s, train_loss=4.62e+3, val_r2_score=0.747]
# Epoch 5: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.87it/s, train_loss=3.96e+3, val_r2_score=0.766]
# Epoch 6: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.87it/s, train_loss=3.47e+3, val_r2_score=0.758]
# Epoch 7: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.28it/s, train_loss=3.16e+3, val_r2_score=0.757]
# Epoch 8: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 66.01it/s, train_loss=3.12e+3, val_r2_score=0.783]
# Epoch 9: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.29it/s, train_loss=3.03e+3, val_r2_score=0.780]
# Epoch 10: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.36it/s, train_loss=2.86e+3, val_r2_score=0.774]
# Epoch 11: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.81it/s, train_loss=2.78e+3, val_r2_score=0.783]
# Epoch 12: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.77it/s, train_loss=2.74e+3, val_r2_score=0.779]
# Epoch 13: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 58.97it/s, train_loss=2.59e+3, val_r2_score=0.784]
# Epoch 14: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 64.74it/s, train_loss=2.69e+3, val_r2_score=0.780]
# Epoch 15: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.88it/s, train_loss=2.59e+3, val_r2_score=0.773]
# Epoch 16: 100%|████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.61it/s, train_loss=2.5e+3, val_r2_score=0.784]
# Epoch 17: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 60.59it/s, train_loss=2.45e+3, val_r2_score=0.777]
# Epoch 18: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.80it/s, train_loss=2.48e+3, val_r2_score=0.770]
# Epoch 19: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.55it/s, train_loss=2.46e+3, val_r2_score=0.778]
# Epoch 20: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.52it/s, train_loss=2.39e+3, val_r2_score=0.778]
# Epoch 21: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.68it/s, train_loss=2.35e+3, val_r2_score=0.772]
# Epoch 22: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.44it/s, train_loss=2.24e+3, val_r2_score=0.771]
# Epoch 23: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 59.75it/s, train_loss=2.37e+3, val_r2_score=0.776]
# Epoch 24: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.96it/s, train_loss=2.18e+3, val_r2_score=0.779]
# Epoch 25: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 60.89it/s, train_loss=2.09e+3, val_r2_score=0.776]
# Epoch 26: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.18it/s, train_loss=2.01e+3, val_r2_score=0.767]
# Epoch 27: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 62.72it/s, train_loss=2.07e+3, val_r2_score=0.765]
# Epoch 28: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.48it/s, train_loss=2.07e+3, val_r2_score=0.772]
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:01<00:00, 61.50it/s, train_loss=1.88e+3, val_r2_score=0.772]
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:02<00:00, 34.66it/s, train_loss=1.97e+3, val_r2_score=0.755]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████████████████████████████████| 100/100 [00:02<00:00, 34.34it/s, train_loss=1.97e+3, val_r2_score=0.755]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.003060882091522217
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  delay_trace.txt_dl_delay  task type:  reg  task num:  4 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179730, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179703, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# Train data shape (1000, 92)
# Test data shape (173964, 92)
# Val data shape (1000, 92)
# Time to process data for one learning task:  0.905132532119751
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 177.67it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.17it/s, train_loss=805.0, val_r2_score=0.154]
# Epoch 2: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.91it/s, train_loss=630.0, val_r2_score=0.277]
# Epoch 3: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.79it/s, train_loss=538.0, val_r2_score=0.353]
# Epoch 4: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.52it/s, train_loss=437.0, val_r2_score=0.430]
# Epoch 5: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.24it/s, train_loss=350.0, val_r2_score=0.512]
# Epoch 6: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.47it/s, train_loss=304.0, val_r2_score=0.539]
# Epoch 7: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.42it/s, train_loss=244.0, val_r2_score=0.531]
# Epoch 8: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.70it/s, train_loss=223.0, val_r2_score=0.568]
# Epoch 9: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.83it/s, train_loss=190.0, val_r2_score=0.566]
# Epoch 10: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.03it/s, train_loss=157.0, val_r2_score=0.582]
# Epoch 11: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.77it/s, train_loss=155.0, val_r2_score=0.580]
# Epoch 12: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 50.87it/s, train_loss=158.0, val_r2_score=0.593]
# Epoch 13: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.36it/s, train_loss=143.0, val_r2_score=0.597]
# Epoch 14: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.65it/s, train_loss=130.0, val_r2_score=0.609]
# Epoch 15: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.10it/s, train_loss=125.0, val_r2_score=0.605]
# Epoch 16: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.43it/s, train_loss=116.0, val_r2_score=0.592]
# Epoch 17: 100%|█████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.42it/s, train_loss=109.0, val_r2_score=0.608]
# Epoch 18: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.83it/s, train_loss=110.0, val_r2_score=0.549]
# Epoch 19: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.07it/s, train_loss=109.0, val_r2_score=0.609]
# Epoch 20: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.76it/s, train_loss=89.10, val_r2_score=0.564]
# Epoch 21: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.66it/s, train_loss=98.20, val_r2_score=0.556]
# Epoch 22: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.85it/s, train_loss=87.80, val_r2_score=0.598]
# Epoch 23: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.81it/s, train_loss=79.80, val_r2_score=0.609]
# Epoch 24: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.61it/s, train_loss=92.20, val_r2_score=0.589]
# Epoch 25: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.90it/s, train_loss=64.20, val_r2_score=0.602]
# Epoch 26: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.10it/s, train_loss=70.40, val_r2_score=0.602]
# Epoch 27: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.68it/s, train_loss=67.40, val_r2_score=0.584]
# Epoch 28: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.44it/s, train_loss=66.80, val_r2_score=0.598]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.12it/s, train_loss=66.90, val_r2_score=0.579]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:03<00:00, 33.20it/s, train_loss=59.00, val_r2_score=0.573]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:03<00:00, 32.89it/s, train_loss=59.00, val_r2_score=0.573]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.003278663158416748
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# Time to run experiments for rand itr  0  for num labeled samples  1000 :  512.7351384162903
#
# ===============================  DONE with this random iteration  ===================================================
# ============================= Train set mean over runs ===================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.147310  0.618048  0.743979
# vrFragment_trace.txt_vr_burst_thput_mbps   4.652042  0.563197  0.812443
# vrFragment_trace.txt_vr_frag_time         26.848912  0.465823  0.882944
# vrFragment_trace.txt_vr_burst_time        26.804725  0.568496  0.897145
# delay_trace.txt_dl_delay                   2.901800  0.264005  0.951103
# =============================== Test set results =========================================
#                                                MAE     MAPE       R2
# vrFragment_trace.txt_vr_frag_thput_mbps    [0.258]  [1.240]  [0.347]
# vrFragment_trace.txt_vr_burst_thput_mbps   [7.230]  [0.933]  [0.611]
# vrFragment_trace.txt_vr_frag_time         [28.654]  [0.685]  [0.721]
# vrFragment_trace.txt_vr_burst_time        [29.248]  [0.931]  [0.769]
# delay_trace.txt_dl_delay                   [6.927]  [0.487]  [0.555]
# ============================= Test set mean over runs ====================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.258368  1.240025  0.346747
# vrFragment_trace.txt_vr_burst_thput_mbps   7.229554  0.932692  0.610932
# vrFragment_trace.txt_vr_frag_time         28.654281  0.684821  0.720875
# vrFragment_trace.txt_vr_burst_time        29.247726  0.930959  0.769297
# delay_trace.txt_dl_delay                   6.927362  0.486632  0.554525
# ==========================================================================================
# Time to run experiments for  1000  labeled samples:  512.7523949146271
#
# ===============================  DONE with this num labeled samples size  ===================================================
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  2.915637254714966
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  2.9844207763671875
# Seed set to 42
# Loaded run 12
# Time to read data:  15.072316646575928
# ==========================================================================
# NUM. LABELLED SAMPLES:  20000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
#
#
# WARNING !!!!
#
# Asked to sample from train set of size 3256 a number greater than or equal to its size 20000
# Going to just take as many samples as available, No need to random sample
# Train data shape (3256, 92)
# Test data shape (2439, 92)
# Val data shape (813, 92)
# Time to process data for one learning task:  0.02092146873474121
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 66/66 [00:00<00:00, 182.36it/s]
# Epoch 1: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.50it/s, train_loss=1.280, val_r2_score=-0.853]
# Epoch 2: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.71it/s, train_loss=0.415, val_r2_score=-0.475]
# Epoch 3: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.71it/s, train_loss=0.320, val_r2_score=-0.221]
# Epoch 4: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.03it/s, train_loss=0.286, val_r2_score=-0.0979]
# Epoch 5: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.13it/s, train_loss=0.230, val_r2_score=-0.00107]
# Epoch 6: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.50it/s, train_loss=0.196, val_r2_score=0.0522]
# Epoch 7: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.06it/s, train_loss=0.187, val_r2_score=0.0678]
# Epoch 8: 100%|████████████████████████████████████████████████████| 66/66 [00:01<00:00, 44.01it/s, train_loss=0.169, val_r2_score=0.153]
# Epoch 9: 100%|████████████████████████████████████████████████████| 66/66 [00:01<00:00, 41.78it/s, train_loss=0.161, val_r2_score=0.163]
# Epoch 10: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.94it/s, train_loss=0.149, val_r2_score=0.150]
# Epoch 11: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.36it/s, train_loss=0.137, val_r2_score=0.170]
# Epoch 12: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.21it/s, train_loss=0.144, val_r2_score=0.166]
# Epoch 13: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.02it/s, train_loss=0.130, val_r2_score=0.292]
# Epoch 14: 100%|███████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.71it/s, train_loss=0.121, val_r2_score=0.292]
# ...
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
#
#
# WARNING !!!!
#
# Asked to sample from train set of size 3255 a number greater than or equal to its size 20000
# Going to just take as many samples as available, No need to random sample
# Train data shape (3255, 92)
# Test data shape (2404, 92)
# Val data shape (801, 92)
# Time to process data for one learning task:  0.023740053176879883
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 66/66 [00:00<00:00, 172.90it/s]
# Epoch 1: 100%|████████████████████████████████████████████████| 66/66 [00:02<00:00, 31.20it/s, train_loss=2.46e+4, val_r2_score=-0.0165]
# Epoch 2: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.92it/s, train_loss=1.23e+4, val_r2_score=0.353]
# Epoch 3: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.97it/s, train_loss=6.87e+3, val_r2_score=0.638]
# Epoch 4: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.42it/s, train_loss=4.79e+3, val_r2_score=0.722]
# Epoch 5: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.27it/s, train_loss=3.91e+3, val_r2_score=0.734]
# Epoch 6: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 36.00it/s, train_loss=3.72e+3, val_r2_score=0.752]
# Epoch 7: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 35.64it/s, train_loss=3.53e+3, val_r2_score=0.766]
# Epoch 8: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 36.03it/s, train_loss=3.29e+3, val_r2_score=0.781]
# Epoch 9: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.47it/s, train_loss=3.23e+3, val_r2_score=0.793]
# Epoch 10: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.91it/s, train_loss=3.14e+3, val_r2_score=0.799]
# Epoch 11: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.37it/s, train_loss=3.13e+3, val_r2_score=0.785]
# Epoch 12: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.84it/s, train_loss=3.06e+3, val_r2_score=0.787]
# Epoch 13: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.49it/s, train_loss=3.02e+3, val_r2_score=0.794]
# Epoch 14: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.20it/s, train_loss=2.95e+3, val_r2_score=0.786]
# Epoch 15: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.15it/s, train_loss=2.93e+3, val_r2_score=0.803]
# Epoch 16: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.76it/s, train_loss=3.1e+3, val_r2_score=0.793]
# Epoch 17: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.31it/s, train_loss=2.96e+3, val_r2_score=0.807]
# Epoch 18: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.38it/s, train_loss=2.94e+3, val_r2_score=0.791]
# Epoch 19: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 44.70it/s, train_loss=2.85e+3, val_r2_score=0.806]
# Epoch 20: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.35it/s, train_loss=2.92e+3, val_r2_score=0.812]
# Epoch 21: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.73it/s, train_loss=2.86e+3, val_r2_score=0.810]
# Epoch 22: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 40.70it/s, train_loss=2.75e+3, val_r2_score=0.805]
# Epoch 23: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.80it/s, train_loss=2.79e+3, val_r2_score=0.811]
# Epoch 24: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.29it/s, train_loss=2.74e+3, val_r2_score=0.791]
# Epoch 25: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.57it/s, train_loss=2.67e+3, val_r2_score=0.797]
# Epoch 26: 100%|██████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.21it/s, train_loss=2.9e+3, val_r2_score=0.816]
# Epoch 27: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 43.59it/s, train_loss=2.71e+3, val_r2_score=0.816]
# Epoch 28: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 44.27it/s, train_loss=2.69e+3, val_r2_score=0.814]
# Epoch 29: 100%|█████████████████████████████████████████████████| 66/66 [00:01<00:00, 42.23it/s, train_loss=2.66e+3, val_r2_score=0.817]
# Epoch 29: 100%|█████████████████████████████████████████████████| 66/66 [00:02<00:00, 23.77it/s, train_loss=2.68e+3, val_r2_score=0.796]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 66/66 [00:02<00:00, 23.55it/s, train_loss=2.68e+3, val_r2_score=0.796]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.004105560607441376
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  20000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  delay_trace.txt_dl_delay  task type:  reg  task num:  4 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179730, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179703, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# Train data shape (20000, 92)
# Test data shape (154964, 92)
# Val data shape (20000, 92)
# Time to process data for one learning task:  0.9136953353881836
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 400/400 [00:02<00:00, 167.61it/s]
# Epoch 1: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 116.37it/s, train_loss=526.0, val_r2_score=0.575]
# Epoch 2: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 124.59it/s, train_loss=298.0, val_r2_score=0.633]
# Epoch 3: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 106.90it/s, train_loss=260.0, val_r2_score=0.652]
# Epoch 4: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 112.29it/s, train_loss=243.0, val_r2_score=0.667]
# Epoch 5: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.21it/s, train_loss=234.0, val_r2_score=0.673]
# Epoch 6: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.58it/s, train_loss=230.0, val_r2_score=0.673]
# Epoch 7: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 118.37it/s, train_loss=222.0, val_r2_score=0.686]
# Epoch 8: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 111.50it/s, train_loss=214.0, val_r2_score=0.683]
# Epoch 9: 100%|█████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.40it/s, train_loss=211.0, val_r2_score=0.673]
# Epoch 10: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 118.89it/s, train_loss=206.0, val_r2_score=0.694]
# Epoch 11: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.65it/s, train_loss=203.0, val_r2_score=0.689]
# Epoch 12: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 114.58it/s, train_loss=198.0, val_r2_score=0.698]
# Epoch 13: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 113.89it/s, train_loss=198.0, val_r2_score=0.700]
# Epoch 14: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.33it/s, train_loss=190.0, val_r2_score=0.701]
# Epoch 15: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 112.77it/s, train_loss=188.0, val_r2_score=0.702]
# Epoch 16: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 122.18it/s, train_loss=187.0, val_r2_score=0.704]
# Epoch 17: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 113.77it/s, train_loss=184.0, val_r2_score=0.704]
# Epoch 18: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 115.43it/s, train_loss=182.0, val_r2_score=0.700]
# Epoch 19: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 116.03it/s, train_loss=179.0, val_r2_score=0.704]
# Epoch 20: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 114.95it/s, train_loss=178.0, val_r2_score=0.704]
# Epoch 21: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 113.75it/s, train_loss=174.0, val_r2_score=0.703]
# Epoch 22: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 120.27it/s, train_loss=173.0, val_r2_score=0.703]
# Epoch 23: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 114.99it/s, train_loss=172.0, val_r2_score=0.705]
# Epoch 24: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 114.07it/s, train_loss=168.0, val_r2_score=0.704]
# Epoch 25: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 116.58it/s, train_loss=163.0, val_r2_score=0.704]
# Epoch 26: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 116.40it/s, train_loss=162.0, val_r2_score=0.703]
# Epoch 27: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 120.34it/s, train_loss=157.0, val_r2_score=0.702]
# Epoch 28: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 116.27it/s, train_loss=156.0, val_r2_score=0.688]
# Epoch 29: 100%|████████████████████████████████████████████████| 400/400 [00:03<00:00, 127.69it/s, train_loss=158.0, val_r2_score=0.697]
# Epoch 29: 100%|█████████████████████████████████████████████████| 400/400 [00:05<00:00, 74.92it/s, train_loss=154.0, val_r2_score=0.678]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 400/400 [00:05<00:00, 74.53it/s, train_loss=154.0, val_r2_score=0.678]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.00203454852104187
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# Time to run experiments for rand itr  0  for num labeled samples  20000 :  546.811194896698
#
# ===============================  DONE with this random iteration  ===================================================
# ============================= Train set mean over runs ===================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.172692  1.292112  0.700276
# vrFragment_trace.txt_vr_burst_thput_mbps   5.233975  0.565098  0.755840
# vrFragment_trace.txt_vr_frag_time         28.729874  0.486643  0.851405
# vrFragment_trace.txt_vr_burst_time        30.163580  0.564082  0.846254
# delay_trace.txt_dl_delay                   4.955212  0.468834  0.820719
# =============================== Test set results =========================================
#                                                MAE     MAPE       R2
# vrFragment_trace.txt_vr_frag_thput_mbps    [0.272]  [1.875]  [0.393]
# vrFragment_trace.txt_vr_burst_thput_mbps   [7.188]  [0.799]  [0.611]
# vrFragment_trace.txt_vr_frag_time         [26.121]  [0.665]  [0.789]
# vrFragment_trace.txt_vr_burst_time        [27.559]  [0.770]  [0.782]
# delay_trace.txt_dl_delay                   [6.095]  [0.531]  [0.679]
# ============================= Test set mean over runs ====================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.271766  1.875281  0.392713
# vrFragment_trace.txt_vr_burst_thput_mbps   7.187564  0.798970  0.611251
# vrFragment_trace.txt_vr_frag_time         26.121235  0.665207  0.788974
# vrFragment_trace.txt_vr_burst_time        27.559429  0.769548  0.782386
# delay_trace.txt_dl_delay                   6.095101  0.531165  0.678665
# ==========================================================================================
# Time to run experiments for  20000  labeled samples:  546.8250541687012
#
# ===============================  DONE with this num labeled samples size  ===================================================
# Time to run the whole script:  1059.5775084495544
# ===============================  EVERYTHING DONE  ===========================================
