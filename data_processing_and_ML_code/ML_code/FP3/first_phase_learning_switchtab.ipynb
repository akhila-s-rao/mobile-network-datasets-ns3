# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='switchtab', 
             pt_folder='FP3')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  2.9840686321258545
# Loaded run 1
# Time to read csv file for run:  2.9549801349639893
# Loaded run 2
# Time to read csv file for run:  2.921977996826172
# Loaded run 3
# Time to read csv file for run:  2.9329946041107178
# Loaded run 4
# Time to read csv file for run:  2.9219396114349365
# Loaded run 5
# Time to read csv file for run:  2.6960198879241943
# Loaded run 6
# Time to read csv file for run:  2.953089714050293
# Loaded run 7
# Time to read csv file for run:  2.729836940765381
# Loaded run 8
# Time to read csv file for run:  2.908451557159424
# Loaded run 9
# Time to read csv file for run:  2.9225754737854004
# Loaded run 10
# Seed set to 42
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33026, 102)
# X_pretrain  (32705, 92)
# HYPERPARAMETERS:  {'loss_fn': 'MSELoss', 'metric': 'r2_score', 'hidden_dim': 200, 'max_epochs': 100, 'batch_size': 128, 'optim_hparams': {'lr': 0.0001, 'weight_decay': 5e-05}, 'encoder_depth': 1, 'corruption_rate': 0.3, 'dropout_rate': 0.1, 'n_head': 2, 'u_label': -1}
# refresh rate:  10
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                   | Type      | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn           | MSELoss   | 0      | train
# 1 | reconstruction_loss_fn | MSELoss   | 0      | train
# 2 | model                  | SwitchTab | 657 K  | train
# -------------------------------------------------------------
# 657 K     Trainable params
# 0         Non-trainable params
# 657 K     Total params
# 2.630     Total estimated model params size (MB)
# Epoch 0: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.94it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.81it/s, train_loss=1.180, val_loss=0.933]
# Epoch 2: 100%|██████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 24.10it/s, train_loss=0.915, val_loss=0.888]
# Epoch 3: 100%|██████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 24.07it/s, train_loss=0.860, val_loss=0.868]
# Epoch 4: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.57it/s, train_loss=0.846, val_loss=0.824]
# Epoch 5: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.61it/s, train_loss=0.826, val_loss=0.836]
# Epoch 6: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.72it/s, train_loss=0.827, val_loss=0.817]
# Epoch 7: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.09it/s, train_loss=0.819, val_loss=0.856]
# Epoch 8: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.54it/s, train_loss=0.808, val_loss=0.829]
# Epoch 9: 100%|██████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.55it/s, train_loss=0.812, val_loss=0.809]
# Epoch 10: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.90it/s, train_loss=0.800, val_loss=0.822]
# Epoch 11: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.65it/s, train_loss=0.800, val_loss=0.787]
# Epoch 12: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.85it/s, train_loss=0.789, val_loss=0.832]
# Epoch 13: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.65it/s, train_loss=0.799, val_loss=0.816]
# Epoch 14: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.46it/s, train_loss=0.798, val_loss=0.801]
# Epoch 15: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.30it/s, train_loss=0.794, val_loss=0.798]
# Epoch 16: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.04it/s, train_loss=0.788, val_loss=0.814]
# Epoch 17: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.54it/s, train_loss=0.799, val_loss=0.801]
# Epoch 18: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.20it/s, train_loss=0.795, val_loss=0.803]
# Epoch 19: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.91it/s, train_loss=0.798, val_loss=0.835]
# Epoch 20: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.60it/s, train_loss=0.785, val_loss=0.826]
# Epoch 21: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.38it/s, train_loss=0.784, val_loss=0.789]
# Epoch 22: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.22it/s, train_loss=0.792, val_loss=0.792]
# Epoch 23: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.47it/s, train_loss=0.795, val_loss=0.796]
# Epoch 24: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.45it/s, train_loss=0.793, val_loss=0.807]
# Epoch 25: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.11it/s, train_loss=0.789, val_loss=0.823]
# Epoch 26: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.22it/s, train_loss=0.787, val_loss=0.786]
# Epoch 27: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.21it/s, train_loss=0.789, val_loss=0.779]
# Epoch 28: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.47it/s, train_loss=0.790, val_loss=0.806]
# Epoch 29: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.64it/s, train_loss=0.792, val_loss=0.793]
# Epoch 30: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.21it/s, train_loss=0.780, val_loss=0.808]
# Epoch 31: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.70it/s, train_loss=0.782, val_loss=0.804]
# Epoch 32: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.82it/s, train_loss=0.782, val_loss=0.789]
# Epoch 33: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.93it/s, train_loss=0.784, val_loss=0.798]
# Epoch 34: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.39it/s, train_loss=0.785, val_loss=0.811]
# Epoch 35: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.16it/s, train_loss=0.781, val_loss=0.812]
# Epoch 36: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.84it/s, train_loss=0.785, val_loss=0.790]
# Epoch 37: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.41it/s, train_loss=0.780, val_loss=0.791]
# Epoch 38: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.76it/s, train_loss=0.782, val_loss=0.776]
# Epoch 39: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.89it/s, train_loss=0.787, val_loss=0.857]
# Epoch 40: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.93it/s, train_loss=0.778, val_loss=0.808]
# Epoch 41: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.87it/s, train_loss=0.788, val_loss=0.789]
# Epoch 42: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.48it/s, train_loss=0.775, val_loss=0.794]
# Epoch 43: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.02it/s, train_loss=0.781, val_loss=0.786]
# Epoch 44: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.30it/s, train_loss=0.785, val_loss=0.781]
# Epoch 45: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.05it/s, train_loss=0.783, val_loss=0.785]
# Epoch 46: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.50it/s, train_loss=0.783, val_loss=0.821]
# Epoch 47: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.88it/s, train_loss=0.780, val_loss=0.800]
# Epoch 48: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.97it/s, train_loss=0.785, val_loss=0.776]
# Epoch 49: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.00it/s, train_loss=0.780, val_loss=0.773]
# Epoch 50: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.81it/s, train_loss=0.783, val_loss=0.770]
# Epoch 51: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.59it/s, train_loss=0.781, val_loss=0.779]
# Epoch 52: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.81it/s, train_loss=0.789, val_loss=0.807]
# Epoch 53: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.22it/s, train_loss=0.788, val_loss=0.778]
# Epoch 54: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.43it/s, train_loss=0.781, val_loss=0.787]
# Epoch 55: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.37it/s, train_loss=0.785, val_loss=0.781]
# Epoch 56: 100%|█████████████████████████████████████████████████████████| 232/232 [00:11<00:00, 20.99it/s, train_loss=0.772, val_loss=0.777]
# Epoch 57: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.84it/s, train_loss=0.779, val_loss=0.811]
# Epoch 58: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.71it/s, train_loss=0.781, val_loss=0.804]
# Epoch 59: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.11it/s, train_loss=0.782, val_loss=0.838]
# Epoch 60: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.24it/s, train_loss=0.786, val_loss=0.770]
# Epoch 61: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.43it/s, train_loss=0.775, val_loss=0.775]
# Epoch 62: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.80it/s, train_loss=0.780, val_loss=0.772]
# Epoch 63: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.60it/s, train_loss=0.777, val_loss=0.779]
# Epoch 64: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.56it/s, train_loss=0.786, val_loss=0.789]
# Epoch 65: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.30it/s, train_loss=0.781, val_loss=0.796]
# Epoch 66: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.13it/s, train_loss=0.791, val_loss=0.802]
# Epoch 67: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.41it/s, train_loss=0.778, val_loss=0.820]
# Epoch 68: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.96it/s, train_loss=0.784, val_loss=0.793]
# Epoch 69: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.56it/s, train_loss=0.770, val_loss=0.775]
# Epoch 70: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.85it/s, train_loss=0.785, val_loss=0.801]
# Epoch 71: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.55it/s, train_loss=0.778, val_loss=0.783]
# Epoch 72: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.32it/s, train_loss=0.774, val_loss=0.826]
# Epoch 73: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.93it/s, train_loss=0.773, val_loss=0.798]
# Epoch 74: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.53it/s, train_loss=0.777, val_loss=0.810]
# Epoch 75: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.25it/s, train_loss=0.779, val_loss=0.785]
# Epoch 76: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.32it/s, train_loss=0.785, val_loss=0.789]
# Epoch 77: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.07it/s, train_loss=0.787, val_loss=0.793]
# Epoch 78: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.21it/s, train_loss=0.779, val_loss=0.815]
# Epoch 79: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.18it/s, train_loss=0.772, val_loss=0.781]
# Epoch 80: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.64it/s, train_loss=0.779, val_loss=0.800]
# Epoch 81: 100%|█████████████████████████████████████████████████████████| 232/232 [00:09<00:00, 23.49it/s, train_loss=0.778, val_loss=0.792]
# Epoch 82: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.05it/s, train_loss=0.771, val_loss=0.804]
# Epoch 83: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.60it/s, train_loss=0.778, val_loss=0.768]
# Epoch 84: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.93it/s, train_loss=0.781, val_loss=0.765]
# Epoch 85: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.48it/s, train_loss=0.769, val_loss=0.816]
# Epoch 86: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.92it/s, train_loss=0.776, val_loss=0.781]
# Epoch 87: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.75it/s, train_loss=0.774, val_loss=0.778]
# Epoch 88: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 23.06it/s, train_loss=0.774, val_loss=0.805]
# Epoch 89: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.21it/s, train_loss=0.772, val_loss=0.791]
# Epoch 90: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.03it/s, train_loss=0.774, val_loss=0.799]
# Epoch 91: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.52it/s, train_loss=0.775, val_loss=0.784]
# Epoch 92: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.35it/s, train_loss=0.775, val_loss=0.798]
# Epoch 93: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.72it/s, train_loss=0.780, val_loss=0.800]
# Epoch 94: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.76it/s, train_loss=0.773, val_loss=0.768]
# Epoch 95: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.52it/s, train_loss=0.780, val_loss=0.793]
# Epoch 96: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.88it/s, train_loss=0.772, val_loss=0.818]
# Epoch 97: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.00it/s, train_loss=0.783, val_loss=0.787]
# Epoch 98: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.71it/s, train_loss=0.769, val_loss=0.788]
# Epoch 99: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 22.84it/s, train_loss=0.772, val_loss=0.773]
# Epoch 99: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.42it/s, train_loss=0.778, val_loss=0.782]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|█████████████████████████████████████████████████████████| 232/232 [00:10<00:00, 21.29it/s, train_loss=0.778, val_loss=0.782]
# DONE SAVING PRETRAINED MODEL
#    | Name                                                                     | Type               | Params | Mode
# -------------------------------------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                                             | MSELoss            | 0      | train
# 1  | reconstruction_loss_fn                                                   | MSELoss            | 0      | train
# 2  | model                                                                    | SwitchTab          | 657 K  | train
# 3  | model._SwitchTab__encoder                                                | Encoder            | 439 K  | train
# 4  | model._SwitchTab__encoder.transformer                                    | FTTransformer      | 439 K  | train
# 5  | model._SwitchTab__encoder.transformer.tokenizer                          | FeatureTokenizer   | 37.0 K | train
# 6  | model._SwitchTab__encoder.transformer.tokenizer.cat_weights              | Embedding          | 0      | train
# 7  | model._SwitchTab__encoder.transformer.backbone                           | Sequential         | 402 K  | train
# 8  | model._SwitchTab__encoder.transformer.backbone.0                         | Transformer        | 402 K  | train
# 9  | model._SwitchTab__encoder.transformer.backbone.0.block                   | ModuleDict         | 402 K  | train
# 10 | model._SwitchTab__encoder.transformer.backbone.0.block.attention         | MultiheadAttention | 160 K  | train
# 11 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.W_qkv   | Linear             | 120 K  | train
# 12 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.W_out   | Linear             | 40.2 K | train
# 13 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.dropout | Dropout            | 0      | train
# 14 | model._SwitchTab__encoder.transformer.backbone.0.block.linear0           | Linear             | 160 K  | train
# 15 | model._SwitchTab__encoder.transformer.backbone.0.block.linear1           | Linear             | 80.2 K | train
# 16 | model._SwitchTab__encoder.transformer.backbone.0.block.norm1             | LayerNorm          | 400    | train
# 17 | model._SwitchTab__encoder.transformer.backbone.0.block.ffn_dropout       | Dropout            | 0      | train
# 18 | model.projector_m                                                        | Projector          | 40.2 K | train
# 19 | model.projector_m.linear                                                 | Linear             | 40.2 K | train
# 20 | model.projector_m.activation                                             | SiLU               | 0      | train
# 21 | model.projector_s                                                        | Projector          | 40.2 K | train
# 22 | model.projector_s.linear                                                 | Linear             | 40.2 K | train
# 23 | model.projector_s.activation                                             | SiLU               | 0      | train
# 24 | model.decoder                                                            | Decoder            | 36.9 K | train
# 25 | model.decoder.linear                                                     | Linear             | 36.9 K | train
# 26 | model.decoder.activation                                                 | SiLU               | 0      | train
# 27 | model.head                                                               | Linear             | 201    | train
# 28 | model.one_layer_prediction_head                                          | Sequential         | 40.4 K | train
# 29 | model.one_layer_prediction_head.head_linear_hid                          | Linear             | 40.2 K | train
# 30 | model.one_layer_prediction_head.head_activation                          | ReLU               | 0      | train
# 31 | model.one_layer_prediction_head.head_linear_out                          | Linear             | 201    | train
# 32 | model.two_layer_prediction_head                                          | Sequential         | 60.4 K | train
# 33 | model.two_layer_prediction_head.head_linear_hid1                         | Linear             | 40.2 K | train
# 34 | model.two_layer_prediction_head.head_activation1                         | ReLU               | 0      | train
# 35 | model.two_layer_prediction_head.head_linear_hid2                         | Linear             | 20.1 K | train
# 36 | model.two_layer_prediction_head.head_activation2                         | ReLU               | 0      | train
# 37 | model.two_layer_prediction_head.head_linear_out                          | Linear             | 101    | train
# 38 | model.activation                                                         | SiLU               | 0      | train
# -------------------------------------------------------------------------------------------------------------------------
# 657 K     Trainable params
# 0         Non-trainable params
# 657 K     Total params
# 2.630     Total estimated model params size (MB)
# Time to pretrain model:  1101.674648284912
# DONE PRETRAINING
