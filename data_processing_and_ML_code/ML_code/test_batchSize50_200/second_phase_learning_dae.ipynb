# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
s3l_training(SP_results_folder='rando_test_batchSize50_200', # This folder will be created and the results csv files stored there 
             pred_head_type = 'ts3l',
             pt_type ='dae',
             pt_folder = 'FP2',
             pretrain=False, # if True First Phase training
             use_pretrained_model=True, 
             freeze_encoder=False,
             pred_head_size = 1, 
             shift_samp_for_predict = True)
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# rand_itr:  0  train_runs:  [11]  test_runs:  [12]
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  3.03232741355896
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  2.8606128692626953
# Seed set to 42
# Loaded run 12
# Time to read data:  14.992100477218628
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# Train data shape (1000, 92)
# Test data shape (2439, 92)
# Val data shape (813, 92)
# Time to process data for one learning task:  0.021871089935302734
#    | Name                                             | Type       | Params | Mode
# -----------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss    | 0      | train
# 1  | mask_loss_fn                                     | BCELoss    | 0      | train
# 2  | categorical_feature_loss                         | BCELoss    | 0      | train
# 3  | continuous_feature_loss                          | MSELoss    | 0      | train
# 4  | model                                            | DAE        | 357 K  | train
# 5  | model._DAE__encoder                              | MLP        | 139 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear     | 18.6 K | train
# 7  | model._DAE__encoder.relu_0                       | ReLU       | 0      | train
# 8  | model._DAE__encoder.dropout_0                    | Dropout    | 0      | train
# 9  | model._DAE__encoder.linear_1                     | Linear     | 40.2 K | train
# 10 | model._DAE__encoder.relu_1                       | ReLU       | 0      | train
# 11 | model._DAE__encoder.dropout_1                    | Dropout    | 0      | train
# 12 | model._DAE__encoder.linear_2                     | Linear     | 40.2 K | train
# 13 | model._DAE__encoder.relu_2                       | ReLU       | 0      | train
# 14 | model._DAE__encoder.dropout_2                    | Dropout    | 0      | train
# 15 | model._DAE__encoder.last_layer                   | Linear     | 40.2 K | train
# 16 | model.mask_predictor_head                        | MLP        | 58.7 K | train
# 17 | model.mask_predictor_head.linear_0               | Linear     | 40.2 K | train
# 18 | model.mask_predictor_head.relu_0                 | ReLU       | 0      | train
# 19 | model.mask_predictor_head.dropout_0              | Dropout    | 0      | train
# 20 | model.mask_predictor_head.last_layer             | Linear     | 18.5 K | train
# 21 | model.reconstruction_head                        | MLP        | 58.7 K | train
# 22 | model.reconstruction_head.linear_0               | Linear     | 40.2 K | train
# 23 | model.reconstruction_head.relu_0                 | ReLU       | 0      | train
# 24 | model.reconstruction_head.dropout_0              | Dropout    | 0      | train
# 25 | model.reconstruction_head.last_layer             | Linear     | 18.5 K | train
# 26 | model.one_layer_prediction_head                  | Sequential | 40.4 K | train
# 27 | model.one_layer_prediction_head.head_linear_hid  | Linear     | 40.2 K | train
# 28 | model.one_layer_prediction_head.head_activation  | ReLU       | 0      | train
# 29 | model.one_layer_prediction_head.head_linear_out  | Linear     | 201    | train
# 30 | model.two_layer_prediction_head                  | Sequential | 60.4 K | train
# 31 | model.two_layer_prediction_head.head_linear_hid1 | Linear     | 40.2 K | train
# 32 | model.two_layer_prediction_head.head_activation1 | ReLU       | 0      | train
# 33 | model.two_layer_prediction_head.head_linear_hid2 | Linear     | 20.1 K | train
# 34 | model.two_layer_prediction_head.head_activation2 | ReLU       | 0      | train
# 35 | model.two_layer_prediction_head.head_linear_out  | Linear     | 101    | train
# -----------------------------------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# HYPERPARAMETERS:  {'batch_size': 50, 'max_epochs': 30, 'patience': 5, 'loss': {'reg': 'MSELoss', 'clas': 'CrossEntropyLoss'}, 'metrics': {'reg': ['r2_score'], 'clas': ['Recall']}}
# refresh rate:  10
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 162.33it/s]
# Epoch 1: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.06it/s, train_loss=2.790, val_r2_score=-3.80]
# Epoch 2: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.28it/s, train_loss=0.875, val_r2_score=-1.92]
# Epoch 3: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.18it/s, train_loss=0.643, val_r2_score=-1.23]
# Epoch 4: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.30it/s, train_loss=0.447, val_r2_score=-0.83]
# Epoch 5: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.25it/s, train_loss=0.356, val_r2_score=-0.601]
# Epoch 6: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.33it/s, train_loss=0.379, val_r2_score=-0.578]
# Epoch 7: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.11it/s, train_loss=0.311, val_r2_score=-0.704]
# Epoch 8: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.41it/s, train_loss=0.302, val_r2_score=-0.475]
# Epoch 9: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.28it/s, train_loss=0.275, val_r2_score=-0.314]
# Epoch 10: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=0.267, val_r2_score=-0.371]
# Epoch 11: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=0.260, val_r2_score=-0.37]
# Epoch 12: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.39it/s, train_loss=0.247, val_r2_score=-0.24]
# Epoch 13: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.97it/s, train_loss=0.230, val_r2_score=-0.237]
# Epoch 14: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.53it/s, train_loss=0.230, val_r2_score=-0.275]
# Epoch 15: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.43it/s, train_loss=0.212, val_r2_score=-0.139]
# Epoch 16: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.97it/s, train_loss=0.211, val_r2_score=-0.133]
# Epoch 17: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.30it/s, train_loss=0.206, val_r2_score=-0.179]
# Epoch 18: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.43it/s, train_loss=0.187, val_r2_score=-0.152]
# Epoch 19: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.52it/s, train_loss=0.199, val_r2_score=-0.0844]
# Epoch 20: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=0.186, val_r2_score=-0.0867]
# Epoch 21: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.97it/s, train_loss=0.159, val_r2_score=-0.0144]
# Epoch 22: 100%|████████████████████████████████████████████████| 20/20 [00:01<00:00, 10.27it/s, train_loss=0.181, val_r2_score=-0.00244]
# Epoch 23: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.29it/s, train_loss=0.157, val_r2_score=0.0267]
# Epoch 24: 100%|███████████████████████████████████████████████| 20/20 [00:01<00:00, 14.99it/s, train_loss=0.155, val_r2_score=-0.000657]
# Epoch 25: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.55it/s, train_loss=0.157, val_r2_score=-0.0893]
# Epoch 26: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=0.152, val_r2_score=-0.0473]
# Epoch 27: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.93it/s, train_loss=0.141, val_r2_score=0.0343]
# Epoch 28: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.31it/s, train_loss=0.148, val_r2_score=0.057]
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.29it/s, train_loss=0.144, val_r2_score=0.017]
# Epoch 29: 100%|██████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.82it/s, train_loss=0.139, val_r2_score=0.0657]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|██████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.73it/s, train_loss=0.139, val_r2_score=0.0657]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.010111093521118164
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_thput_mbps  task type:  reg  task num:  1 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2072  369  322  315  177]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2037  253  336  388  234]
# Train data shape (1000, 92)
# Test data shape (2436, 92)
# Val data shape (812, 92)
# Time to process data for one learning task:  0.023213624954223633
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 177.39it/s]
# Epoch 1: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.94it/s, train_loss=437.0, val_r2_score=-0.206]
# Epoch 2: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.39it/s, train_loss=285.0, val_r2_score=0.118]
# Epoch 3: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=233.0, val_r2_score=0.217]
# Epoch 4: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.43it/s, train_loss=205.0, val_r2_score=0.266]
# Epoch 5: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.13it/s, train_loss=183.0, val_r2_score=0.295]
# Epoch 6: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.15it/s, train_loss=163.0, val_r2_score=0.301]
# Epoch 7: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.50it/s, train_loss=153.0, val_r2_score=0.362]
# Epoch 8: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.94it/s, train_loss=144.0, val_r2_score=0.365]
# Epoch 9: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.28it/s, train_loss=131.0, val_r2_score=0.422]
# Epoch 10: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=127.0, val_r2_score=0.465]
# Epoch 11: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.45it/s, train_loss=121.0, val_r2_score=0.462]
# Epoch 12: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.16it/s, train_loss=118.0, val_r2_score=0.497]
# Epoch 13: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.13it/s, train_loss=115.0, val_r2_score=0.489]
# Epoch 14: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.22it/s, train_loss=110.0, val_r2_score=0.484]
# Epoch 15: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.10it/s, train_loss=107.0, val_r2_score=0.509]
# Epoch 16: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.44it/s, train_loss=105.0, val_r2_score=0.507]
# Epoch 17: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.17it/s, train_loss=102.0, val_r2_score=0.528]
# Epoch 18: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.71it/s, train_loss=103.0, val_r2_score=0.547]
# Epoch 19: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.05it/s, train_loss=101.0, val_r2_score=0.527]
# Epoch 20: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.50it/s, train_loss=100.0, val_r2_score=0.535]
# Epoch 21: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.65it/s, train_loss=97.70, val_r2_score=0.557]
# Epoch 22: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.99it/s, train_loss=96.30, val_r2_score=0.566]
# Epoch 23: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.98it/s, train_loss=95.60, val_r2_score=0.560]
# Epoch 24: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=95.80, val_r2_score=0.574]
# Epoch 25: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.25it/s, train_loss=88.90, val_r2_score=0.577]
# Epoch 26: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.26it/s, train_loss=94.70, val_r2_score=0.578]
# Epoch 27: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.10it/s, train_loss=88.30, val_r2_score=0.549]
# Epoch 28: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.15it/s, train_loss=90.00, val_r2_score=0.595]
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=84.90, val_r2_score=0.590]
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.76it/s, train_loss=91.90, val_r2_score=0.582]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.70it/s, train_loss=91.90, val_r2_score=0.582]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.010690677165985107
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_time  task type:  reg  task num:  2 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2519  341  226  122   48]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2877  251   82   26   16]
# Train data shape (1000, 92)
# Test data shape (2408, 92)
# Val data shape (802, 92)
# Time to process data for one learning task:  0.024304866790771484
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 170.58it/s]
# Epoch 1: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.27it/s, train_loss=2.74e+4, val_r2_score=-0.696]
# Epoch 2: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.34it/s, train_loss=2.48e+4, val_r2_score=-0.423]
# Epoch 3: 100%|████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.31it/s, train_loss=2.13e+4, val_r2_score=-0.0804]
# Epoch 4: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.45it/s, train_loss=1.68e+4, val_r2_score=0.146]
# Epoch 5: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.42it/s, train_loss=1.3e+4, val_r2_score=0.250]
# Epoch 6: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=1.02e+4, val_r2_score=0.353]
# Epoch 7: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.14it/s, train_loss=8.44e+3, val_r2_score=0.451]
# Epoch 8: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.57it/s, train_loss=7.34e+3, val_r2_score=0.547]
# Epoch 9: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.38it/s, train_loss=6.18e+3, val_r2_score=0.637]
# Epoch 10: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.10it/s, train_loss=5.21e+3, val_r2_score=0.669]
# Epoch 11: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.44it/s, train_loss=4.73e+3, val_r2_score=0.722]
# Epoch 12: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=4.26e+3, val_r2_score=0.740]
# Epoch 13: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.09it/s, train_loss=4.04e+3, val_r2_score=0.760]
# Epoch 14: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.36it/s, train_loss=3.8e+3, val_r2_score=0.768]
# Epoch 15: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=3.65e+3, val_r2_score=0.767]
# Epoch 16: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.98it/s, train_loss=3.56e+3, val_r2_score=0.782]
# Epoch 17: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.65it/s, train_loss=3.46e+3, val_r2_score=0.785]
# Epoch 18: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.07it/s, train_loss=3.2e+3, val_r2_score=0.781]
# Epoch 19: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 11.82it/s, train_loss=3.24e+3, val_r2_score=0.794]
# Epoch 20: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.02it/s, train_loss=3.17e+3, val_r2_score=0.798]
# Epoch 21: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.25it/s, train_loss=3.24e+3, val_r2_score=0.799]
# Epoch 22: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=3.07e+3, val_r2_score=0.802]
# Epoch 23: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.41it/s, train_loss=3.13e+3, val_r2_score=0.805]
# Epoch 24: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 10.08it/s, train_loss=3.01e+3, val_r2_score=0.794]
# Epoch 25: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=2.89e+3, val_r2_score=0.804]
# Epoch 26: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.67it/s, train_loss=2.8e+3, val_r2_score=0.809]
# Epoch 27: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.67it/s, train_loss=2.9e+3, val_r2_score=0.807]
# Epoch 28: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.22it/s, train_loss=2.92e+3, val_r2_score=0.810]
# Epoch 29: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 12.11it/s, train_loss=2.72e+3, val_r2_score=0.807]
# Epoch 29: 100%|██████████████████████████████████████████████████| 20/20 [00:02<00:00,  6.88it/s, train_loss=2.7e+3, val_r2_score=0.812]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|██████████████████████████████████████████████████| 20/20 [00:02<00:00,  6.81it/s, train_loss=2.7e+3, val_r2_score=0.812]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.010509562492370606
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_burst_time  task type:  reg  task num:  3 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# Train data shape (1000, 92)
# Test data shape (2404, 92)
# Val data shape (801, 92)
# Time to process data for one learning task:  0.023442745208740234
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 164.99it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.48it/s, train_loss=2.83e+4, val_r2_score=-0.75]
# Epoch 2: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.26it/s, train_loss=2.55e+4, val_r2_score=-0.462]
# Epoch 3: 100%|████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.57it/s, train_loss=2.18e+4, val_r2_score=-0.0943]
# Epoch 4: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 12.13it/s, train_loss=1.67e+4, val_r2_score=0.129]
# Epoch 5: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.60it/s, train_loss=1.26e+4, val_r2_score=0.214]
# Epoch 6: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.22it/s, train_loss=9.8e+3, val_r2_score=0.322]
# Epoch 7: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.30it/s, train_loss=8.47e+3, val_r2_score=0.419]
# Epoch 8: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.32it/s, train_loss=7.33e+3, val_r2_score=0.535]
# Epoch 9: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.34it/s, train_loss=6.29e+3, val_r2_score=0.605]
# Epoch 10: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.48it/s, train_loss=5.49e+3, val_r2_score=0.664]
# Epoch 11: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.36it/s, train_loss=4.91e+3, val_r2_score=0.698]
# Epoch 12: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.03it/s, train_loss=4.5e+3, val_r2_score=0.729]
# Epoch 13: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=4.08e+3, val_r2_score=0.738]
# Epoch 14: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.23it/s, train_loss=3.64e+3, val_r2_score=0.748]
# Epoch 15: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.36it/s, train_loss=3.73e+3, val_r2_score=0.755]
# Epoch 16: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.29it/s, train_loss=3.54e+3, val_r2_score=0.757]
# Epoch 17: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.35it/s, train_loss=3.26e+3, val_r2_score=0.762]
# Epoch 18: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.50it/s, train_loss=3.1e+3, val_r2_score=0.765]
# Epoch 19: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.16it/s, train_loss=3.16e+3, val_r2_score=0.770]
# Epoch 20: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 12.47it/s, train_loss=3.08e+3, val_r2_score=0.769]
# Epoch 21: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.55it/s, train_loss=2.91e+3, val_r2_score=0.771]
# Epoch 22: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.37it/s, train_loss=2.99e+3, val_r2_score=0.771]
# Epoch 23: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.97it/s, train_loss=2.92e+3, val_r2_score=0.773]
# Epoch 24: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.29it/s, train_loss=2.92e+3, val_r2_score=0.774]
# Epoch 25: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.94it/s, train_loss=2.74e+3, val_r2_score=0.778]
# Epoch 26: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.36it/s, train_loss=2.79e+3, val_r2_score=0.779]
# Epoch 27: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.82it/s, train_loss=2.74e+3, val_r2_score=0.779]
# Epoch 28: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.13it/s, train_loss=2.71e+3, val_r2_score=0.782]
# Epoch 29: 100%|█████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.19it/s, train_loss=2.71e+3, val_r2_score=0.783]
# Epoch 29: 100%|█████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.80it/s, train_loss=2.68e+3, val_r2_score=0.779]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.72it/s, train_loss=2.68e+3, val_r2_score=0.779]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.01023726463317871
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  1000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  delay_trace.txt_dl_delay  task type:  reg  task num:  4 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179730, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179703, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# Train data shape (1000, 92)
# Test data shape (173964, 92)
# Val data shape (1000, 92)
# Time to process data for one learning task:  0.8407957553863525
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 169.40it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=940.0, val_r2_score=-0.0488]
# Epoch 2: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.11it/s, train_loss=808.0, val_r2_score=0.0615]
# Epoch 3: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.03it/s, train_loss=734.0, val_r2_score=0.136]
# Epoch 4: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.07it/s, train_loss=682.0, val_r2_score=0.190]
# Epoch 5: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.89it/s, train_loss=629.0, val_r2_score=0.230]
# Epoch 6: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=587.0, val_r2_score=0.283]
# Epoch 7: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.81it/s, train_loss=550.0, val_r2_score=0.323]
# Epoch 8: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.67it/s, train_loss=507.0, val_r2_score=0.366]
# Epoch 9: 100%|████████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.61it/s, train_loss=463.0, val_r2_score=0.406]
# Epoch 10: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.93it/s, train_loss=427.0, val_r2_score=0.434]
# Epoch 11: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.85it/s, train_loss=384.0, val_r2_score=0.469]
# Epoch 12: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 12.05it/s, train_loss=342.0, val_r2_score=0.495]
# Epoch 13: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.12it/s, train_loss=311.0, val_r2_score=0.515]
# Epoch 14: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.68it/s, train_loss=290.0, val_r2_score=0.525]
# Epoch 15: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.07it/s, train_loss=277.0, val_r2_score=0.514]
# Epoch 16: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 13.22it/s, train_loss=230.0, val_r2_score=0.546]
# Epoch 17: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.98it/s, train_loss=223.0, val_r2_score=0.532]
# Epoch 18: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.77it/s, train_loss=210.0, val_r2_score=0.557]
# Epoch 19: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.87it/s, train_loss=192.0, val_r2_score=0.566]
# Epoch 20: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.70it/s, train_loss=187.0, val_r2_score=0.567]
# Epoch 21: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.86it/s, train_loss=168.0, val_r2_score=0.564]
# Epoch 22: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.85it/s, train_loss=166.0, val_r2_score=0.570]
# Epoch 23: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.85it/s, train_loss=154.0, val_r2_score=0.576]
# Epoch 24: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.99it/s, train_loss=155.0, val_r2_score=0.563]
# Epoch 25: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.05it/s, train_loss=149.0, val_r2_score=0.577]
# Epoch 26: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.84it/s, train_loss=131.0, val_r2_score=0.584]
# Epoch 27: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.21it/s, train_loss=143.0, val_r2_score=0.579]
# Epoch 28: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.86it/s, train_loss=142.0, val_r2_score=0.582]
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 14.75it/s, train_loss=137.0, val_r2_score=0.592]
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.58it/s, train_loss=110.0, val_r2_score=0.573]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|███████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.51it/s, train_loss=110.0, val_r2_score=0.573]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.012788629531860352
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# Time to run experiments for rand itr  0  for num labeled samples  1000 :  434.3536026477814
#
# ===============================  DONE with this random iteration  ===================================================
# ============================= Train set mean over runs ===================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.184379  1.221613  0.655340
# vrFragment_trace.txt_vr_burst_thput_mbps   5.797619  0.696898  0.720800
# vrFragment_trace.txt_vr_frag_time         31.664718  0.578861  0.836683
# vrFragment_trace.txt_vr_burst_time        31.687705  0.633648  0.848601
# delay_trace.txt_dl_delay                   4.201289  0.331968  0.881244
# =============================== Test set results =========================================
#                                                MAE     MAPE       R2
# vrFragment_trace.txt_vr_frag_thput_mbps    [0.281]  [1.734]  [0.319]
# vrFragment_trace.txt_vr_burst_thput_mbps   [8.124]  [1.129]  [0.570]
# vrFragment_trace.txt_vr_frag_time         [28.300]  [0.809]  [0.762]
# vrFragment_trace.txt_vr_burst_time        [28.175]  [0.939]  [0.789]
# delay_trace.txt_dl_delay                   [7.038]  [0.509]  [0.558]
# ============================= Test set mean over runs ====================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.280551  1.733800  0.318602
# vrFragment_trace.txt_vr_burst_thput_mbps   8.123506  1.129473  0.569537
# vrFragment_trace.txt_vr_frag_time         28.299679  0.808853  0.762092
# vrFragment_trace.txt_vr_burst_time        28.174613  0.938889  0.788560
# delay_trace.txt_dl_delay                   7.037580  0.508510  0.558186
# ==========================================================================================
# Time to run experiments for  1000  labeled samples:  434.3660931587219
#
# ===============================  DONE with this num labeled samples size  ===================================================
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  2.8761539459228516
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  2.956507444381714
# Seed set to 42
# Loaded run 12
# Time to read data:  15.185954332351685
# ==========================================================================
# NUM. LABELLED SAMPLES:  20000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2066  358  330  321  181]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3285, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2046  324  312  390  180]
#
#
# WARNING !!!!
#
# Asked to sample from train set of size 3256 a number greater than or equal to its size 20000
# Going to just take as many samples as available, No need to random sample
# Train data shape (3256, 92)
# Test data shape (2439, 92)
# Val data shape (813, 92)
# Time to process data for one learning task:  0.019114017486572266
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 169.35it/s]
# Epoch 1: 100%|████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.31it/s, train_loss=2.950, val_r2_score=-3.58]
# Epoch 2: 100%|████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.37it/s, train_loss=0.990, val_r2_score=-1.60]
# Epoch 3: 100%|████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.25it/s, train_loss=0.638, val_r2_score=-1.06]
# Epoch 4: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 11.83it/s, train_loss=0.465, val_r2_score=-0.752]
# Epoch 5: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.33it/s, train_loss=0.414, val_r2_score=-0.445]
# Epoch 6: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.26it/s, train_loss=0.373, val_r2_score=-0.381]
# Epoch 7: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.48it/s, train_loss=0.341, val_r2_score=-0.296]
# Epoch 8: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.18it/s, train_loss=0.308, val_r2_score=-0.235]
# Epoch 9: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.42it/s, train_loss=0.286, val_r2_score=-0.196]
# Epoch 10: 100%|███████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.48it/s, train_loss=0.277, val_r2_score=-0.19]
# Epoch 11: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.19it/s, train_loss=0.260, val_r2_score=-0.121]
# Epoch 12: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.43it/s, train_loss=0.248, val_r2_score=-0.0933]
# Epoch 13: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.49it/s, train_loss=0.248, val_r2_score=-0.0693]
# Epoch 14: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.60it/s, train_loss=0.235, val_r2_score=-0.0491]
# ...
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3300, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2504  337  239  118   57]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3281, 102)
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
# After removing bins that are not populated enough
# [0 1 2 3 4] [2864  249   92   25   18]
#
#
# WARNING !!!!
#
# Asked to sample from train set of size 3255 a number greater than or equal to its size 20000
# Going to just take as many samples as available, No need to random sample
# Train data shape (3255, 92)
# Test data shape (2404, 92)
# Val data shape (801, 92)
# Time to process data for one learning task:  0.02310466766357422
# refresh rate:  10
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 146.68it/s]
# Epoch 1: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.76it/s, train_loss=2.86e+4, val_r2_score=-0.747]
# Epoch 2: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.59it/s, train_loss=2.58e+4, val_r2_score=-0.50]
# Epoch 3: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.91it/s, train_loss=2.29e+4, val_r2_score=-0.176]
# Epoch 4: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.97it/s, train_loss=1.81e+4, val_r2_score=0.0996]
# Epoch 5: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.40it/s, train_loss=1.38e+4, val_r2_score=0.200]
# Epoch 6: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.87it/s, train_loss=1.09e+4, val_r2_score=0.280]
# Epoch 7: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 11.43it/s, train_loss=9.17e+3, val_r2_score=0.395]
# Epoch 8: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.84it/s, train_loss=7.68e+3, val_r2_score=0.507]
# Epoch 9: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.48it/s, train_loss=6.51e+3, val_r2_score=0.577]
# Epoch 10: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.99it/s, train_loss=5.56e+3, val_r2_score=0.649]
# Epoch 11: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.92it/s, train_loss=4.87e+3, val_r2_score=0.687]
# Epoch 12: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.10it/s, train_loss=4.34e+3, val_r2_score=0.712]
# Epoch 13: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.88it/s, train_loss=4.05e+3, val_r2_score=0.724]
# Epoch 14: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.07it/s, train_loss=3.86e+3, val_r2_score=0.730]
# Epoch 15: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.19it/s, train_loss=3.7e+3, val_r2_score=0.740]
# Epoch 16: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.81it/s, train_loss=3.47e+3, val_r2_score=0.748]
# Epoch 17: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.83it/s, train_loss=3.43e+3, val_r2_score=0.752]
# Epoch 18: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.75it/s, train_loss=3.44e+3, val_r2_score=0.762]
# Epoch 19: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.30it/s, train_loss=3.34e+3, val_r2_score=0.766]
# Epoch 20: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.16it/s, train_loss=3.31e+3, val_r2_score=0.769]
# Epoch 21: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.18it/s, train_loss=3.16e+3, val_r2_score=0.771]
# Epoch 22: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.92it/s, train_loss=3.14e+3, val_r2_score=0.778]
# Epoch 23: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.34it/s, train_loss=3.13e+3, val_r2_score=0.781]
# Epoch 24: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.81it/s, train_loss=3.26e+3, val_r2_score=0.784]
# Epoch 25: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.96it/s, train_loss=3.06e+3, val_r2_score=0.784]
# Epoch 26: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 12.13it/s, train_loss=3.08e+3, val_r2_score=0.789]
# Epoch 27: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.04it/s, train_loss=3.06e+3, val_r2_score=0.786]
# Epoch 28: 100%|█████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.99it/s, train_loss=3.04e+3, val_r2_score=0.791]
# Epoch 29: 100%|██████████████████████████████████████████████████| 17/17 [00:01<00:00, 14.00it/s, train_loss=2.9e+3, val_r2_score=0.791]
# Epoch 29: 100%|█████████████████████████████████████████████████| 17/17 [00:02<00:00,  7.24it/s, train_loss=3.03e+3, val_r2_score=0.796]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 17/17 [00:02<00:00,  7.16it/s, train_loss=3.03e+3, val_r2_score=0.796]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.012199018041842178
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# ==========================================================================
# NUM. LABELLED SAMPLES:  20000
# ==========================================================================
# ==========================================================================
# Random iteration:  0
# ==========================================================================
# ==========================================================================
# Learning task:  delay_trace.txt_dl_delay  task type:  reg  task num:  4 / 5
# ==========================================================================
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179730, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164920   7597   2962   1532    848]
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (179703, 102)
# NOTE: clipping all rows with delay values >  5000
# NOTE: removing samples that are above the 99th percentile
# NOTE: stratifying regression samples using 5 bins
# bin_and_remove_outliers
# Before removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# After removing bins that are not populated enough
# [0 1 2 3 4] [164638   7448   2878   1610    904]
# Train data shape (20000, 92)
# Test data shape (154964, 92)
# Val data shape (20000, 92)
# Time to process data for one learning task:  0.9216015338897705
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 357 K  | train
# -------------------------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# refresh rate:  10
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 174.59it/s]
# Epoch 1: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.98it/s, train_loss=726.0, val_r2_score=0.307]
# Epoch 2: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.54it/s, train_loss=450.0, val_r2_score=0.526]
# Epoch 3: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.42it/s, train_loss=330.0, val_r2_score=0.593]
# Epoch 4: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.19it/s, train_loss=288.0, val_r2_score=0.633]
# Epoch 5: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.80it/s, train_loss=265.0, val_r2_score=0.648]
# Epoch 6: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.43it/s, train_loss=253.0, val_r2_score=0.654]
# Epoch 7: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.53it/s, train_loss=250.0, val_r2_score=0.653]
# Epoch 8: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.01it/s, train_loss=238.0, val_r2_score=0.667]
# Epoch 9: 100%|██████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.05it/s, train_loss=231.0, val_r2_score=0.667]
# Epoch 10: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.27it/s, train_loss=227.0, val_r2_score=0.673]
# Epoch 11: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.89it/s, train_loss=225.0, val_r2_score=0.667]
# Epoch 12: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.40it/s, train_loss=220.0, val_r2_score=0.675]
# Epoch 13: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.40it/s, train_loss=220.0, val_r2_score=0.682]
# Epoch 14: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.72it/s, train_loss=215.0, val_r2_score=0.682]
# Epoch 15: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.99it/s, train_loss=210.0, val_r2_score=0.686]
# Epoch 16: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.67it/s, train_loss=210.0, val_r2_score=0.689]
# Epoch 17: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.67it/s, train_loss=207.0, val_r2_score=0.689]
# Epoch 18: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.86it/s, train_loss=206.0, val_r2_score=0.693]
# Epoch 19: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.83it/s, train_loss=200.0, val_r2_score=0.687]
# Epoch 20: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.20it/s, train_loss=201.0, val_r2_score=0.693]
# Epoch 21: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.79it/s, train_loss=198.0, val_r2_score=0.691]
# Epoch 22: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.72it/s, train_loss=197.0, val_r2_score=0.698]
# Epoch 23: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.91it/s, train_loss=195.0, val_r2_score=0.699]
# Epoch 24: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.78it/s, train_loss=192.0, val_r2_score=0.695]
# Epoch 25: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.73it/s, train_loss=189.0, val_r2_score=0.696]
# Epoch 26: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.87it/s, train_loss=187.0, val_r2_score=0.696]
# Epoch 27: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.05it/s, train_loss=188.0, val_r2_score=0.702]
# Epoch 28: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.57it/s, train_loss=184.0, val_r2_score=0.695]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.59it/s, train_loss=185.0, val_r2_score=0.699]
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:03<00:00, 30.65it/s, train_loss=182.0, val_r2_score=0.703]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|█████████████████████████████████████████████████| 100/100 [00:03<00:00, 30.37it/s, train_loss=182.0, val_r2_score=0.703]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                                     | 0/? [00:00<?, ?it/s]Inference time per batch is:  0.003431062698364258
# NOTE: Clipping the predictions to be within the range of the ground-truth values
# ===============================  DONE with this learning task  ===================================================
# Time to run experiments for rand itr  0  for num labeled samples  20000 :  437.7618405818939
#
# ===============================  DONE with this random iteration  ===================================================
# ============================= Train set mean over runs ===================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.205558  1.494193  0.587038
# vrFragment_trace.txt_vr_burst_thput_mbps   5.993512  0.701430  0.701551
# vrFragment_trace.txt_vr_frag_time         31.398592  0.583210  0.828191
# vrFragment_trace.txt_vr_burst_time        32.435730  0.626009  0.825579
# delay_trace.txt_dl_delay                   5.210423  0.441828  0.794130
# =============================== Test set results =========================================
#                                                MAE     MAPE       R2
# vrFragment_trace.txt_vr_frag_thput_mbps    [0.290]  [2.015]  [0.305]
# vrFragment_trace.txt_vr_burst_thput_mbps   [7.946]  [1.019]  [0.553]
# vrFragment_trace.txt_vr_frag_time         [27.728]  [0.819]  [0.780]
# vrFragment_trace.txt_vr_burst_time        [27.487]  [0.821]  [0.792]
# delay_trace.txt_dl_delay                   [5.840]  [0.484]  [0.707]
# ============================= Test set mean over runs ====================================
#                                                 MAE      MAPE        R2
# vrFragment_trace.txt_vr_frag_thput_mbps    0.289899  2.014748  0.304697
# vrFragment_trace.txt_vr_burst_thput_mbps   7.946202  1.019171  0.552882
# vrFragment_trace.txt_vr_frag_time         27.728207  0.818893  0.780011
# vrFragment_trace.txt_vr_burst_time        27.486640  0.821145  0.791864
# delay_trace.txt_dl_delay                   5.839979  0.483616  0.706982
# ==========================================================================================
# Time to run experiments for  20000  labeled samples:  437.7742028236389
#
# ===============================  DONE with this num labeled samples size  ===================================================
# Time to run the whole script:  872.140373468399
# ===============================  EVERYTHING DONE  ===========================================
