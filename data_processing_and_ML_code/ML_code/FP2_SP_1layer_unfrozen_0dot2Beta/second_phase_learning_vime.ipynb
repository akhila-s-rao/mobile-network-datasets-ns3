# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(SP_results_folder='FP2_SP_1layer_unfrozen_test', # This folder will be created and the results csv files stored there 
             pred_head_type = 'ts3l',
             pt_type ='vime',
             unlab_dataset_scenario = 'pd4',
             pt_folder = 'FP2',
             pretrain=False, # if True First Phase training
             use_pretrained_model=True, 
             freeze_encoder=False,
             pred_head_size = 1, 
             shift_samp_for_predict = True)
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# rand_itr:  0  train_runs:  [11]  test_runs:  [12]
# Concatenating runs:  range(1, 2)
# Time to read csv file for run:  3.025472402572632
# Loaded run 1
# pretrain_data, before removing rows that dont have traffic  (179910, 102)
# pretrain_data, after removing rows that dont have traffic  (20978, 102)
# X_pretrain  (20964, 92)
# train runs used  [11]
# test runs used  [12]
# Concatenating runs:  [11]
# Time to read csv file for run:  2.9308409690856934
# Loaded run 11
# Concatenating runs:  [12]
# Time to read csv file for run:  2.908231019973755
# Loaded run 12
# Time to read data:  15.03996205329895
# ...
# NUM. LABELLED SAMPLES:  250
# ...
# Random iteration:  0
# ...
# Learning task:  vrFragment_trace.txt_vr_frag_thput_mbps  task type:  reg  task num:  0 / 5
# ...
# Dropping rows for which this learning_tasks label is NA, since there is no ground truth
# (3302, 102)
# NOTE: removing samples that are above the 99th percentile
# ...
