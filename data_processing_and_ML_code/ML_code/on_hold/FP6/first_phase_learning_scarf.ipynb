# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='scarf', 
             pt_folder='FP6')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  3.4466841220855713
# Loaded run 1
# Time to read csv file for run:  3.0163064002990723
# Loaded run 2
# Time to read csv file for run:  2.9938035011291504
# Loaded run 3
# Time to read csv file for run:  3.001960515975952
# Loaded run 4
# Time to read csv file for run:  2.991166353225708
# Loaded run 5
# Time to read csv file for run:  2.9305758476257324
# Loaded run 6
# Time to read csv file for run:  2.790005922317505
# Loaded run 7
# Time to read csv file for run:  2.97322678565979
# Loaded run 8
# Time to read csv file for run:  2.907076835632324
# Loaded run 9
# Time to read csv file for run:  2.96897292137146
# Loaded run 10
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (205538, 102)
# X_pretrain  (205086, 92)
# Seed set to 42
# HYPERPARAMETERS:  {'loss_fn': 'MSELoss', 'metric': 'r2_score', 'hidden_dim': 200, 'max_epochs': 100, 'batch_size': 128, 'optim_hparams': {'lr': 0.0001, 'weight_decay': 5e-05}, 'encoder_depth': 8, 'head_depth': 2, 'dropout_rate': 0.1, 'corruption_rate': 0.3}
# refresh rate:  10
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type       | Params | Mode
# --------------------------------------------------------
# 0 | task_loss_fn     | MSELoss    | 0      | train
# 1 | contrastive_loss | NTXentLoss | 0      | train
# 2 | model            | SCARF      | 484 K  | train
# --------------------------------------------------------
# 484 K     Trainable params
# 0         Non-trainable params
# 484 K     Total params
# 1.938     Total estimated model params size (MB)
# Epoch 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 1451/1451 [00:30<00:00, 47.89it/s]
# Epoch 1: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:30<00:00, 46.98it/s, train_loss=1.930, val_loss=1.830]
# Epoch 2: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 45.04it/s, train_loss=0.854, val_loss=1.590]
# Epoch 3: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 45.21it/s, train_loss=0.672, val_loss=1.460]
# Epoch 4: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 45.15it/s, train_loss=0.595, val_loss=1.380]
# Epoch 5: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 44.82it/s, train_loss=0.548, val_loss=1.350]
# Epoch 6: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.61it/s, train_loss=0.519, val_loss=1.260]
# Epoch 7: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 46.47it/s, train_loss=0.501, val_loss=1.230]
# Epoch 8: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 45.03it/s, train_loss=0.484, val_loss=1.210]
# Epoch 9: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 46.56it/s, train_loss=0.471, val_loss=1.180]
# Epoch 10: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.59it/s, train_loss=0.458, val_loss=1.160]
# Epoch 11: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.50it/s, train_loss=0.451, val_loss=1.180]
# Epoch 12: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 46.03it/s, train_loss=0.445, val_loss=1.160]
# Epoch 13: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.37it/s, train_loss=0.436, val_loss=1.130]
# Epoch 14: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.53it/s, train_loss=0.425, val_loss=1.100]
# Epoch 15: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.68it/s, train_loss=0.425, val_loss=1.070]
# Epoch 16: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 45.25it/s, train_loss=0.417, val_loss=1.080]
# Epoch 17: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 44.88it/s, train_loss=0.412, val_loss=1.170]
# Epoch 18: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 44.08it/s, train_loss=0.408, val_loss=1.020]
# Epoch 19: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.89it/s, train_loss=0.401, val_loss=0.996]
# Epoch 20: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 46.65it/s, train_loss=0.395, val_loss=1.030]
# Epoch 21: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.67it/s, train_loss=0.392, val_loss=0.957]
# Epoch 22: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:32<00:00, 44.33it/s, train_loss=0.383, val_loss=0.981]
# Epoch 23: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.57it/s, train_loss=0.382, val_loss=0.974]
# Epoch 24: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45.46it/s, train_loss=0.378, val_loss=0.929]
# Epoch 25: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:31<00:00, 45
 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.57it/s, train_loss=0.247, val_loss=0.498]
# Epoch 71: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:26<00:00, 53.80it/s, train_loss=0.246, val_loss=0.495]
# Epoch 72: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 51.47it/s, train_loss=0.244, val_loss=0.477]
# Epoch 73: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 53.06it/s, train_loss=0.240, val_loss=0.446]
# Epoch 74: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 50.44it/s, train_loss=0.239, val_loss=0.514]
# Epoch 75: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.94it/s, train_loss=0.236, val_loss=0.472]
# Epoch 76: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:26<00:00, 53.88it/s, train_loss=0.235, val_loss=0.470]
# Epoch 77: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 53.19it/s, train_loss=0.233, val_loss=0.511]
# Epoch 78: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 50.48it/s, train_loss=0.232, val_loss=0.462]
# Epoch 79: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.34it/s, train_loss=0.229, val_loss=0.501]
# Epoch 80: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.99it/s, train_loss=0.228, val_loss=0.455]
# Epoch 81: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.24it/s, train_loss=0.225, val_loss=0.481]
# Epoch 82: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.63it/s, train_loss=0.224, val_loss=0.430]
# Epoch 83: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.01it/s, train_loss=0.222, val_loss=0.449]
# Epoch 84: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 51.34it/s, train_loss=0.219, val_loss=0.439]
# Epoch 85: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:29<00:00, 49.24it/s, train_loss=0.217, val_loss=0.424]
# Epoch 86: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 51.28it/s, train_loss=0.216, val_loss=0.532]
# Epoch 87: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.34it/s, train_loss=0.214, val_loss=0.427]
# Epoch 88: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.79it/s, train_loss=0.212, val_loss=0.418]
# Epoch 89: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 50.59it/s, train_loss=0.211, val_loss=0.458]
# Epoch 90: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:28<00:00, 51.05it/s, train_loss=0.211, val_loss=0.407]
# Epoch 91: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 51.82it/s, train_loss=0.210, val_loss=0.400]
# Epoch 92: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:26<00:00, 55.14it/s, train_loss=0.207, val_loss=0.453]
# Epoch 93: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 53.05it/s, train_loss=0.206, val_loss=0.404]
# Epoch 94: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:26<00:00, 54.88it/s, train_loss=0.202, val_loss=0.397]
# Epoch 95: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:26<00:00, 55.50it/s, train_loss=0.200, val_loss=0.378]
# Epoch 96: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.55it/s, train_loss=0.200, val_loss=0.491]
# Epoch 97: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 53.20it/s, train_loss=0.199, val_loss=0.387]
# Epoch 98: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:29<00:00, 48.84it/s, train_loss=0.196, val_loss=0.433]
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:27<00:00, 52.04it/s, train_loss=0.195, val_loss=0.400]
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:29<00:00, 49.51it/s, train_loss=0.193, val_loss=0.427]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:29<00:00, 49.45it/s, train_loss=0.193, val_loss=0.427]
# DONE SAVING PRETRAINED MODEL
#    | Name                                             | Type        | Params | Mode
# ------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss     | 0      | train
# 1  | contrastive_loss                                 | NTXentLoss  | 0      | train
# 2  | model                                            | SCARF       | 484 K  | train
# 3  | model._SCARF__encoder                            | MLP         | 302 K  | train
# 4  | model._SCARF__encoder.linear_0                   | Linear      | 18.6 K | train
# 5  | model._SCARF__encoder.batchnorm_0                | BatchNorm1d | 400    | train
# 6  | model._SCARF__encoder.relu_0                     | ReLU        | 0      | train
# 7  | model._SCARF__encoder.dropout_0                  | Dropout     | 0      | train
# 8  | model._SCARF__encoder.linear_1                   | Linear      | 40.2 K | train
# 9  | model._SCARF__encoder.batchnorm_1                | BatchNorm1d | 400    | train
# 10 | model._SCARF__encoder.relu_1                     | ReLU        | 0      | train
# 11 | model._SCARF__encoder.dropout_1                  | Dropout     | 0      | train
# 12 | model._SCARF__encoder.linear_2                   | Linear      | 40.2 K | train
# 13 | model._SCARF__encoder.batchnorm_2                | BatchNorm1d | 400    | train
# 14 | model._SCARF__encoder.relu_2                     | ReLU        | 0      | train
# 15 | model._SCARF__encoder.dropout_2                  | Dropout     | 0      | train
# 16 | model._SCARF__encoder.linear_3                   | Linear      | 40.2 K | train
# 17 | model._SCARF__encoder.batchnorm_3                | BatchNorm1d | 400    | train
# 18 | model._SCARF__encoder.relu_3                     | ReLU        | 0      | train
# 19 | model._SCARF__encoder.dropout_3                  | Dropout     | 0      | train
# 20 | model._SCARF__encoder.linear_4                   | Linear      | 40.2 K | train
# 21 | model._SCARF__encoder.batchnorm_4                | BatchNorm1d | 400    | train
# 22 | model._SCARF__encoder.relu_4                     | ReLU        | 0      | train
# 23 | model._SCARF__encoder.dropout_4                  | Dropout     | 0      | train
# 24 | model._SCARF__encoder.linear_5                   | Linear      | 40.2 K | train
# 25 | model._SCARF__encoder.batchnorm_5                | BatchNorm1d | 400    | train
# 26 | model._SCARF__encoder.relu_5                     | ReLU        | 0      | train
# 27 | model._SCARF__encoder.dropout_5                  | Dropout     | 0      | train
# 28 | model._SCARF__encoder.linear_6                   | Linear      | 40.2 K | train
# 29 | model._SCARF__encoder.batchnorm_6                | BatchNorm1d | 400    | train
# 30 | model._SCARF__encoder.relu_6                     | ReLU        | 0      | train
# 31 | model._SCARF__encoder.dropout_6                  | Dropout     | 0      | train
# 32 | model._SCARF__encoder.linear_n_layers            | Linear      | 40.2 K | train
# 33 | model.pretraining_head                           | MLP         | 80.8 K | train
# 34 | model.pretraining_head.linear_0                  | Linear      | 40.2 K | train
# 35 | model.pretraining_head.batchnorm_0               | BatchNorm1d | 400    | train
# 36 | model.pretraining_head.relu_0                    | ReLU        | 0      | train
# 37 | model.pretraining_head.dropout_0                 | Dropout     | 0      | train
# 38 | model.pretraining_head.linear_n_layers           | Linear      | 40.2 K | train
# 39 | model.one_layer_prediction_head                  | Sequential  | 40.4 K | train
# 40 | model.one_layer_prediction_head.head_linear_hid  | Linear      | 40.2 K | train
# 41 | model.one_layer_prediction_head.head_activation  | ReLU        | 0      | train
# 42 | model.one_layer_prediction_head.head_linear_out  | Linear      | 201    | train
# 43 | model.two_layer_prediction_head                  | Sequential  | 60.4 K | train
# 44 | model.two_layer_prediction_head.head_linear_hid1 | Linear      | 40.2 K | train
# 45 | model.two_layer_prediction_head.head_activation1 | ReLU        | 0      | train
# 46 | model.two_layer_prediction_head.head_linear_hid2 | Linear      | 20.1 K | train
# 47 | model.two_layer_prediction_head.head_activation2 | ReLU        | 0      | train
# 48 | model.two_layer_prediction_head.head_linear_out  | Linear      | 101    | train
# ------------------------------------------------------------------------------------------
# 484 K     Trainable params
# 0         Non-trainable params
# 484 K     Total params
# 1.938     Total estimated model params size (MB)
# Time to pretrain model:  3215.7989513874054
# DONE PRETRAINING
