# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='dae', 
             pt_folder='FP6')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  3.3206865787506104
# Loaded run 1
# Time to read csv file for run:  3.1652398109436035
# Loaded run 2
# Time to read csv file for run:  3.0180392265319824
# Loaded run 3
# Time to read csv file for run:  3.0269010066986084
# Loaded run 4
# Time to read csv file for run:  3.070181369781494
# Loaded run 5
# Time to read csv file for run:  2.7779626846313477
# Loaded run 6
# Time to read csv file for run:  3.008981227874756
# Loaded run 7
# Time to read csv file for run:  3.0050971508026123
# Loaded run 8
# Time to read csv file for run:  2.884127378463745
# Loaded run 9
# Time to read csv file for run:  2.951488733291626
# Loaded run 10
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (205538, 102)
# X_pretrain  (205086, 92)
# Seed set to 42
# HYPERPARAMETERS:  {'loss_fn': 'MSELoss', 'metric': 'r2_score', 'hidden_dim': 200, 'max_epochs': 100, 'batch_size': 128, 'optim_hparams': {'lr': 0.0001, 'weight_decay': 5e-05}, 'encoder_depth': 8, 'head_depth': 2, 'dropout_rate': 0.1, 'noise_type': 'Swap', 'noise_ratio': 0.3}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# refresh rate:  10
#   | Name                     | Type    | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn             | MSELoss | 0      | train
# 1 | mask_loss_fn             | BCELoss | 0      | train
# 2 | categorical_feature_loss | BCELoss | 0      | train
# 3 | continuous_feature_loss  | MSELoss | 0      | train
# 4 | model                    | DAE     | 458 K  | train
# -------------------------------------------------------------
# 458 K     Trainable params
# 0         Non-trainable params
# 458 K     Total params
# 1.832     Total estimated model params size (MB)
# Epoch 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 66.23it/s]
# Epoch 1: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.86it/s, train_loss=1.610, val_loss=1.190]
# Epoch 2: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.67it/s, train_loss=1.170, val_loss=1.060]
# Epoch 3: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.90it/s, train_loss=1.090, val_loss=0.990]
# Epoch 4: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.61it/s, train_loss=1.040, val_loss=0.954]
# Epoch 5: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.26it/s, train_loss=1.010, val_loss=0.939]
# Epoch 6: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.87it/s, train_loss=0.995, val_loss=0.924]
# Epoch 7: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.72it/s, train_loss=0.981, val_loss=0.942]
# Epoch 8: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.55it/s, train_loss=0.972, val_loss=0.924]
# Epoch 9: 100%|████████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.65it/s, train_loss=0.963, val_loss=0.901]
# Epoch 10: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.44it/s, train_loss=0.953, val_loss=0.923]
# Epoch 11: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.83it/s, train_loss=0.946, val_loss=0.912]
# Epoch 12: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.58it/s, train_loss=0.945, val_loss=0.929]
# Epoch 13: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.62it/s, train_loss=0.937, val_loss=0.934]
# Epoch 14: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.80it/s, train_loss=0.931, val_loss=0.896]
# Epoch 15: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.27it/s, train_loss=0.926, val_loss=0.919]
# Epoch 16: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.49it/s, train_loss=0.926, val_loss=0.893]
# Epoch 17: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.19it/s, train_loss=0.922, val_loss=0.916]
# Epoch 18: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.97it/s, train_loss=0.917, val_loss=0.886]
# Epoch 19: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.31it/s, train_loss=0.914, val_loss=0.872]
# Epoch 20: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68
 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.27it/s, train_loss=0.857, val_loss=0.820]
# Epoch 70: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 69.00it/s, train_loss=0.856, val_loss=0.824]
# Epoch 71: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.19it/s, train_loss=0.857, val_loss=0.871]
# Epoch 72: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.69it/s, train_loss=0.856, val_loss=0.830]
# Epoch 73: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.09it/s, train_loss=0.855, val_loss=0.828]
# Epoch 74: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.13it/s, train_loss=0.851, val_loss=0.836]
# Epoch 75: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 71.17it/s, train_loss=0.859, val_loss=0.849]
# Epoch 76: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.51it/s, train_loss=0.855, val_loss=0.830]
# Epoch 77: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.09it/s, train_loss=0.851, val_loss=0.819]
# Epoch 78: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.09it/s, train_loss=0.855, val_loss=0.828]
# Epoch 79: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 71.65it/s, train_loss=0.854, val_loss=0.831]
# Epoch 80: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.86it/s, train_loss=0.850, val_loss=0.833]
# Epoch 81: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.53it/s, train_loss=0.855, val_loss=0.842]
# Epoch 82: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.25it/s, train_loss=0.848, val_loss=0.835]
# Epoch 83: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.45it/s, train_loss=0.854, val_loss=0.821]
# Epoch 84: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.53it/s, train_loss=0.850, val_loss=0.826]
# Epoch 85: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.13it/s, train_loss=0.850, val_loss=0.829]
# Epoch 86: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.19it/s, train_loss=0.849, val_loss=0.820]
# Epoch 87: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.59it/s, train_loss=0.846, val_loss=0.827]
# Epoch 88: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.33it/s, train_loss=0.852, val_loss=0.833]
# Epoch 89: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.53it/s, train_loss=0.853, val_loss=0.843]
# Epoch 90: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.03it/s, train_loss=0.846, val_loss=0.819]
# Epoch 91: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.84it/s, train_loss=0.851, val_loss=0.818]
# Epoch 92: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.27it/s, train_loss=0.848, val_loss=0.864]
# Epoch 93: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 70.37it/s, train_loss=0.842, val_loss=0.844]
# Epoch 94: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.54it/s, train_loss=0.846, val_loss=0.849]
# Epoch 95: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 69.48it/s, train_loss=0.849, val_loss=0.878]
# Epoch 96: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.28it/s, train_loss=0.844, val_loss=0.819]
# Epoch 97: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.22it/s, train_loss=0.841, val_loss=0.815]
# Epoch 98: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 68.66it/s, train_loss=0.841, val_loss=0.803]
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:20<00:00, 72.11it/s, train_loss=0.846, val_loss=0.846]
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.95it/s, train_loss=0.843, val_loss=0.826]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|███████████████████████████████████████████████████████| 1451/1451 [00:21<00:00, 67.79it/s, train_loss=0.843, val_loss=0.826]
# DONE SAVING PRETRAINED MODEL
#    | Name                                             | Type        | Params | Mode
# ------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                     | MSELoss     | 0      | train
# 1  | mask_loss_fn                                     | BCELoss     | 0      | train
# 2  | categorical_feature_loss                         | BCELoss     | 0      | train
# 3  | continuous_feature_loss                          | MSELoss     | 0      | train
# 4  | model                                            | DAE         | 458 K  | train
# 5  | model._DAE__encoder                              | MLP         | 302 K  | train
# 6  | model._DAE__encoder.linear_0                     | Linear      | 18.6 K | train
# 7  | model._DAE__encoder.batchnorm_0                  | BatchNorm1d | 400    | train
# 8  | model._DAE__encoder.relu_0                       | ReLU        | 0      | train
# 9  | model._DAE__encoder.dropout_0                    | Dropout     | 0      | train
# 10 | model._DAE__encoder.linear_1                     | Linear      | 40.2 K | train
# 11 | model._DAE__encoder.batchnorm_1                  | BatchNorm1d | 400    | train
# 12 | model._DAE__encoder.relu_1                       | ReLU        | 0      | train
# 13 | model._DAE__encoder.dropout_1                    | Dropout     | 0      | train
# 14 | model._DAE__encoder.linear_2                     | Linear      | 40.2 K | train
# 15 | model._DAE__encoder.batchnorm_2                  | BatchNorm1d | 400    | train
# 16 | model._DAE__encoder.relu_2                       | ReLU        | 0      | train
# 17 | model._DAE__encoder.dropout_2                    | Dropout     | 0      | train
# 18 | model._DAE__encoder.linear_3                     | Linear      | 40.2 K | train
# 19 | model._DAE__encoder.batchnorm_3                  | BatchNorm1d | 400    | train
# 20 | model._DAE__encoder.relu_3                       | ReLU        | 0      | train
# 21 | model._DAE__encoder.dropout_3                    | Dropout     | 0      | train
# 22 | model._DAE__encoder.linear_4                     | Linear      | 40.2 K | train
# 23 | model._DAE__encoder.batchnorm_4                  | BatchNorm1d | 400    | train
# 24 | model._DAE__encoder.relu_4                       | ReLU        | 0      | train
# 25 | model._DAE__encoder.dropout_4                    | Dropout     | 0      | train
# 26 | model._DAE__encoder.linear_5                     | Linear      | 40.2 K | train
# 27 | model._DAE__encoder.batchnorm_5                  | BatchNorm1d | 400    | train
# 28 | model._DAE__encoder.relu_5                       | ReLU        | 0      | train
# 29 | model._DAE__encoder.dropout_5                    | Dropout     | 0      | train
# 30 | model._DAE__encoder.linear_6                     | Linear      | 40.2 K | train
# 31 | model._DAE__encoder.batchnorm_6                  | BatchNorm1d | 400    | train
# 32 | model._DAE__encoder.relu_6                       | ReLU        | 0      | train
# 33 | model._DAE__encoder.dropout_6                    | Dropout     | 0      | train
# 34 | model._DAE__encoder.linear_n_layers              | Linear      | 40.2 K | train
# 35 | model.mask_predictor_head                        | MLP         | 27.2 K | train
# 36 | model.mask_predictor_head.linear_0               | Linear      | 18.5 K | train
# 37 | model.mask_predictor_head.batchnorm_0            | BatchNorm1d | 184    | train
# 38 | model.mask_predictor_head.relu_0                 | ReLU        | 0      | train
# 39 | model.mask_predictor_head.dropout_0              | Dropout     | 0      | train
# 40 | model.mask_predictor_head.linear_n_layers        | Linear      | 8.6 K  | train
# 41 | model.reconstruction_head                        | MLP         | 27.2 K | train
# 42 | model.reconstruction_head.linear_0               | Linear      | 18.5 K | train
# 43 | model.reconstruction_head.batchnorm_0            | BatchNorm1d | 184    | train
# 44 | model.reconstruction_head.relu_0                 | ReLU        | 0      | train
# 45 | model.reconstruction_head.dropout_0              | Dropout     | 0      | train
# 46 | model.reconstruction_head.linear_n_layers        | Linear      | 8.6 K  | train
# 47 | model.one_layer_prediction_head                  | Sequential  | 40.4 K | train
# 48 | model.one_layer_prediction_head.head_linear_hid  | Linear      | 40.2 K | train
# 49 | model.one_layer_prediction_head.head_activation  | ReLU        | 0      | train
# 50 | model.one_layer_prediction_head.head_linear_out  | Linear      | 201    | train
# 51 | model.two_layer_prediction_head                  | Sequential  | 60.4 K | train
# 52 | model.two_layer_prediction_head.head_linear_hid1 | Linear      | 40.2 K | train
# 53 | model.two_layer_prediction_head.head_activation1 | ReLU        | 0      | train
# 54 | model.two_layer_prediction_head.head_linear_hid2 | Linear      | 20.1 K | train
# 55 | model.two_layer_prediction_head.head_activation2 | ReLU        | 0      | train
# 56 | model.two_layer_prediction_head.head_linear_out  | Linear      | 101    | train
# ------------------------------------------------------------------------------------------
# 458 K     Trainable params
# 0         Non-trainable params
# 458 K     Total params
# 1.832     Total estimated model params size (MB)
# Time to pretrain model:  2226.8949720859528
# DONE PRETRAINING
