# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='vime', 
             pt_folder='FP4_only_traffic_rows_no_DO_BN')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  4.52939248085022
# Loaded run 1
# Time to read csv file for run:  4.182111978530884
# Loaded run 2
# Time to read csv file for run:  4.370813608169556
# Loaded run 3
# Time to read csv file for run:  4.763010025024414
# Loaded run 4
# Time to read csv file for run:  4.986065864562988
# Loaded run 5
# Time to read csv file for run:  4.778624057769775
# Loaded run 6
# Time to read csv file for run:  5.254720211029053
# Loaded run 7
# Time to read csv file for run:  5.567668437957764
# Loaded run 8
# Time to read csv file for run:  5.446281909942627
# Loaded run 9
# Time to read csv file for run:  5.149248361587524
# Loaded run 10
# Seed set to 42
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33012, 102)
# X_pretrain  (32691, 92)
# GPU available: True (cuda), used: True
# refresh rate:  10
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                        | Type    | Params | Mode
# ----------------------------------------------------------------
# 0 | task_loss_fn                | MSELoss | 0      | train
# 1 | mask_loss_fn                | BCELoss | 0      | train
# 2 | categorical_feature_loss_fn | BCELoss | 0      | train
# 3 | continuous_feature_loss_fn  | MSELoss | 0      | train
# 4 | consistency_loss_fn         | MSELoss | 0      | train
# 5 | model                       | VIME    | 276 K  | train
# ----------------------------------------------------------------
# 276 K     Trainable params
# 0         Non-trainable params
# 276 K     Total params
# 1.108     Total estimated model params size (MB)
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████| 232/232 [00:04<00:00, 57.77it/s, v_num=202]
# Epoch 1: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 55.64it/s, v_num=202, train_loss=3.730, val_loss=3.370]
# Epoch 2: 100%|███████████████████████████████████████████████| 232/232 [00:03<00:00, 58.11it/s, v_num=202, train_loss=3.290, val_loss=3.230]
# Epoch 3: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 53.69it/s, v_num=202, train_loss=3.250, val_loss=3.160]
# Epoch 4: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 55.39it/s, v_num=202, train_loss=3.140, val_loss=3.110]
# Epoch 5: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 55.68it/s, v_num=202, train_loss=3.120, val_loss=3.080]
# Epoch 6: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 55.80it/s, v_num=202, train_loss=3.070, val_loss=3.060]
# Epoch 7: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 57.74it/s, v_num=202, train_loss=3.060, val_loss=3.040]
# Epoch 8: 100%|███████████████████████████████████████████████| 232/232 [00:04<00:00, 55.43it/s, v_num=202, train_loss=3.040, val_loss=3.030]
# Epoch 9: 100%|███████████████████████████████████████████████| 232/232 [00:03<00:00, 60.67it/s, v_num=202, train_loss=3.030, val_loss=3.020]
# Epoch 10: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.18it/s, v_num=202, train_loss=3.020, val_loss=3.010]
# Epoch 11: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.65it/s, v_num=202, train_loss=3.020, val_loss=3.010]
# Epoch 12: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 57.23it/s, v_num=202, train_loss=3.010, val_loss=3.000]
# Epoch 13: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 56.94it/s, v_num=202, train_loss=3.010, val_loss=2.990]
# Epoch 14: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.94it/s, v_num=202, train_loss=3.000, val_loss=2.990]
# Epoch 15: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 66.36it/s, v_num=202, train_loss=3.000, val_loss=2.980]
# Epoch 16: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 60.17it/s, v_num=202, train_loss=3.000, val_loss=2.980]
# Epoch 17: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.61it/s, v_num=202, train_loss=2.980, val_loss=2.970]
# Epoch 18: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 55.06it/s, v_num=202, train_loss=2.980, val_loss=2.970]
# Epoch 19: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 60.78it/s, v_num=202, train_loss=2.980, val_loss=2.970]
# Epoch 20: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 56
 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 51.12it/s, v_num=202, train_loss=2.920, val_loss=2.910]
# Epoch 74: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 62.02it/s, v_num=202, train_loss=2.910, val_loss=2.910]
# Epoch 75: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 62.26it/s, v_num=202, train_loss=2.920, val_loss=2.910]
# Epoch 76: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.36it/s, v_num=202, train_loss=2.910, val_loss=2.910]
# Epoch 77: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 57.01it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 78: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 55.83it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 79: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.92it/s, v_num=202, train_loss=2.910, val_loss=2.910]
# Epoch 80: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.17it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 81: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 61.95it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 82: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 61.78it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 83: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 62.23it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 84: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 57.43it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 85: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 57.83it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 86: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 58.72it/s, v_num=202, train_loss=2.920, val_loss=2.900]
# Epoch 87: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 59.24it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 88: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 59.11it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 89: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 55.16it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 90: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 60.81it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 91: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 64.37it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 92: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 50.27it/s, v_num=202, train_loss=2.910, val_loss=2.900]
# Epoch 93: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 55.09it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 94: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 64.06it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 95: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 62.43it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 96: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 61.06it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 97: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 60.83it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 98: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 60.68it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 99: 100%|██████████████████████████████████████████████| 232/232 [00:03<00:00, 62.81it/s, v_num=202, train_loss=2.900, val_loss=2.900]
# Epoch 99: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 53.19it/s, v_num=202, train_loss=2.900, val_loss=2.890]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████████████████████████████████████████| 232/232 [00:04<00:00, 52.86it/s, v_num=202, train_loss=2.900, val_loss=2.890]
# DONE SAVING PRETRAINED MODEL
#    | Name                                         | Type                 | Params | Mode
# -----------------------------------------------------------------------------------------------
# 0  | task_loss_fn                                 | MSELoss              | 0      | train
# 1  | mask_loss_fn                                 | BCELoss              | 0      | train
# 2  | categorical_feature_loss_fn                  | BCELoss              | 0      | train
# 3  | continuous_feature_loss_fn                   | MSELoss              | 0      | train
# 4  | consistency_loss_fn                          | MSELoss              | 0      | train
# 5  | model                                        | VIME                 | 276 K  | train
# 6  | model._VIME__encoder                         | VIMESelfSupervised   | 176 K  | train
# 7  | model._VIME__encoder.encoder                 | MLP                  | 139 K  | train
# 8  | model._VIME__encoder.encoder.linear_0        | Linear               | 18.6 K | train
# 9  | model._VIME__encoder.encoder.relu_0          | ReLU                 | 0      | train
# 10 | model._VIME__encoder.encoder.dropout_0       | Dropout              | 0      | train
# 11 | model._VIME__encoder.encoder.linear_1        | Linear               | 40.2 K | train
# 12 | model._VIME__encoder.encoder.relu_1          | ReLU                 | 0      | train
# 13 | model._VIME__encoder.encoder.dropout_1       | Dropout              | 0      | train
# 14 | model._VIME__encoder.encoder.linear_2        | Linear               | 40.2 K | train
# 15 | model._VIME__encoder.encoder.relu_2          | ReLU                 | 0      | train
# 16 | model._VIME__encoder.encoder.dropout_2       | Dropout              | 0      | train
# 17 | model._VIME__encoder.encoder.linear_n_layers | Linear               | 40.2 K | train
# 18 | model._VIME__encoder.mask_output             | Linear               | 18.5 K | train
# 19 | model._VIME__encoder.feature_output          | Linear               | 18.5 K | train
# 20 | model.one_layer_prediction_head              | VIMESemiSupervised_1 | 40.4 K | train
# 21 | model.one_layer_prediction_head.fc1          | Linear               | 40.2 K | train
# 22 | model.one_layer_prediction_head.fc3          | Linear               | 201    | train
# 23 | model.two_layer_prediction_head              | VIMESemiSupervised_2 | 60.4 K | train
# 24 | model.two_layer_prediction_head.fc1          | Linear               | 40.2 K | train
# 25 | model.two_layer_prediction_head.fc2          | Linear               | 20.1 K | train
# 26 | model.two_layer_prediction_head.fc3          | Linear               | 101    | train
# -----------------------------------------------------------------------------------------------
# 276 K     Trainable params
# 0         Non-trainable params
# 276 K     Total params
# 1.108     Total estimated model params size (MB)
# DONE PRETRAINING
