# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training

# %%
s3l_training(pretrain=True, # if True First Phase training
             use_pretrained_model=False, # if True Second Phase learning
             pt_type='switchtab', 
             pt_folder='FP4_only_traffic_rows_no_DO_BN')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  5.511884450912476
# Loaded run 1
# Time to read csv file for run:  4.821742534637451
# Loaded run 2
# Time to read csv file for run:  5.804240942001343
# Loaded run 3
# Time to read csv file for run:  5.547770738601685
# Loaded run 4
# Time to read csv file for run:  5.670722961425781
# Loaded run 5
# Time to read csv file for run:  5.612753868103027
# Loaded run 6
# Time to read csv file for run:  5.697778701782227
# Loaded run 7
# Time to read csv file for run:  5.264346122741699
# Loaded run 8
# Time to read csv file for run:  5.312298774719238
# Loaded run 9
# Time to read csv file for run:  5.035275936126709
# Loaded run 10
# Seed set to 42
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# pretrain_data, after removing rows that dont have traffic  (33012, 102)
# X_pretrain  (32691, 92)
# GPU available: True (cuda), used: True
# refresh rate:  10
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                   | Type      | Params | Mode
# -------------------------------------------------------------
# 0 | task_loss_fn           | MSELoss   | 0      | train
# 1 | reconstruction_loss_fn | MSELoss   | 0      | train
# 2 | model                  | SwitchTab | 657 K  | train
# -------------------------------------------------------------
# 657 K     Trainable params
# 0         Non-trainable params
# 657 K     Total params
# 2.630     Total estimated model params size (MB)
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████████████| 232/232 [00:06<00:00, 37.28it/s, v_num=268]
# Epoch 1: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.63it/s, v_num=268, train_loss=1.180, val_loss=0.897]
# Epoch 2: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.69it/s, v_num=268, train_loss=0.904, val_loss=0.851]
# Epoch 3: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.86it/s, v_num=268, train_loss=0.868, val_loss=0.828]
# Epoch 4: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 38.15it/s, v_num=268, train_loss=0.839, val_loss=0.814]
# Epoch 5: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.45it/s, v_num=268, train_loss=0.833, val_loss=0.819]
# Epoch 6: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.19it/s, v_num=268, train_loss=0.820, val_loss=0.813]
# Epoch 7: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 36.33it/s, v_num=268, train_loss=0.819, val_loss=0.790]
# Epoch 8: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 36.77it/s, v_num=268, train_loss=0.805, val_loss=0.797]
# Epoch 9: 100%|███████████████████████████████████████████████| 232/232 [00:06<00:00, 37.03it/s, v_num=268, train_loss=0.812, val_loss=0.791]
# Epoch 10: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.23it/s, v_num=268, train_loss=0.805, val_loss=0.787]
# Epoch 11: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.09it/s, v_num=268, train_loss=0.810, val_loss=0.803]
# Epoch 12: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.15it/s, v_num=268, train_loss=0.802, val_loss=0.789]
# Epoch 13: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 36.50it/s, v_num=268, train_loss=0.805, val_loss=0.776]
# Epoch 14: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 36.78it/s, v_num=268, train_loss=0.803, val_loss=0.773]
# Epoch 15: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 36.77it/s, v_num=268, train_loss=0.800, val_loss=0.771]
# Epoch 16: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.29it/s, v_num=268, train_loss=0.803, val_loss=0.774]
# Epoch 17: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.03it/s, v_num=268, train_loss=0.793, val_loss=0.796]
# Epoch 18: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.08it/s, v_num=268, train_loss=0.803, val_loss=0.769]
# Epoch 19: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 36.82it/s, v_num=268, train_loss=0.797, val_loss=0.767]
# Epoch 20: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.39it/s, v_num=268, train_loss=0.792, val_loss=0.785]
# Epoch 21: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 36.87it/s, v_num=268, train_loss=0.791, val_loss=0.765]
# Epoch 22: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.37it/s, v_num=268, train_loss=0.793, val_loss=0.789]
# Epoch 23: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.84it/s, v_num=268, train_loss=0.788, val_loss=0.792]
# Epoch 24: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 37.94it/s, v_num=268, train_loss=0.792, val_loss=0.773]
# Epoch 25: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00, 35.58it/s, v_num=268, train_loss=0.781, val_loss=0.768]
# Epoch 26: 100%|██████████████████████████████████████████████| 232/232 [00:06<00:00,
------------------------------------------------------------------------------------
# 0  | task_loss_fn                                                             | MSELoss            | 0      | train
# 1  | reconstruction_loss_fn                                                   | MSELoss            | 0      | train
# 2  | model                                                                    | SwitchTab          | 657 K  | train
# 3  | model._SwitchTab__encoder                                                | Encoder            | 439 K  | train
# 4  | model._SwitchTab__encoder.transformer                                    | FTTransformer      | 439 K  | train
# 5  | model._SwitchTab__encoder.transformer.tokenizer                          | FeatureTokenizer   | 37.0 K | train
# 6  | model._SwitchTab__encoder.transformer.tokenizer.cat_weights              | Embedding          | 0      | train
# 7  | model._SwitchTab__encoder.transformer.backbone                           | Sequential         | 402 K  | train
# 8  | model._SwitchTab__encoder.transformer.backbone.0                         | Transformer        | 402 K  | train
# 9  | model._SwitchTab__encoder.transformer.backbone.0.block                   | ModuleDict         | 402 K  | train
# 10 | model._SwitchTab__encoder.transformer.backbone.0.block.attention         | MultiheadAttention | 160 K  | train
# 11 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.W_qkv   | Linear             | 120 K  | train
# 12 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.W_out   | Linear             | 40.2 K | train
# 13 | model._SwitchTab__encoder.transformer.backbone.0.block.attention.dropout | Dropout            | 0      | train
# 14 | model._SwitchTab__encoder.transformer.backbone.0.block.linear0           | Linear             | 160 K  | train
# 15 | model._SwitchTab__encoder.transformer.backbone.0.block.linear1           | Linear             | 80.2 K | train
# 16 | model._SwitchTab__encoder.transformer.backbone.0.block.norm1             | LayerNorm          | 400    | train
# 17 | model._SwitchTab__encoder.transformer.backbone.0.block.ffn_dropout       | Dropout            | 0      | train
# 18 | model.projector_m                                                        | Projector          | 40.2 K | train
# 19 | model.projector_m.linear                                                 | Linear             | 40.2 K | train
# 20 | model.projector_m.activation                                             | SiLU               | 0      | train
# 21 | model.projector_s                                                        | Projector          | 40.2 K | train
# 22 | model.projector_s.linear                                                 | Linear             | 40.2 K | train
# 23 | model.projector_s.activation                                             | SiLU               | 0      | train
# 24 | model.decoder                                                            | Decoder            | 36.9 K | train
# 25 | model.decoder.linear                                                     | Linear             | 36.9 K | train
# 26 | model.decoder.activation                                                 | SiLU               | 0      | train
# 27 | model.head                                                               | Linear             | 201    | train
# 28 | model.one_layer_prediction_head                                          | Sequential         | 40.4 K | train
# 29 | model.one_layer_prediction_head.head_linear_hid                          | Linear             | 40.2 K | train
# 30 | model.one_layer_prediction_head.head_activation                          | ReLU               | 0      | train
# 31 | model.one_layer_prediction_head.head_linear_out                          | Linear             | 201    | train
# 32 | model.two_layer_prediction_head                                          | Sequential         | 60.4 K | train
# 33 | model.two_layer_prediction_head.head_linear_hid1                         | Linear             | 40.2 K | train
# 34 | model.two_layer_prediction_head.head_activation1                         | ReLU               | 0      | train
# 35 | model.two_layer_prediction_head.head_linear_hid2                         | Linear             | 20.1 K | train
# 36 | model.two_layer_prediction_head.head_activation2                         | ReLU               | 0      | train
# 37 | model.two_layer_prediction_head.head_linear_out                          | Linear             | 101    | train
# 38 | model.activation                                                         | SiLU               | 0      | train
# -------------------------------------------------------------------------------------------------------------------------
# 657 K     Trainable params
# 0         Non-trainable params
# 657 K     Total params
# 2.630     Total estimated model params size (MB)
# DONE PRETRAINING
