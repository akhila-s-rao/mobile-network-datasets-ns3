# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from s3l_training import s3l_training
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
s3l_training(SP_results_folder='FP2_SP_1layer_unfrozen_0dot5Beta', # This folder will be created and the results csv files stored there 
             pred_head_type = 'ts3l',
             pt_type ='vime',
             unlab_dataset_scenario = 'pd4',
             pt_folder = 'FP2',
             pretrain=False, # if True First Phase training
             use_pretrained_model=True, 
             freeze_encoder=False,
             pred_head_size = 1, 
             shift_samp_for_predict = True)
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# rand_itr:  0  train_runs:  [15 18 16 13 17 14 11]  test_runs:  [12 19 20]
# Concatenating runs:  range(1, 11)
# Time to read csv file for run:  2.7560529708862305
# Loaded run 1
# Time to read csv file for run:  2.8455581665039062
# Loaded run 2
# Time to read csv file for run:  2.8639228343963623
# Loaded run 3
# Time to read csv file for run:  2.8750767707824707
# Loaded run 4
# Time to read csv file for run:  2.8486971855163574
# Loaded run 5
# Time to read csv file for run:  2.8935253620147705
# Loaded run 6
# Time to read csv file for run:  2.8221054077148438
# Loaded run 7
# Time to read csv file for run:  2.8972160816192627
# Loaded run 8
# Time to read csv file for run:  2.67262864112854
# Loaded run 9
# Time to read csv file for run:  2.875880479812622
# Loaded run 10
# pretrain_data, before removing rows that dont have traffic  (1799100, 102)
# ...
