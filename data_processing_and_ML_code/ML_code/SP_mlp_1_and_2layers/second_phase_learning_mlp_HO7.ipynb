# %%
# reload
#%reset
# %load_ext autoreload
# %autoreload 2 

import warnings
import logging
import os

# DEBUG MODE
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
logging.getLogger('tensorflow').setLevel(logging.FATAL)
    
from second_phase_training import second_phase_training
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
second_phase_training('mlp')
# Out:
# Run with random seed:  561
# GPU is available.
# 1
# True
# 12.1
# # train runs used  7
# # test runs used  3
# Concatenating runs:  [15 18 16 13 17 14 11]
# Time to read csv file for run:  3.12565541267395
# Loaded run 15
# Time to read csv file for run:  2.8101155757904053
# Loaded run 18
# Time to read csv file for run:  2.7651541233062744
# Loaded run 16
# Time to read csv file for run:  2.8544321060180664
# Loaded run 13
# Time to read csv file for run:  2.796616315841675
# Loaded run 17
# Time to read csv file for run:  2.7753212451934814
# Loaded run 14
# Time to read csv file for run:  2.7555408477783203
# Loaded run 11
# Concatenating runs:  [12 19 20]
# Time to read csv file for run:  2.8010365962982178
# Loaded run 12
# Time to read csv file for run:  2.8370234966278076
# Loaded run 19
# Time to read csv file for run:  2.8295247554779053
# Loaded run 20
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...
