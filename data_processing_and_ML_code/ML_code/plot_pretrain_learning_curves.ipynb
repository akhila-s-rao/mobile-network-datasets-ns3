# %%
from plotting_functions import plot_model_train_info
from helper_functions import s3l_load
# Out:
# 2024-10-21 15:15:07.467648: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-21 15:15:07.514475: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-21 15:15:07.515512: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-21 15:15:08.412781: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
pt_type = 'dae'
pt_folder = 'FP2'

# %%
pretrain_slice = 'all'
pretrain_type = 's3l_'+pt_type
pretrain_models_folder = 'models/'+pt_folder+'/'+pt_type+'_pretrain/'
pretrain_model_to_load_name = pretrain_slice+'_'+pretrain_type
pretrain_model_to_load_type = 's3l_'+pt_type

ssl_model = s3l_load(pretrain_models_folder+pretrain_model_to_load_name+'.ckpt', pretrain_model_to_load_type)
plt_str = 'loss_curve_'+pt_type+'_'+pt_folder+'.pdf'
print(ssl_model.first_phase_train_loss) 
plot_model_train_info (ssl_model.first_phase_train_loss, ssl_model.first_phase_val_loss, 'plots/'+plt_str)
# Out:
# Seed set to 42
# []
# True

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.2+cu121
